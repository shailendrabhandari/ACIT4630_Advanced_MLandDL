# %% [markdown]
# # For plotting accuracies

# %%
import pandas as pd

# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category = FutureWarning)
# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category = FutureWarning)

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('Accuracy_prec.csv')

# %%
X = df.iloc[:, :-1].values # We take all the feature columns (we exclude the last one)
#Y = df.iloc[:, 5].values # We take the dependent variables
df
# Out:
#       Scores  Single layer LSTM  Multi-layer LSTM  1D-CNN+LSTM
# 0   Accuracy              98.04             98.73        99.68
# 1  F1_scores              99.22             98.86        99.73
# 2  Precision              98.47             98.31       100.00
# 3     Recall             100.00             99.47        99.47

# %%
X = df['Scores']
A = df['Single layer LSTM']
B = df['Multi-layer LSTM']
C = df['1D-CNN+LSTM']

#bin_vector = np.loadtext('sacc_or_fixation.txt')
plt.plot(X[0:1000],A[0:500], c='b', label= 'Single Layer LSTM')
plt.plot(X[0:1000],B[0:500], c='g', label ='Multi-layer LSTM')
plt.plot(X[0:1000],C[0:500], c='r', label ='1D-CNN+LSTM')

plt.legend(loc="lower right")
plt.title('Accuracies of each activities for different models')
plt.xlabel('',fontsize=15)
plt.ylabel('Scores',fontsize=15)
plt. grid(True)
plt.savefig('images/comparision of accuriesAndprecision.pdf')
plt.show()
