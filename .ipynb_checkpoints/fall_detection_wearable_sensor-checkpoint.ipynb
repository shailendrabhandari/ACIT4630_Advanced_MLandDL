# %% [markdown]
# # Detecting Falls with Wearable Sensors

# %%
import pandas as pd
from sklearn import tree
import numpy as np
import graphviz
from sklearn.metrics import accuracy_score
from sklearn.metrics import fbeta_score  #The F-beta score is the weighted harmonic mean
#of precision and recall, reaching its optimal value at 1 and its worst value at 0.
import numpy as np
from time import time
from IPython.display import display
baseDir='data/FallDataSet' #Directory for data set

def export_decision_tree(clf, feature_names):
    dot_data = tree.export_graphviz(clf,
                                    out_file=None,
                                    feature_names=feature_names,
                                    class_names=['not survived', 'survived'],
                                    filled=True)
    return graphviz.Source(dot_data)

# %% [markdown]
# ## Data input

# %%
from falldetection.feature_extractor import FeatureExtractor 
df = FeatureExtractor.sensor_file_2_df('/media/shailendra/New Volume/Master_Data_Science_Oslo_met/Second_Sem/Machine_learning/Final_project/newProject/data/FallDataSet/101/Testler Export/901/Test_1/340535.txt')
df.head()
# Out:
#         Acc_X     Acc_Y     Acc_Z     Gyr_X     Gyr_Y     Gyr_Z     Mag_X  \
# 155  9.737897  1.062179  0.791073 -0.017405  0.002575 -0.005722 -0.816650
# 156  9.753418  1.071167  0.784302 -0.025940  0.003099  0.005341 -0.816650
# 157  9.707761  1.046896  0.803351 -0.019455  0.017548  0.002670 -0.816650
# 158  9.765625  1.071167  0.752258 -0.040627  0.018358  0.002861 -0.814209
# 159  9.820127  1.035285  0.733662 -0.043821  0.021172  0.001335 -0.816650
#
#         Mag_Y     Mag_Z
# 155  0.521729  0.022461
# 156  0.521729  0.022461
# 157  0.521729  0.019775
# 158  0.521729  0.019531
# 159  0.521729  0.019775

# %%
#Importing data from the relevant DLA

from falldetection.sensor import Sensor 
from falldetection.sensor_files_provider import SensorFilesProvider
from falldetection.sensor_files_to_exclude import get_sensor_files_to_exclude_for
from falldetection.fall_predicate import isFall

def get_sensor_files(baseDir, sensor, sensor_file_filter):
    def get_sensor_files():
        return createSensorFilesProvider().provide_sensor_files()

    def createSensorFilesProvider():
        return SensorFilesProvider(baseDir, sensor, get_sensor_files_to_exclude_for(sensor))

    return list(filter(sensor_file_filter, get_sensor_files()))

fall_sensor_files = get_sensor_files(baseDir, Sensor.RIGHT_THIGH, isFall)
non_fall_sensor_files = get_sensor_files(baseDir, Sensor.RIGHT_THIGH, lambda sensor_file: not isFall(sensor_file))

# %%
# plotting different activies like fall/ non fall and so on (Data visualization)

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from falldetection.feature_extractor import FeatureExtractor

def get_total_acceleration(df):
    return np.sqrt(df['Acc_X'] ** 2 + df['Acc_Y'] ** 2 + df['Acc_Z'] ** 2)

def reindex(series):
    return pd.Series(series.values, name='total_acceleration', index=pd.Index(np.arange(-50, 51, 1)))

def get_reindexed_total_acceleration(sensor_file):
    return reindex(get_total_acceleration(FeatureExtractor.sensor_file_2_df(sensor_file)))

def get_total_accelerations(sensor_files):
    return list(map(get_reindexed_total_acceleration, sensor_files))

def set_labels():
    plt.xlabel('Time (s)')  # ('Time (1/25 s)')
    plt.ylabel('Total acceleration ($m/s^2$)')    

def plot_total_accelerations(sensor_files):
    total_accelerations = get_total_accelerations(sensor_files)
    ax = sns.lineplot(data=total_accelerations, ci='sd', legend=True)
    set_labels()
    
def plot_individual_total_accelerations(sensor_files):    
    def set_individual_names(total_accelerations):
        for counter, total_acceleration in enumerate(total_accelerations):
            total_acceleration.name = 'Total_acceleration' + str(counter)
        
    total_accelerations = get_total_accelerations(sensor_files)
    set_individual_names(total_accelerations)
    ax = sns.lineplot(data=total_accelerations, dashes=False, legend=True)
    #ax =sns.kdeplot(data=total_accelerations , shade=True)
    set_labels()

# %%
plot_individual_total_accelerations(fall_sensor_files[:5])
plt.show()
plt.savefig('/media/shailendra/New Volume/Master_Data_Science_Oslo_met/Second_Sem/Machine_learning/Final_project/newProject/some_fall_total_accelerations.png')

# %%
plot_individual_total_accelerations(non_fall_sensor_files[:5])
plt.savefig('images/some_non_fall_total_accelerations.png')

# %%
plot_total_accelerations(fall_sensor_files)
plt.savefig('images/fall_total_accelerations.png')

# %%
plot_total_accelerations(non_fall_sensor_files)
plt.savefig('images/non_fall_total_accelerations.png')

# %%
#sensor on right thigh and waist
from falldetection.sensor import Sensor

csv_file_by_sensor = {Sensor.RIGHT_THIGH: 'data/features_right_thigh.csv', Sensor.WAIST: 'data/features_waist.csv'}
csv_file = csv_file_by_sensor[Sensor.RIGHT_THIGH]

# %%
import os
from falldetection.feature_extractor_workflow import extract_features_and_save, FeatureExtractorWorkflow

def create_extracted_features_file(csv_file, sensor):
    if not os.path.isfile(csv_file):
        extract_features_and_save(sensor=sensor,
                                  baseDir=baseDir,
                                  csv_file=csv_file,
                                  autocovar_num=11,
                                  dft_amplitudes_num=0)

create_extracted_features_file(csv_file_by_sensor[Sensor.RIGHT_THIGH], Sensor.RIGHT_THIGH)
create_extracted_features_file(csv_file_by_sensor[Sensor.WAIST], Sensor.WAIST)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %matplotlib inline

data = pd.read_csv(csv_file, index_col=0)

# Success - Display the first record
display(data.head())    #n=as many as needed
# Out:
#                                           sensorFile   fall  Acc_X_min  Acc_X_max  Acc_X_mean  Acc_X_var  Acc_X_skew  Acc_X_kurtosis  Acc_X_autocovar_lag_1  Acc_X_autocovar_lag_2  Acc_X_autocovar_lag_3  Acc_X_autocovar_lag_4  Acc_X_autocovar_lag_5  Acc_X_autocovar_lag_6  Acc_X_autocovar_lag_7  Acc_X_autocovar_lag_8  Acc_X_autocovar_lag_9  Acc_X_autocovar_lag_10  Acc_X_autocovar_lag_11  Acc_Y_min  Acc_Y_max  Acc_Y_mean  Acc_Y_var  Acc_Y_skew  Acc_Y_kurtosis  Acc_Y_autocovar_lag_1  Acc_Y_autocovar_lag_2  Acc_Y_autocovar_lag_3  Acc_Y_autocovar_lag_4  Acc_Y_autocovar_lag_5  Acc_Y_autocovar_lag_6  Acc_Y_autocovar_lag_7  Acc_Y_autocovar_lag_8  Acc_Y_autocovar_lag_9  Acc_Y_autocovar_lag_10  Acc_Y_autocovar_lag_11  Acc_Z_min  Acc_Z_max  Acc_Z_mean  Acc_Z_var  Acc_Z_skew  Acc_Z_kurtosis  Acc_Z_autocovar_lag_1  Acc_Z_autocovar_lag_2  Acc_Z_autocovar_lag_3  Acc_Z_autocovar_lag_4  Acc_Z_autocovar_lag_5  Acc_Z_autocovar_lag_6  Acc_Z_autocovar_lag_7  Acc_Z_autocovar_lag_8  Acc_Z_autocovar_lag_9  \
# 0  data/FallDataSet/101/Testler Export/802/Test_4...  False   4.597473  16.176939    9.371301   2.628580    0.911441        3.541434               1.678807               0.151347              -0.739682              -0.957049              -0.825571              -0.361732              -0.021460              -0.094988              -0.376303               -0.570615               -0.613772  -3.427529   2.119994   -0.398477   1.197303   -0.501028        0.529118               0.878305               0.416364               0.126367              -0.030061              -0.056597               0.054419               0.089898               0.003392              -0.015369                0.069596                0.051978   0.998425   6.542873    3.035454   1.145468    0.374688        0.594420               0.959414               0.663527               0.366912               0.115107               0.007818              -0.018418              -0.028478              -0.076136              -0.160418
# 1  data/FallDataSet/101/Testler Export/803/Test_1...  False   0.927734  21.058655    9.801436  33.440234    0.286469       -1.192471              23.826426               4.343578             -13.102570             -22.705950             -24.542798             -19.199858              -6.335627              12.085995              26.793747               27.631057               14.164719  -5.561900   6.168294   -0.177329   5.368146    0.253341        1.067869               2.952709               1.228112               1.203936               0.838892              -0.187301              -1.068701              -1.292931              -1.618419              -3.755128               -3.817113               -1.669153  -2.191973   6.176758    1.633364   5.202874   -0.046526       -1.255640               3.925334               1.310397              -1.800534              -4.030999              -4.532042              -3.184207              -0.507004               2.311134               4.161301
# 2  data/FallDataSet/101/Testler Export/803/Test_2...  False   0.397563  21.265912    9.725431  40.427378    0.169519       -1.343237              28.655823               4.781240             -17.476077             -29.836935             -30.923475             -21.481118              -2.482121              20.181225              34.607734               30.822636               12.001411  -6.915212   6.536865   -0.234838   5.577954    0.066424        1.401981               2.166793              -0.068059               0.735277               0.677589              -0.345715              -0.802104              -0.251115              -1.134686              -4.137664               -3.113853               -0.340973  -2.085876   6.524658    1.793985   6.000285    0.021022       -1.319290               4.411590               1.120413              -2.400525              -4.818507              -5.056611              -3.162510               0.070632               3.210865               4.891293
# 3  data/FallDataSet/101/Testler Export/803/Test_3...  False  -0.485229  21.955872    9.640511  47.161436    0.222504       -1.310149              33.123833               4.217760             -21.421921             -34.226704             -34.970838             -24.548683              -2.511337              24.792808              41.726149               35.490290               11.181147  -5.890512   6.324768   -0.196868   6.166606    0.343380        1.082675               2.739671               0.313216               0.771336               0.868668              -0.381860              -1.065671              -0.536944              -1.492446              -4.661175               -3.327379               -0.659586  -2.237201   6.297493    1.875507   6.009118   -0.127945       -1.321008               4.337453               1.156383              -2.376663              -4.980900              -5.293504              -3.298557               0.104452               3.381181               5.179111
# 4  data/FallDataSet/101/Testler Export/804/Test_1...  False   8.437753   9.976053    9.300462   0.093432   -0.404062        0.428661               0.072309               0.050691               0.035434               0.017760               0.010346               0.012580               0.013402               0.015759               0.014517                0.009059                0.000705  -0.411320   0.428772   -0.039518   0.050725    0.121676       -1.050316               0.037818               0.030645               0.034974               0.032221               0.027917               0.032276               0.033357               0.028403               0.029625                0.028867                0.027556  -5.242157   2.923346   -2.784108   3.479533    1.435584        1.665802               3.270075               3.060340               2.845711               2.626288               2.411007               2.201964               2.003315               1.805250               1.608153
#
#    Acc_Z_autocovar_lag_10  Acc_Z_autocovar_lag_11  Gyr_X_min  Gyr_X_max  Gyr_X_mean  Gyr_X_var  Gyr_X_skew  Gyr_X_kurtosis  Gyr_X_autocovar_lag_1  Gyr_X_autocovar_lag_2  Gyr_X_autocovar_lag_3  Gyr_X_autocovar_lag_4  Gyr_X_autocovar_lag_5  Gyr_X_autocovar_lag_6  Gyr_X_autocovar_lag_7  Gyr_X_autocovar_lag_8  Gyr_X_autocovar_lag_9  Gyr_X_autocovar_lag_10  Gyr_X_autocovar_lag_11  Gyr_Y_min  Gyr_Y_max  Gyr_Y_mean  Gyr_Y_var  Gyr_Y_skew  Gyr_Y_kurtosis  Gyr_Y_autocovar_lag_1  Gyr_Y_autocovar_lag_2  Gyr_Y_autocovar_lag_3  Gyr_Y_autocovar_lag_4  Gyr_Y_autocovar_lag_5  Gyr_Y_autocovar_lag_6  Gyr_Y_autocovar_lag_7  Gyr_Y_autocovar_lag_8  Gyr_Y_autocovar_lag_9  Gyr_Y_autocovar_lag_10  Gyr_Y_autocovar_lag_11  Gyr_Z_min  Gyr_Z_max  Gyr_Z_mean  Gyr_Z_var  Gyr_Z_skew  Gyr_Z_kurtosis  Gyr_Z_autocovar_lag_1  Gyr_Z_autocovar_lag_2  Gyr_Z_autocovar_lag_3  Gyr_Z_autocovar_lag_4  Gyr_Z_autocovar_lag_5  Gyr_Z_autocovar_lag_6  Gyr_Z_autocovar_lag_7  Gyr_Z_autocovar_lag_8  Gyr_Z_autocovar_lag_9  \
# 0               -0.220864               -0.199297  -0.729733   0.768550   -0.025268   0.096762   -0.150801        0.162428               0.080819               0.050844               0.021899              -0.000659              -0.011707              -0.013646              -0.010212              -0.003578               0.001283                0.002531               -0.001399  -0.775762   0.326210    0.022363   0.055121   -1.294349        1.285619               0.047757               0.032257               0.014440              -0.002138              -0.016557              -0.026447              -0.030416              -0.029336              -0.023301               -0.013017                0.000388  -0.451152   0.435264   -0.005884   0.027069   -0.119397        0.957447               0.022928               0.015783               0.010556               0.006781               0.002913              -0.000350              -0.002034              -0.003398              -0.005706
# 1                4.227218                2.397005  -1.921164   1.846363   -0.057747   0.950754    0.013071       -1.003187               0.847611               0.645871               0.420160               0.193430              -0.043727              -0.281444              -0.495294              -0.689067              -0.818059               -0.819282               -0.696202  -0.689136   0.945143   -0.003560   0.178496    0.262737       -0.813415               0.126279               0.034137              -0.058099              -0.120249              -0.132727              -0.096163              -0.020365               0.066172               0.131901                0.129054                0.060830  -1.233404   1.064037   -0.002396   0.330738   -0.112388       -0.968058               0.294639               0.230346               0.155781               0.070813              -0.014087              -0.095424              -0.174793              -0.235907              -0.267818
# 2                4.347333                1.853562  -1.924624   2.055617    0.066446   1.087859   -0.145001       -0.972171               0.957356               0.698429               0.427387               0.184992              -0.057448              -0.317975              -0.574313              -0.812995              -0.945196               -0.908897               -0.729176  -0.692167   0.933286   -0.026665   0.149517    0.447470       -0.689503               0.095353               0.018265              -0.036486              -0.077950              -0.083590              -0.057643              -0.016803               0.034626               0.072663                0.064909                0.021521  -1.314816   1.108291    0.024439   0.343809   -0.403051       -0.741917               0.289905               0.217457               0.146987               0.055277              -0.038962              -0.119788              -0.197195              -0.250508              -0.267854
# 3                4.571986                1.888005  -2.121062   1.924283   -0.085754   1.088749   -0.043902       -0.914780               0.947997               0.678262               0.418042               0.179857              -0.064322              -0.309918              -0.551300              -0.805262              -0.952145               -0.907637               -0.702238  -0.656544   1.119067   -0.008330   0.111802    0.654742        0.478688               0.068233               0.017477              -0.010288              -0.036499              -0.050230              -0.043609              -0.025254               0.006864               0.035645                0.028065               -0.004460  -1.219803   1.267998   -0.029431   0.330170    0.007869       -0.948447               0.287709               0.221563               0.150747               0.055850              -0.041047              -0.118877              -0.190065              -0.244512              -0.262591
# 4                1.425916                1.245272  -0.228883   0.136810   -0.013888   0.006564   -0.722347       -0.193566               0.005677               0.004408               0.003405               0.002362               0.001440               0.000934               0.000507               0.000041               0.000007                0.000281                0.000422  -0.773985   0.378040   -0.205690   0.101950   -0.172342       -1.135720               0.099803               0.096729               0.092917               0.088550               0.084051               0.079623               0.075419               0.071054               0.066466                0.061702                0.056980  -0.081780   0.126411    0.012660   0.002289    0.241269       -0.547826               0.002036               0.001651               0.001317               0.000970               0.000691               0.000580               0.000569               0.000623               0.000726
#
#    Gyr_Z_autocovar_lag_10  Gyr_Z_autocovar_lag_11  Mag_X_min  Mag_X_max  Mag_X_mean  Mag_X_var  Mag_X_skew  Mag_X_kurtosis  Mag_X_autocovar_lag_1  Mag_X_autocovar_lag_2  Mag_X_autocovar_lag_3  Mag_X_autocovar_lag_4  Mag_X_autocovar_lag_5  Mag_X_autocovar_lag_6  Mag_X_autocovar_lag_7  Mag_X_autocovar_lag_8  Mag_X_autocovar_lag_9  Mag_X_autocovar_lag_10  Mag_X_autocovar_lag_11  Mag_Y_min  Mag_Y_max  Mag_Y_mean  Mag_Y_var  Mag_Y_skew  Mag_Y_kurtosis  Mag_Y_autocovar_lag_1  Mag_Y_autocovar_lag_2  Mag_Y_autocovar_lag_3  Mag_Y_autocovar_lag_4  Mag_Y_autocovar_lag_5  Mag_Y_autocovar_lag_6  Mag_Y_autocovar_lag_7  Mag_Y_autocovar_lag_8  Mag_Y_autocovar_lag_9  Mag_Y_autocovar_lag_10  Mag_Y_autocovar_lag_11  Mag_Z_min  Mag_Z_max  Mag_Z_mean  Mag_Z_var  Mag_Z_skew  Mag_Z_kurtosis  Mag_Z_autocovar_lag_1  Mag_Z_autocovar_lag_2  Mag_Z_autocovar_lag_3  Mag_Z_autocovar_lag_4  Mag_Z_autocovar_lag_5  Mag_Z_autocovar_lag_6  Mag_Z_autocovar_lag_7  Mag_Z_autocovar_lag_8  Mag_Z_autocovar_lag_9  \
# 0               -0.007947               -0.009021  -0.775146  -0.618164   -0.683018   0.001454   -0.121862       -0.060797               0.001413               0.001349               0.001264               0.001164               0.001059               0.000952               0.000849               0.000754               0.000674                0.000604                0.000544  -0.607910  -0.523682   -0.565306   0.000378    0.613932       -0.679603               0.000350               0.000308               0.000260               0.000214               0.000171               0.000135               0.000104               0.000068               0.000027               -0.000016               -0.000060  -0.532471  -0.310791   -0.434106   0.004101   -0.031054       -1.052086               0.003972               0.003768               0.003507               0.003209               0.002898               0.002601               0.002342               0.002128               0.001954
# 1               -0.272454               -0.247691  -0.905029  -0.693359   -0.794361   0.002719   -0.167695       -0.635155               0.002572               0.002307               0.001949               0.001545               0.001120               0.000714               0.000357               0.000091              -0.000073               -0.000120               -0.000050   0.344971   0.697510    0.562577   0.009231   -0.533359       -0.569435               0.008900               0.008066               0.006822               0.005307               0.003667               0.002055               0.000618              -0.000511              -0.001228               -0.001478               -0.001255  -0.068115   0.339844    0.165073   0.012605   -0.351763       -0.908481               0.012208               0.011301               0.010057               0.008625               0.007144               0.005732               0.004485               0.003464               0.002726
# 2               -0.258535               -0.222871  -0.923584  -0.681396   -0.804182   0.003292   -0.014337       -0.605762               0.003150               0.002844               0.002429               0.001946               0.001430               0.000937               0.000517               0.000204               0.000015               -0.000044                0.000029   0.371826   0.666504    0.559326   0.005686   -0.536706       -0.479134               0.005291               0.004504               0.003400               0.002108               0.000776              -0.000462              -0.001460              -0.002096              -0.002306               -0.002099               -0.001535  -0.057373   0.346924    0.128150   0.012469    0.021336       -1.022253               0.011875               0.010878               0.009689               0.008370               0.006967               0.005678               0.004661               0.003975               0.003636
# 3               -0.255474               -0.218805  -0.877686  -0.650391   -0.777172   0.002486   -0.094192       -0.427093               0.002308               0.002012               0.001626               0.001190               0.000738               0.000334               0.000004              -0.000236              -0.000361               -0.000357               -0.000226   0.353271   0.676758    0.553928   0.006754   -0.546487       -0.386242               0.006496               0.005825               0.004823               0.003601               0.002292               0.001031              -0.000049              -0.000849              -0.001292               -0.001354               -0.001044  -0.077148   0.309326    0.117659   0.010056    0.011291       -0.859877               0.009748               0.009046               0.008086               0.006967               0.005793               0.004640               0.003593               0.002733               0.002176
# 4                0.000816                0.000833  -1.042480  -0.642578   -0.955450   0.007354    2.043311        4.119613               0.006813               0.006263               0.005705               0.005147               0.004598               0.004061               0.003542               0.003041               0.002560                0.002112                0.001691   0.129883   0.234131    0.186190   0.001029   -0.271615       -1.267864               0.001023               0.001014               0.001000               0.000983               0.000962               0.000939               0.000913               0.000885               0.000856                0.000825                0.000792  -0.917725  -0.187744   -0.412032   0.029454   -1.440117        1.511414               0.027835               0.026190               0.024481               0.022755               0.021013               0.019238               0.017458               0.015693               0.013964
#
#    Mag_Z_autocovar_lag_10  Mag_Z_autocovar_lag_11
# 0                0.001821                0.001719
# 1                0.002307                0.002243
# 2                0.003671                0.004008
# 3                0.001995                0.002166
# 4                0.012236                0.010556

# %%
n_records = len(data)

n_fall = len(data[data['fall'] == True])
n_adl = len(data[data['fall'] == False])

def fall_percent(y):
    return (len(y[y == True]) / len(y)) * 100    

# Print the results
print("Total number of records: {}".format(n_records))
print("Number of falls: {}".format(n_fall))
print("Number of Activities of Daily Life: {}".format(n_adl))
print("Percentage of falls: {:.2f}%".format(fall_percent(data['fall'])))
print("Percentage of Activities of Daily Life: {:.2f}%".format(100 - fall_percent(data['fall'])))
# Out:
# Total number of records: 1570
# Number of falls: 910
# Number of Activities of Daily Life: 660
# Percentage of falls: 57.96%
# Percentage of Activities of Daily Life: 42.04%

# %%
y_feature = data['fall']
X_feature = data.drop(columns=['fall', 'sensorFile'])
X_feature.head()
# Out:
#    Acc_X_min  Acc_X_max  Acc_X_mean  Acc_X_var  Acc_X_skew  Acc_X_kurtosis  Acc_X_autocovar_lag_1  Acc_X_autocovar_lag_2  Acc_X_autocovar_lag_3  Acc_X_autocovar_lag_4  Acc_X_autocovar_lag_5  Acc_X_autocovar_lag_6  Acc_X_autocovar_lag_7  Acc_X_autocovar_lag_8  Acc_X_autocovar_lag_9  Acc_X_autocovar_lag_10  Acc_X_autocovar_lag_11  Acc_Y_min  Acc_Y_max  Acc_Y_mean  Acc_Y_var  Acc_Y_skew  Acc_Y_kurtosis  Acc_Y_autocovar_lag_1  Acc_Y_autocovar_lag_2  Acc_Y_autocovar_lag_3  Acc_Y_autocovar_lag_4  Acc_Y_autocovar_lag_5  Acc_Y_autocovar_lag_6  Acc_Y_autocovar_lag_7  Acc_Y_autocovar_lag_8  Acc_Y_autocovar_lag_9  Acc_Y_autocovar_lag_10  Acc_Y_autocovar_lag_11  Acc_Z_min  Acc_Z_max  Acc_Z_mean  Acc_Z_var  Acc_Z_skew  Acc_Z_kurtosis  Acc_Z_autocovar_lag_1  Acc_Z_autocovar_lag_2  Acc_Z_autocovar_lag_3  Acc_Z_autocovar_lag_4  Acc_Z_autocovar_lag_5  Acc_Z_autocovar_lag_6  Acc_Z_autocovar_lag_7  Acc_Z_autocovar_lag_8  Acc_Z_autocovar_lag_9  Acc_Z_autocovar_lag_10  Acc_Z_autocovar_lag_11  Gyr_X_min  \
# 0   4.597473  16.176939    9.371301   2.628580    0.911441        3.541434               1.678807               0.151347              -0.739682              -0.957049              -0.825571              -0.361732              -0.021460              -0.094988              -0.376303               -0.570615               -0.613772  -3.427529   2.119994   -0.398477   1.197303   -0.501028        0.529118               0.878305               0.416364               0.126367              -0.030061              -0.056597               0.054419               0.089898               0.003392              -0.015369                0.069596                0.051978   0.998425   6.542873    3.035454   1.145468    0.374688        0.594420               0.959414               0.663527               0.366912               0.115107               0.007818              -0.018418              -0.028478              -0.076136              -0.160418               -0.220864               -0.199297  -0.729733
# 1   0.927734  21.058655    9.801436  33.440234    0.286469       -1.192471              23.826426               4.343578             -13.102570             -22.705950             -24.542798             -19.199858              -6.335627              12.085995              26.793747               27.631057               14.164719  -5.561900   6.168294   -0.177329   5.368146    0.253341        1.067869               2.952709               1.228112               1.203936               0.838892              -0.187301              -1.068701              -1.292931              -1.618419              -3.755128               -3.817113               -1.669153  -2.191973   6.176758    1.633364   5.202874   -0.046526       -1.255640               3.925334               1.310397              -1.800534              -4.030999              -4.532042              -3.184207              -0.507004               2.311134               4.161301                4.227218                2.397005  -1.921164
# 2   0.397563  21.265912    9.725431  40.427378    0.169519       -1.343237              28.655823               4.781240             -17.476077             -29.836935             -30.923475             -21.481118              -2.482121              20.181225              34.607734               30.822636               12.001411  -6.915212   6.536865   -0.234838   5.577954    0.066424        1.401981               2.166793              -0.068059               0.735277               0.677589              -0.345715              -0.802104              -0.251115              -1.134686              -4.137664               -3.113853               -0.340973  -2.085876   6.524658    1.793985   6.000285    0.021022       -1.319290               4.411590               1.120413              -2.400525              -4.818507              -5.056611              -3.162510               0.070632               3.210865               4.891293                4.347333                1.853562  -1.924624
# 3  -0.485229  21.955872    9.640511  47.161436    0.222504       -1.310149              33.123833               4.217760             -21.421921             -34.226704             -34.970838             -24.548683              -2.511337              24.792808              41.726149               35.490290               11.181147  -5.890512   6.324768   -0.196868   6.166606    0.343380        1.082675               2.739671               0.313216               0.771336               0.868668              -0.381860              -1.065671              -0.536944              -1.492446              -4.661175               -3.327379               -0.659586  -2.237201   6.297493    1.875507   6.009118   -0.127945       -1.321008               4.337453               1.156383              -2.376663              -4.980900              -5.293504              -3.298557               0.104452               3.381181               5.179111                4.571986                1.888005  -2.121062
# 4   8.437753   9.976053    9.300462   0.093432   -0.404062        0.428661               0.072309               0.050691               0.035434               0.017760               0.010346               0.012580               0.013402               0.015759               0.014517                0.009059                0.000705  -0.411320   0.428772   -0.039518   0.050725    0.121676       -1.050316               0.037818               0.030645               0.034974               0.032221               0.027917               0.032276               0.033357               0.028403               0.029625                0.028867                0.027556  -5.242157   2.923346   -2.784108   3.479533    1.435584        1.665802               3.270075               3.060340               2.845711               2.626288               2.411007               2.201964               2.003315               1.805250               1.608153                1.425916                1.245272  -0.228883
#
#    Gyr_X_max  Gyr_X_mean  Gyr_X_var  Gyr_X_skew  Gyr_X_kurtosis  Gyr_X_autocovar_lag_1  Gyr_X_autocovar_lag_2  Gyr_X_autocovar_lag_3  Gyr_X_autocovar_lag_4  Gyr_X_autocovar_lag_5  Gyr_X_autocovar_lag_6  Gyr_X_autocovar_lag_7  Gyr_X_autocovar_lag_8  Gyr_X_autocovar_lag_9  Gyr_X_autocovar_lag_10  Gyr_X_autocovar_lag_11  Gyr_Y_min  Gyr_Y_max  Gyr_Y_mean  Gyr_Y_var  Gyr_Y_skew  Gyr_Y_kurtosis  Gyr_Y_autocovar_lag_1  Gyr_Y_autocovar_lag_2  Gyr_Y_autocovar_lag_3  Gyr_Y_autocovar_lag_4  Gyr_Y_autocovar_lag_5  Gyr_Y_autocovar_lag_6  Gyr_Y_autocovar_lag_7  Gyr_Y_autocovar_lag_8  Gyr_Y_autocovar_lag_9  Gyr_Y_autocovar_lag_10  Gyr_Y_autocovar_lag_11  Gyr_Z_min  Gyr_Z_max  Gyr_Z_mean  Gyr_Z_var  Gyr_Z_skew  Gyr_Z_kurtosis  Gyr_Z_autocovar_lag_1  Gyr_Z_autocovar_lag_2  Gyr_Z_autocovar_lag_3  Gyr_Z_autocovar_lag_4  Gyr_Z_autocovar_lag_5  Gyr_Z_autocovar_lag_6  Gyr_Z_autocovar_lag_7  Gyr_Z_autocovar_lag_8  Gyr_Z_autocovar_lag_9  Gyr_Z_autocovar_lag_10  Gyr_Z_autocovar_lag_11  Mag_X_min  Mag_X_max  \
# 0   0.768550   -0.025268   0.096762   -0.150801        0.162428               0.080819               0.050844               0.021899              -0.000659              -0.011707              -0.013646              -0.010212              -0.003578               0.001283                0.002531               -0.001399  -0.775762   0.326210    0.022363   0.055121   -1.294349        1.285619               0.047757               0.032257               0.014440              -0.002138              -0.016557              -0.026447              -0.030416              -0.029336              -0.023301               -0.013017                0.000388  -0.451152   0.435264   -0.005884   0.027069   -0.119397        0.957447               0.022928               0.015783               0.010556               0.006781               0.002913              -0.000350              -0.002034              -0.003398              -0.005706               -0.007947               -0.009021  -0.775146  -0.618164
# 1   1.846363   -0.057747   0.950754    0.013071       -1.003187               0.847611               0.645871               0.420160               0.193430              -0.043727              -0.281444              -0.495294              -0.689067              -0.818059               -0.819282               -0.696202  -0.689136   0.945143   -0.003560   0.178496    0.262737       -0.813415               0.126279               0.034137              -0.058099              -0.120249              -0.132727              -0.096163              -0.020365               0.066172               0.131901                0.129054                0.060830  -1.233404   1.064037   -0.002396   0.330738   -0.112388       -0.968058               0.294639               0.230346               0.155781               0.070813              -0.014087              -0.095424              -0.174793              -0.235907              -0.267818               -0.272454               -0.247691  -0.905029  -0.693359
# 2   2.055617    0.066446   1.087859   -0.145001       -0.972171               0.957356               0.698429               0.427387               0.184992              -0.057448              -0.317975              -0.574313              -0.812995              -0.945196               -0.908897               -0.729176  -0.692167   0.933286   -0.026665   0.149517    0.447470       -0.689503               0.095353               0.018265              -0.036486              -0.077950              -0.083590              -0.057643              -0.016803               0.034626               0.072663                0.064909                0.021521  -1.314816   1.108291    0.024439   0.343809   -0.403051       -0.741917               0.289905               0.217457               0.146987               0.055277              -0.038962              -0.119788              -0.197195              -0.250508              -0.267854               -0.258535               -0.222871  -0.923584  -0.681396
# 3   1.924283   -0.085754   1.088749   -0.043902       -0.914780               0.947997               0.678262               0.418042               0.179857              -0.064322              -0.309918              -0.551300              -0.805262              -0.952145               -0.907637               -0.702238  -0.656544   1.119067   -0.008330   0.111802    0.654742        0.478688               0.068233               0.017477              -0.010288              -0.036499              -0.050230              -0.043609              -0.025254               0.006864               0.035645                0.028065               -0.004460  -1.219803   1.267998   -0.029431   0.330170    0.007869       -0.948447               0.287709               0.221563               0.150747               0.055850              -0.041047              -0.118877              -0.190065              -0.244512              -0.262591               -0.255474               -0.218805  -0.877686  -0.650391
# 4   0.136810   -0.013888   0.006564   -0.722347       -0.193566               0.005677               0.004408               0.003405               0.002362               0.001440               0.000934               0.000507               0.000041               0.000007                0.000281                0.000422  -0.773985   0.378040   -0.205690   0.101950   -0.172342       -1.135720               0.099803               0.096729               0.092917               0.088550               0.084051               0.079623               0.075419               0.071054               0.066466                0.061702                0.056980  -0.081780   0.126411    0.012660   0.002289    0.241269       -0.547826               0.002036               0.001651               0.001317               0.000970               0.000691               0.000580               0.000569               0.000623               0.000726                0.000816                0.000833  -1.042480  -0.642578
#
#    Mag_X_mean  Mag_X_var  Mag_X_skew  Mag_X_kurtosis  Mag_X_autocovar_lag_1  Mag_X_autocovar_lag_2  Mag_X_autocovar_lag_3  Mag_X_autocovar_lag_4  Mag_X_autocovar_lag_5  Mag_X_autocovar_lag_6  Mag_X_autocovar_lag_7  Mag_X_autocovar_lag_8  Mag_X_autocovar_lag_9  Mag_X_autocovar_lag_10  Mag_X_autocovar_lag_11  Mag_Y_min  Mag_Y_max  Mag_Y_mean  Mag_Y_var  Mag_Y_skew  Mag_Y_kurtosis  Mag_Y_autocovar_lag_1  Mag_Y_autocovar_lag_2  Mag_Y_autocovar_lag_3  Mag_Y_autocovar_lag_4  Mag_Y_autocovar_lag_5  Mag_Y_autocovar_lag_6  Mag_Y_autocovar_lag_7  Mag_Y_autocovar_lag_8  Mag_Y_autocovar_lag_9  Mag_Y_autocovar_lag_10  Mag_Y_autocovar_lag_11  Mag_Z_min  Mag_Z_max  Mag_Z_mean  Mag_Z_var  Mag_Z_skew  Mag_Z_kurtosis  Mag_Z_autocovar_lag_1  Mag_Z_autocovar_lag_2  Mag_Z_autocovar_lag_3  Mag_Z_autocovar_lag_4  Mag_Z_autocovar_lag_5  Mag_Z_autocovar_lag_6  Mag_Z_autocovar_lag_7  Mag_Z_autocovar_lag_8  Mag_Z_autocovar_lag_9  Mag_Z_autocovar_lag_10  Mag_Z_autocovar_lag_11
# 0   -0.683018   0.001454   -0.121862       -0.060797               0.001413               0.001349               0.001264               0.001164               0.001059               0.000952               0.000849               0.000754               0.000674                0.000604                0.000544  -0.607910  -0.523682   -0.565306   0.000378    0.613932       -0.679603               0.000350               0.000308               0.000260               0.000214               0.000171               0.000135               0.000104               0.000068               0.000027               -0.000016               -0.000060  -0.532471  -0.310791   -0.434106   0.004101   -0.031054       -1.052086               0.003972               0.003768               0.003507               0.003209               0.002898               0.002601               0.002342               0.002128               0.001954                0.001821                0.001719
# 1   -0.794361   0.002719   -0.167695       -0.635155               0.002572               0.002307               0.001949               0.001545               0.001120               0.000714               0.000357               0.000091              -0.000073               -0.000120               -0.000050   0.344971   0.697510    0.562577   0.009231   -0.533359       -0.569435               0.008900               0.008066               0.006822               0.005307               0.003667               0.002055               0.000618              -0.000511              -0.001228               -0.001478               -0.001255  -0.068115   0.339844    0.165073   0.012605   -0.351763       -0.908481               0.012208               0.011301               0.010057               0.008625               0.007144               0.005732               0.004485               0.003464               0.002726                0.002307                0.002243
# 2   -0.804182   0.003292   -0.014337       -0.605762               0.003150               0.002844               0.002429               0.001946               0.001430               0.000937               0.000517               0.000204               0.000015               -0.000044                0.000029   0.371826   0.666504    0.559326   0.005686   -0.536706       -0.479134               0.005291               0.004504               0.003400               0.002108               0.000776              -0.000462              -0.001460              -0.002096              -0.002306               -0.002099               -0.001535  -0.057373   0.346924    0.128150   0.012469    0.021336       -1.022253               0.011875               0.010878               0.009689               0.008370               0.006967               0.005678               0.004661               0.003975               0.003636                0.003671                0.004008
# 3   -0.777172   0.002486   -0.094192       -0.427093               0.002308               0.002012               0.001626               0.001190               0.000738               0.000334               0.000004              -0.000236              -0.000361               -0.000357               -0.000226   0.353271   0.676758    0.553928   0.006754   -0.546487       -0.386242               0.006496               0.005825               0.004823               0.003601               0.002292               0.001031              -0.000049              -0.000849              -0.001292               -0.001354               -0.001044  -0.077148   0.309326    0.117659   0.010056    0.011291       -0.859877               0.009748               0.009046               0.008086               0.006967               0.005793               0.004640               0.003593               0.002733               0.002176                0.001995                0.002166
# 4   -0.955450   0.007354    2.043311        4.119613               0.006813               0.006263               0.005705               0.005147               0.004598               0.004061               0.003542               0.003041               0.002560                0.002112                0.001691   0.129883   0.234131    0.186190   0.001029   -0.271615       -1.267864               0.001023               0.001014               0.001000               0.000983               0.000962               0.000939               0.000913               0.000885               0.000856                0.000825                0.000792  -0.917725  -0.187744   -0.412032   0.029454   -1.440117        1.511414               0.027835               0.026190               0.024481               0.022755               0.021013               0.019238               0.017458               0.015693               0.013964                0.012236                0.010556

# %%
#information of the data set
from sklearn.model_selection import train_test_split

X_feature_train, X_feature_test, y_feature_train, y_feature_test = train_test_split(X_feature,y_feature,test_size=0.2,random_state=0)

# Show the results of the split
print("Training set has {} samples.".format(X_feature_train.shape[0]))
print("Testing set has {} samples.".format(X_feature_test.shape[0]))
    
print("Percentage of train falls: {:.2f}%".format(fall_percent(y_feature_train)))
print("Percentage of test falls: {:.2f}%".format(fall_percent(y_feature_test)))
# Out:
# Training set has 1256 samples.
# Testing set has 314 samples.
# Percentage of train falls: 58.92%
# Percentage of test falls: 54.14%

# %% [markdown]
# ### always fall classifier, always adl classifier and random classifier

# %%
always_fall_prediction = np.array([True]*len(X_feature_test))
always_adl_prediction = np.array([False]*len(X_feature_test))

# %%
from sklearn.metrics import accuracy_score

random_prediction = np.random.choice([True, False], len(X_feature_test))

print("accuracy_score(always_fall_prediction): {0:.0f}%".format(accuracy_score(y_feature_test, always_fall_prediction) * 100))
print("accuracy_score(always_adl_prediction): {0:.0f}%".format(accuracy_score(y_feature_test, always_adl_prediction) * 100))
print("accuracy_score(random_prediction): {0:.0f}%".format(accuracy_score(y_feature_test, random_prediction) * 100))
# Out:
# accuracy_score(always_fall_prediction): 54%
# accuracy_score(always_adl_prediction): 46%
# accuracy_score(random_prediction): 47%

# %% [markdown]
# ### GaussianNB

# %%
from sklearn.decomposition import PCA  #PCA = Principal componebt analysis

pca = PCA(n_components=1).fit(X_feature_train)

# %%
print("{0:.0f}% variance in the data is explained by the first principal component.".format(pca.explained_variance_ratio_[0] * 100))
# Out:
# 99% variance in the data is explained by the first principal component.

# %%
#import visuals as vs
#pca_results = vs.pca_results(X_feature_train, pca)

# %%
#pca_results.sort_values(by='Dimension 1', axis=1, ascending=False)

# %%
X_feature_train_Acc_Z_var = X_feature_train[['Acc_Z_var']]
X_feature_test_Acc_Z_var = X_feature_test[['Acc_Z_var']]

# %%
from sklearn.naive_bayes import GaussianNB

benchmark_clf = GaussianNB().fit(X_feature_train_Acc_Z_var, y_feature_train)
benchmark_score = accuracy_score(y_feature_test, benchmark_clf.predict(X_feature_test_Acc_Z_var))
print("{0:.0f}%".format(benchmark_score * 100))
# Out:
# 68%

# %% [markdown]
# So the benchmark is a GaussianNB classifier yielding an accuracy of about the above obtained results...%.

# %% [markdown]
# ## Data Preprocessing
# ### Standard Machine Learning Classifiers

# %% [markdown]
# ### LSTM Recurrent Neural Networks

# %%
from falldetection.time_series_extractor_workflow import extract_time_series
from falldetection.sensor import Sensor

X_raw, y_raw = extract_time_series(
    sensor=Sensor.RIGHT_THIGH,
    baseDir=baseDir,
    columns=['Acc_X', 'Acc_Y', 'Acc_Z', 'Gyr_X', 'Gyr_Y', 'Gyr_Z', 'Mag_X', 'Mag_Y', 'Mag_Z'])

# %% [markdown]
# ## Implementation
# ### Standard Machine Learning Classifiers

# %%
import pandas as pd
import visuals as vs
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

def train_predict_multiple(classifiers, X_train, y_train, X_test, y_test, scorer):
    def train_predict(classifier):
        classifier = classifier.fit(X_train, y_train)
        return scorer(y_test, classifier.predict(X_test))

    results = {'Classifier': list(classifiers.keys()),
               'Score': list(map(train_predict, classifiers.values()))}
    return pd.DataFrame(results).sort_values(by='Score', ascending=True)

def plot_training_results(df):
    ax = df.plot.bar(x='Classifier', y='Score', color=['C0', 'C1', 'C2', 'C3'], legend=False, rot=0)
    ax.set_ylabel('Score',)
    ax.axhline(y=benchmark_score,xmin=-0.1,xmax=5.0,linewidth=2,color='r',linestyle='dashed')

classifiers = {'SVC': SVC(random_state=0),
               'DecisionTree': DecisionTreeClassifier(random_state=0),
               'Random Forest': RandomForestClassifier(random_state=0),
               'K Neighbors': KNeighborsClassifier(n_neighbors=3)}

df = train_predict_multiple(classifiers,X_feature_train,y_feature_train,X_feature_test,y_feature_test,scorer=accuracy_score)

plot_training_results(df)
plt.savefig('images/scoresByClassifier.png')
display(df)
# Out:
#       Classifier     Score
# 0            SVC  0.949045
# 1   DecisionTree  0.987261
# 2  Random Forest  1.000000
# 3    K Neighbors  1.000000

# %% [markdown]
# ### LSTM Recurrent Neural Networks

# %%
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.preprocessing import sequence
from keras.layers.convolutional import Conv1D
from keras.layers import ConvLSTM1D
from keras.layers import Flatten
from keras.layers.convolutional import MaxPooling1D
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.layers import TimeDistributed
from keras.layers import Dropout
from numpy import array
# Importing libraries
import numpy as np
import pandas as pd
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
#from keras.utils import to_categorical
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers.core import Dense, Dropout
# Out:
# 2022-05-03 12:58:07.714179: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/shailendra/rsoftware/root/lib/:/home/shailendra/rsoftware/root/lib:/home/shailendra/CLHEP/2.4.1.0-install/lib/:/home/shailendra/geant4/geant4.10.05.p01-build/BuildProducts/lib:/home/shailendra/geant4/geant4.10.05.p01-install/lib:/usr/lib/x86_64-linux-gnu/usr/lib:/usr/local/lib:/Applications/autotools/lib:/home/shailendra/CLHEP/2.4.1.0-install/lib:/home/shailendra/geant4/geant4.10.05.p01-install/lib:/home/shailendra/rsoftware/root/lib:/usr/local/lib:/usr/lib:/home/shailendra/anaroot/lib:/home/shailendra/geant4/geant4.10.05.p01-install/lib
# 2022-05-03 12:58:07.714246: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
from sklearn.model_selection import train_test_split

X_raw_train, X_raw_test, y_raw_train, y_raw_test = train_test_split(X_raw, y_raw, test_size=0.2, random_state=42)
X_raw_train, X_raw_test, X_val, Y_val = train_test_split(X_raw, y_raw, test_size=0.2, random_state=42)

# Initializing parameters
epochs = 70
batch_size = 16
n_hidden = 32
# Utility function to count the number of classes
def _count_classes(y):
    return len(set([tuple(category) for category in y]))
timesteps = len(X_raw_train[0])
input_dim = len(X_raw_train[0][0])
n_classes = _count_classes(y_raw_train)
n_classes  = 1
print(timesteps)
print(input_dim)
print(len(X_raw_train))
# Out:
# 101
# 9
# 1256

# %% [markdown]
# # Base Model

# %%
# Initiliazing the sequential model
model = Sequential()
# Configuring the parameters
model.add(LSTM(n_hidden, input_shape=(timesteps, input_dim)))
# Adding a dropout layer
model.add(Dropout(0.5))
# Adding a dense output layer with sigmoid activation
#model.add(Dense(n_classes, activation='sigmoid'))

model.add(Dense(n_classes, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# 2022-05-03 12:58:10.782055: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/shailendra/rsoftware/root/lib/:/home/shailendra/rsoftware/root/lib:/home/shailendra/CLHEP/2.4.1.0-install/lib/:/home/shailendra/geant4/geant4.10.05.p01-build/BuildProducts/lib:/home/shailendra/geant4/geant4.10.05.p01-install/lib:/usr/lib/x86_64-linux-gnu/usr/lib:/usr/local/lib:/Applications/autotools/lib:/home/shailendra/CLHEP/2.4.1.0-install/lib:/home/shailendra/geant4/geant4.10.05.p01-install/lib:/home/shailendra/rsoftware/root/lib:/usr/local/lib:/usr/lib:/home/shailendra/anaroot/lib:/home/shailendra/geant4/geant4.10.05.p01-install/lib
# 2022-05-03 12:58:10.782102: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-05-03 12:58:10.782128: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (shailendra-Inspiron-7570): /proc/driver/nvidia/version does not exist
# 2022-05-03 12:58:10.783001: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 32)                5376
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 5,409
# Trainable params: 5,409
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training the model
hist = model.fit(X_raw_train,
          y_raw_train,
          batch_size=batch_size,
          validation_data=(X_raw_test, y_raw_test),
          epochs=epochs)

#hist = model.fit(X_raw_train,y_raw_train,batch_size=128,epochs=40,validation_data=(X_raw_test, y_raw_test))
# Out:
# Epoch 1/70
# 79/79 [==============================] - 4s 32ms/step - loss: 0.5871 - accuracy: 0.7237 - val_loss: 0.4469 - val_accuracy: 0.8471
# Epoch 2/70
# 79/79 [==============================] - 2s 27ms/step - loss: 0.4421 - accuracy: 0.8304 - val_loss: 0.3843 - val_accuracy: 0.8599
# Epoch 3/70
# 79/79 [==============================] - 2s 27ms/step - loss: 0.3824 - accuracy: 0.8559 - val_loss: 0.3353 - val_accuracy: 0.8662
# Epoch 4/70
# 79/79 [==============================] - 2s 29ms/step - loss: 0.3374 - accuracy: 0.8623 - val_loss: 0.2854 - val_accuracy: 0.8726
# Epoch 5/70
# 79/79 [==============================] - 2s 26ms/step - loss: 0.3000 - accuracy: 0.8822 - val_loss: 0.2940 - val_accuracy: 0.8854
# Epoch 6/70
# 79/79 [==============================] - 2s 27ms/step - loss: 0.2884 - accuracy: 0.8846 - val_loss: 0.2450 - val_accuracy: 0.8981
# Epoch 7/70
# 79/79 [==============================] - 2s 28ms/step - loss: 0.2560 - accuracy: 0.8957 - val_loss: 0.2542 - val_accuracy: 0.8885
# Epoch 8/70
# 79/79 [==============================] - 3s 33ms/step - loss: 0.2387 - accuracy: 0.8989 - val_loss: 0.1825 - val_accuracy: 0.9268
# Epoch 9/70
# 79/79 [==============================] - 2s 27ms/step - loss: 0.2350 - accuracy: 0.9148 - val_loss: 0.2445 - val_accuracy: 0.8822
# Epoch 10/70
# 79/79 [==============================] - 2s 26ms/step - loss: 0.2281 - accuracy: 0.9053 - val_loss: 0.2734 - val_accuracy: 0.8981
# Epoch 11/70
# 79/79 [==============================] - 2s 25ms/step - loss: 0.2169 - accuracy: 0.9037 - val_loss: 0.1751 - val_accuracy: 0.9331
# Epoch 12/70
# 79/79 [==============================] - 2s 26ms/step - loss: 0.1745 - accuracy: 0.9395 - val_loss: 0.1691 - val_accuracy: 0.9427
# Epoch 13/70
# 79/79 [==============================] - 2s 26ms/step - loss: 0.3171 - accuracy: 0.8328 - val_loss: 0.1972 - val_accuracy: 0.9172
# Epoch 14/70
# 79/79 [==============================] - 2s 25ms/step - loss: 0.1870 - accuracy: 0.9228 - val_loss: 0.1482 - val_accuracy: 0.9299
# Epoch 15/70
# 79/79 [==============================] - 2s 26ms/step - loss: 0.1618 - accuracy: 0.9268 - val_loss: 0.2584 - val_accuracy: 0.8567
# Epoch 16/70
# 79/79 [==============================] - 2s 26ms/step - loss: 0.1742 - accuracy: 0.9244 - val_loss: 0.1461 - val_accuracy: 0.9427
# Epoch 17/70
# 79/79 [==============================] - 2s 27ms/step - loss: 0.1464 - accuracy: 0.9339 - val_loss: 0.1527 - val_accuracy: 0.9331
# Epoch 18/70
# 79/79 [==============================] - 2s 27ms/step - loss: 0.1431 - accuracy: 0.9427 - val_loss: 0.1212 - val_accuracy: 0.9554
# Epoch 19/70
# 79/79 [==============================] - 2s 27ms/step - loss: 0.1863 - accuracy: 0.9140 - val_loss: 0.1571 - val_accuracy: 0.9331
# Epoch 20/70
# 79/79 [==============================] - 2s 29ms/step - loss: 0.1496 - accuracy: 0.9331 - val_loss: 0.1371 - val_accuracy: 0.9395
# Epoch 21/70
# 79/79 [==============================] - 2s 26ms/step - loss: 0.1291 - accuracy: 0.9387 - val_loss: 0.1203 - val_accuracy: 0.9554
# Epoch 22/70
# 79/79 [==============================] - 2s 27ms/step - loss: 0.1278 - accuracy: 0.9443 - val_loss: 0.1162 - val_accuracy: 0.9650
# Epoch 23/70
# 79/79 [==============================] - 2s 28ms/step - loss: 0.1241 - accuracy: 0.9554 - val_loss: 0.1311 - val_accuracy: 0.9682
# Epoch 24/70
# 79/79 [==============================] - 2s 28ms/step - loss: 0.1337 - accuracy: 0.9594 - val_loss: 0.1054 - val_accuracy: 0.9745
# Epoch 25/70
# 79/79 [==============================] - 2s 25ms/step - loss: 0.1188 - accuracy: 0.9586 - val_loss: 0.0911 - val_accuracy: 0.9777
# Epoch 26/70
# 79/79 [==============================] - 2s 27ms/step - loss: 0.1741 - accuracy: 0.9490 - val_loss: 0.1356 - val_accuracy: 0.9459
# Epoch 27/70
# 79/79 [==============================] - 2s 29ms/step - loss: 0.1435 - accuracy: 0.9506 - val_loss: 0.0910 - val_accuracy: 0.9745
# Epoch 28/70
# 79/79 [==============================] - 2s 29ms/step - loss: 0.1164 - accuracy: 0.9594 - val_loss: 0.0880 - val_accuracy: 0.9841
# Epoch 29/70
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0942 - accuracy: 0.9610 - val_loss: 0.0533 - val_accuracy: 0.9873
# Epoch 30/70
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0725 - accuracy: 0.9737 - val_loss: 0.0574 - val_accuracy: 0.9777
# Epoch 31/70
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0701 - accuracy: 0.9729 - val_loss: 0.0351 - val_accuracy: 0.9936
# Epoch 32/70
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0760 - accuracy: 0.9769 - val_loss: 0.0782 - val_accuracy: 0.9682
# Epoch 33/70
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0551 - accuracy: 0.9849 - val_loss: 0.0317 - val_accuracy: 0.9904
# Epoch 34/70
# 79/79 [==============================] - 2s 27ms/step - loss: 0.0566 - accuracy: 0.9849 - val_loss: 0.0491 - val_accuracy: 0.9873
# Epoch 35/70
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0472 - accuracy: 0.9873 - val_loss: 0.0714 - val_accuracy: 0.9809
# Epoch 36/70
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0385 - accuracy: 0.9896 - val_loss: 0.1266 - val_accuracy: 0.9586
# Epoch 37/70
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0728 - accuracy: 0.9713 - val_loss: 0.0476 - val_accuracy: 0.9841
# Epoch 38/70
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0304 - accuracy: 0.9904 - val_loss: 0.0658 - val_accuracy: 0.9745
# Epoch 39/70
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0597 - accuracy: 0.9833 - val_loss: 0.0572 - val_accuracy: 0.9777
# Epoch 40/70
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0315 - accuracy: 0.9912 - val_loss: 0.0252 - val_accuracy: 0.9936
# Epoch 41/70
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0352 - accuracy: 0.9912 - val_loss: 0.0871 - val_accuracy: 0.9650
# Epoch 42/70
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0443 - accuracy: 0.9849 - val_loss: 0.0519 - val_accuracy: 0.9873
# Epoch 43/70
# 79/79 [==============================] - 2s 28ms/step - loss: 0.0526 - accuracy: 0.9865 - val_loss: 0.0220 - val_accuracy: 0.9936
# Epoch 44/70
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0470 - accuracy: 0.9889 - val_loss: 0.0553 - val_accuracy: 0.9745
# Epoch 45/70
# 79/79 [==============================] - 4s 48ms/step - loss: 0.0411 - accuracy: 0.9865 - val_loss: 0.0215 - val_accuracy: 0.9936
# Epoch 46/70
# 79/79 [==============================] - 4s 50ms/step - loss: 0.0252 - accuracy: 0.9960 - val_loss: 0.0273 - val_accuracy: 0.9904
# Epoch 47/70
# 79/79 [==============================] - 3s 41ms/step - loss: 0.0247 - accuracy: 0.9952 - val_loss: 0.0215 - val_accuracy: 0.9968
# Epoch 48/70
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0187 - accuracy: 0.9960 - val_loss: 0.0237 - val_accuracy: 0.9904
# Epoch 49/70
# 79/79 [==============================] - 3s 43ms/step - loss: 0.0165 - accuracy: 0.9960 - val_loss: 0.0254 - val_accuracy: 0.9904
# Epoch 50/70
# 79/79 [==============================] - 4s 45ms/step - loss: 0.0213 - accuracy: 0.9912 - val_loss: 0.0303 - val_accuracy: 0.9904
# Epoch 51/70
# 79/79 [==============================] - 3s 36ms/step - loss: 0.0250 - accuracy: 0.9936 - val_loss: 0.0600 - val_accuracy: 0.9841
# Epoch 52/70
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0193 - accuracy: 0.9920 - val_loss: 0.0230 - val_accuracy: 0.9936
# Epoch 53/70
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0130 - accuracy: 0.9976 - val_loss: 0.0233 - val_accuracy: 0.9904
# Epoch 54/70
# 79/79 [==============================] - 3s 35ms/step - loss: 0.0115 - accuracy: 0.9984 - val_loss: 0.0282 - val_accuracy: 0.9904
# Epoch 55/70
# 79/79 [==============================] - 3s 32ms/step - loss: 0.0101 - accuracy: 0.9976 - val_loss: 0.0241 - val_accuracy: 0.9936
# Epoch 56/70
# 79/79 [==============================] - 3s 34ms/step - loss: 0.0197 - accuracy: 0.9960 - val_loss: 0.0163 - val_accuracy: 0.9968
# Epoch 57/70
# 79/79 [==============================] - 2s 31ms/step - loss: 0.0143 - accuracy: 0.9984 - val_loss: 0.0170 - val_accuracy: 0.9968
# Epoch 58/70
# 79/79 [==============================] - 3s 33ms/step - loss: 0.0085 - accuracy: 0.9984 - val_loss: 0.0434 - val_accuracy: 0.9936
# Epoch 59/70
# 79/79 [==============================] - 2s 28ms/step - loss: 0.0344 - accuracy: 0.9936 - val_loss: 0.0263 - val_accuracy: 0.9936
# Epoch 60/70
# 79/79 [==============================] - 2s 28ms/step - loss: 0.0429 - accuracy: 0.9904 - val_loss: 0.0580 - val_accuracy: 0.9904
# Epoch 61/70
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0275 - accuracy: 0.9936 - val_loss: 0.0474 - val_accuracy: 0.9904
# Epoch 62/70
# 79/79 [==============================] - 2s 27ms/step - loss: 0.0065 - accuracy: 0.9992 - val_loss: 0.0309 - val_accuracy: 0.9936
# Epoch 63/70
# 79/79 [==============================] - 2s 27ms/step - loss: 0.0140 - accuracy: 0.9976 - val_loss: 0.0103 - val_accuracy: 0.9936
# Epoch 64/70
# 79/79 [==============================] - 2s 28ms/step - loss: 0.0170 - accuracy: 0.9984 - val_loss: 0.0155 - val_accuracy: 0.9968
# Epoch 65/70
# 79/79 [==============================] - 2s 28ms/step - loss: 0.0140 - accuracy: 0.9976 - val_loss: 0.0367 - val_accuracy: 0.9904
# Epoch 66/70
# 79/79 [==============================] - 2s 28ms/step - loss: 0.0578 - accuracy: 0.9873 - val_loss: 0.0067 - val_accuracy: 0.9968
# Epoch 67/70
# 79/79 [==============================] - 2s 30ms/step - loss: 0.0140 - accuracy: 0.9976 - val_loss: 0.0150 - val_accuracy: 0.9968
# Epoch 68/70
# 79/79 [==============================] - 2s 28ms/step - loss: 0.0073 - accuracy: 0.9984 - val_loss: 0.0165 - val_accuracy: 0.9968
# Epoch 69/70
# 79/79 [==============================] - 2s 27ms/step - loss: 0.0042 - accuracy: 0.9992 - val_loss: 0.0241 - val_accuracy: 0.9936
# Epoch 70/70
# 79/79 [==============================] - 2s 29ms/step - loss: 0.0102 - accuracy: 0.9976 - val_loss: 0.0060 - val_accuracy: 1.0000

# %%
# summarize history for accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
#plt.savefig('accuracy.pdf', dpi=200)
plt.show()
# summarize history for loss
def plot_curves(hist):
  loss = hist.history['loss']
  val_loss = hist.history['val_loss']
  epochs = range(1, len(loss) + 1)


  plt.figure()
  plt.plot(epochs, loss, 'g', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title('Training and validation loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(loc='upper right')
  #plt.savefig('modelTVloss.pdf', dpi=200) 
  plt.show()

plot_curves(hist)

# %% [markdown]
# # MultiLayer LSTM

# %%
# Initiliazing the sequential model
model = Sequential()
# Configuring the parameters
model.add(LSTM(32,return_sequences=True,input_shape=(timesteps, input_dim)))
# Adding a dropout layer
model.add(Dropout(0.5))

model.add(LSTM(28,input_shape=(timesteps, input_dim)))
# Adding a dropout layer
model.add(Dropout(0.6))
# Adding a dense output layer with sigmoid activation
model.add(Dense(n_classes, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 101, 32)           5376
#
#  dropout_1 (Dropout)         (None, 101, 32)           0
#
#  lstm_2 (LSTM)               (None, 28)                6832
#
#  dropout_2 (Dropout)         (None, 28)                0
#
#  dense_1 (Dense)             (None, 1)                 29
#
# =================================================================
# Total params: 12,237
# Trainable params: 12,237
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training the model
hist = model.fit(X_raw_train,
          y_raw_train,
          batch_size=batch_size,
          validation_data=(X_raw_test, y_raw_test),
          epochs=epochs)
# Out:
# Epoch 1/70
# 79/79 [==============================] - 8s 66ms/step - loss: 0.5761 - accuracy: 0.7213 - val_loss: 0.4113 - val_accuracy: 0.8503
# Epoch 2/70
# 79/79 [==============================] - 6s 71ms/step - loss: 0.3965 - accuracy: 0.8567 - val_loss: 0.3139 - val_accuracy: 0.8854
# Epoch 3/70
# 79/79 [==============================] - 5s 63ms/step - loss: 0.3208 - accuracy: 0.8846 - val_loss: 0.2233 - val_accuracy: 0.9108
# Epoch 4/70
# 79/79 [==============================] - 7s 88ms/step - loss: 0.2834 - accuracy: 0.8941 - val_loss: 0.2303 - val_accuracy: 0.8981
# Epoch 5/70
# 79/79 [==============================] - 6s 70ms/step - loss: 0.2675 - accuracy: 0.9029 - val_loss: 0.2224 - val_accuracy: 0.9108
# Epoch 6/70
# 79/79 [==============================] - 5s 63ms/step - loss: 0.1766 - accuracy: 0.9347 - val_loss: 0.1257 - val_accuracy: 0.9554
# Epoch 7/70
# 79/79 [==============================] - 5s 66ms/step - loss: 0.1693 - accuracy: 0.9451 - val_loss: 0.2034 - val_accuracy: 0.9459
# Epoch 8/70
# 79/79 [==============================] - 5s 65ms/step - loss: 0.1348 - accuracy: 0.9658 - val_loss: 0.0969 - val_accuracy: 0.9650
# Epoch 9/70
# 79/79 [==============================] - 5s 68ms/step - loss: 0.1230 - accuracy: 0.9618 - val_loss: 0.0883 - val_accuracy: 0.9777
# Epoch 10/70
# 79/79 [==============================] - 6s 72ms/step - loss: 0.1879 - accuracy: 0.9268 - val_loss: 0.1818 - val_accuracy: 0.9268
# Epoch 11/70
# 79/79 [==============================] - 6s 75ms/step - loss: 0.1801 - accuracy: 0.9299 - val_loss: 0.1029 - val_accuracy: 0.9459
# Epoch 12/70
# 79/79 [==============================] - 6s 71ms/step - loss: 0.1214 - accuracy: 0.9538 - val_loss: 0.1461 - val_accuracy: 0.9395
# Epoch 13/70
# 79/79 [==============================] - 5s 66ms/step - loss: 0.1052 - accuracy: 0.9642 - val_loss: 0.0809 - val_accuracy: 0.9777
# Epoch 14/70
# 79/79 [==============================] - 5s 60ms/step - loss: 0.0804 - accuracy: 0.9753 - val_loss: 0.0523 - val_accuracy: 0.9841
# Epoch 15/70
# 79/79 [==============================] - 5s 60ms/step - loss: 0.0619 - accuracy: 0.9793 - val_loss: 0.0356 - val_accuracy: 0.9936
# Epoch 16/70
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0850 - accuracy: 0.9705 - val_loss: 0.0843 - val_accuracy: 0.9713
# Epoch 17/70
# 79/79 [==============================] - 5s 61ms/step - loss: 0.0554 - accuracy: 0.9841 - val_loss: 0.0394 - val_accuracy: 0.9777
# Epoch 18/70
# 79/79 [==============================] - 5s 63ms/step - loss: 0.1420 - accuracy: 0.9602 - val_loss: 0.1091 - val_accuracy: 0.9618
# Epoch 19/70
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0896 - accuracy: 0.9769 - val_loss: 0.0403 - val_accuracy: 0.9936
# Epoch 20/70
# 79/79 [==============================] - 5s 60ms/step - loss: 0.1481 - accuracy: 0.9666 - val_loss: 0.0618 - val_accuracy: 0.9809
# Epoch 21/70
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0643 - accuracy: 0.9817 - val_loss: 0.0243 - val_accuracy: 0.9936
# Epoch 22/70
# 79/79 [==============================] - 7s 89ms/step - loss: 0.0466 - accuracy: 0.9841 - val_loss: 0.0572 - val_accuracy: 0.9777
# Epoch 23/70
# 79/79 [==============================] - 7s 88ms/step - loss: 0.0292 - accuracy: 0.9944 - val_loss: 0.0429 - val_accuracy: 0.9904
# Epoch 24/70
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0289 - accuracy: 0.9912 - val_loss: 0.0238 - val_accuracy: 0.9936
# Epoch 25/70
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0167 - accuracy: 0.9968 - val_loss: 0.0213 - val_accuracy: 0.9968
# Epoch 26/70
# 79/79 [==============================] - 5s 61ms/step - loss: 0.0147 - accuracy: 0.9976 - val_loss: 0.0665 - val_accuracy: 0.9809
# Epoch 27/70
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0197 - accuracy: 0.9952 - val_loss: 0.0216 - val_accuracy: 0.9968
# Epoch 28/70
# 79/79 [==============================] - 5s 61ms/step - loss: 0.0112 - accuracy: 0.9968 - val_loss: 0.0213 - val_accuracy: 0.9968
# Epoch 29/70
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0093 - accuracy: 0.9976 - val_loss: 0.0277 - val_accuracy: 0.9904
# Epoch 30/70
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0563 - accuracy: 0.9825 - val_loss: 0.0275 - val_accuracy: 0.9936
# Epoch 31/70
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0128 - accuracy: 0.9984 - val_loss: 0.0129 - val_accuracy: 0.9936
# Epoch 32/70
# 79/79 [==============================] - 5s 61ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0262 - val_accuracy: 0.9936
# Epoch 33/70
# 79/79 [==============================] - 5s 66ms/step - loss: 0.0064 - accuracy: 0.9992 - val_loss: 0.0153 - val_accuracy: 0.9936
# Epoch 34/70
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0085 - accuracy: 0.9976 - val_loss: 0.0362 - val_accuracy: 0.9904
# Epoch 35/70
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0255 - val_accuracy: 0.9904
# Epoch 36/70
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 0.9936
# Epoch 37/70
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0142 - val_accuracy: 0.9936
# Epoch 38/70
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0481 - val_accuracy: 0.9904
# Epoch 39/70
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0279 - val_accuracy: 0.9936
# Epoch 40/70
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0245 - val_accuracy: 0.9936
# Epoch 41/70
# 79/79 [==============================] - 5s 61ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 0.9936
# Epoch 42/70
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0199 - val_accuracy: 0.9936
# Epoch 43/70
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0177 - val_accuracy: 0.9968
# Epoch 44/70
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0144 - val_accuracy: 0.9968
# Epoch 45/70
# 79/79 [==============================] - 5s 66ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 0.9968
# Epoch 46/70
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9968
# Epoch 47/70
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 0.9968
# Epoch 48/70
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 0.9968
# Epoch 49/70
# 79/79 [==============================] - 5s 66ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9968
# Epoch 50/70
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9968
# Epoch 51/70
# 79/79 [==============================] - 5s 64ms/step - loss: 9.4094e-04 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 0.9968
# Epoch 52/70
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 0.9968
# Epoch 53/70
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0167 - val_accuracy: 0.9968
# Epoch 54/70
# 79/79 [==============================] - 5s 62ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0170 - val_accuracy: 0.9968
# Epoch 55/70
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0177 - val_accuracy: 0.9968
# Epoch 56/70
# 79/79 [==============================] - 5s 65ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0175 - val_accuracy: 0.9968
# Epoch 57/70
# 79/79 [==============================] - 5s 67ms/step - loss: 7.0668e-04 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 0.9968
# Epoch 58/70
# 79/79 [==============================] - 5s 65ms/step - loss: 7.6237e-04 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 0.9968
# Epoch 59/70
# 79/79 [==============================] - 5s 61ms/step - loss: 7.7263e-04 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 0.9968
# Epoch 60/70
# 79/79 [==============================] - 5s 62ms/step - loss: 5.8812e-04 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9968
# Epoch 61/70
# 79/79 [==============================] - 5s 63ms/step - loss: 5.7639e-04 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9968
# Epoch 62/70
# 79/79 [==============================] - 5s 60ms/step - loss: 6.7418e-04 - accuracy: 1.0000 - val_loss: 5.8766e-04 - val_accuracy: 1.0000
# Epoch 63/70
# 79/79 [==============================] - 5s 62ms/step - loss: 8.1799e-04 - accuracy: 1.0000 - val_loss: 9.4854e-04 - val_accuracy: 1.0000
# Epoch 64/70
# 79/79 [==============================] - 5s 62ms/step - loss: 4.6555e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 65/70
# 79/79 [==============================] - 5s 61ms/step - loss: 5.0792e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 66/70
# 79/79 [==============================] - 5s 65ms/step - loss: 5.7301e-04 - accuracy: 1.0000 - val_loss: 4.2046e-04 - val_accuracy: 1.0000
# Epoch 67/70
# 79/79 [==============================] - 5s 62ms/step - loss: 5.2875e-04 - accuracy: 1.0000 - val_loss: 3.6007e-04 - val_accuracy: 1.0000
# Epoch 68/70
# 79/79 [==============================] - 5s 63ms/step - loss: 4.7217e-04 - accuracy: 1.0000 - val_loss: 2.1706e-04 - val_accuracy: 1.0000
# Epoch 69/70
# 79/79 [==============================] - 5s 62ms/step - loss: 6.9767e-04 - accuracy: 1.0000 - val_loss: 2.9963e-04 - val_accuracy: 1.0000
# Epoch 70/70
# 79/79 [==============================] - 5s 64ms/step - loss: 6.1934e-04 - accuracy: 1.0000 - val_loss: 3.2176e-04 - val_accuracy: 1.0000

# %%
# summarize history for accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
#plt.savefig('accuracy.pdf', dpi=200)
plt.show()
# summarize history for loss
def plot_curves(hist):
  loss = hist.history['loss']
  val_loss = hist.history['val_loss']
  epochs = range(1, len(loss) + 1)


  plt.figure()
  plt.plot(epochs, loss, 'g', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title('Training and validation loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(loc='upper right')
  #plt.savefig('modelTVloss.pdf', dpi=200) 
  plt.show()

plot_curves(hist)

# %% [markdown]
# # recurrent regularization

# %%
from keras.regularizers import l2
# Initiliazing the sequential model
model = Sequential()
# Configuring the parameters
model.add(LSTM(32,recurrent_regularizer=l2(0.003),return_sequences=True,input_shape=(timesteps, input_dim)))
# Adding a dropout layer
model.add(Dropout(0.5))

model.add(LSTM(28,input_shape=(timesteps, input_dim)))
# Adding a dropout layer
model.add(Dropout(0.6))
# Adding a dense output layer with sigmoid activation
model.add(Dense(n_classes, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 101, 32)           5376
#
#  dropout_3 (Dropout)         (None, 101, 32)           0
#
#  lstm_4 (LSTM)               (None, 28)                6832
#
#  dropout_4 (Dropout)         (None, 28)                0
#
#  dense_2 (Dense)             (None, 1)                 29
#
# =================================================================
# Total params: 12,237
# Trainable params: 12,237
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training the model
hist = model.fit(X_raw_train,
          y_raw_train,
          batch_size=batch_size,
          validation_data=(X_raw_test, y_raw_test),
          epochs=epochs)
# Out:
# Epoch 1/70
# 79/79 [==============================] - 8s 75ms/step - loss: 0.6069 - accuracy: 0.7588 - val_loss: 0.4468 - val_accuracy: 0.8471
# Epoch 2/70
# 79/79 [==============================] - 5s 62ms/step - loss: 0.4203 - accuracy: 0.8543 - val_loss: 0.3479 - val_accuracy: 0.8662
# Epoch 3/70
# 79/79 [==============================] - 5s 64ms/step - loss: 0.3551 - accuracy: 0.8615 - val_loss: 0.2766 - val_accuracy: 0.8949
# Epoch 4/70
# 79/79 [==============================] - 5s 63ms/step - loss: 0.3101 - accuracy: 0.8814 - val_loss: 0.2248 - val_accuracy: 0.9204
# Epoch 5/70
# 79/79 [==============================] - 5s 61ms/step - loss: 0.2394 - accuracy: 0.9212 - val_loss: 0.2108 - val_accuracy: 0.9204
# Epoch 6/70
# 79/79 [==============================] - 5s 63ms/step - loss: 0.2428 - accuracy: 0.9045 - val_loss: 0.1433 - val_accuracy: 0.9427
# Epoch 7/70
# 79/79 [==============================] - 5s 63ms/step - loss: 0.1546 - accuracy: 0.9498 - val_loss: 0.1645 - val_accuracy: 0.9427
# Epoch 8/70
# 79/79 [==============================] - 5s 62ms/step - loss: 0.1431 - accuracy: 0.9475 - val_loss: 0.1059 - val_accuracy: 0.9586
# Epoch 9/70
# 79/79 [==============================] - 5s 62ms/step - loss: 0.1835 - accuracy: 0.9403 - val_loss: 0.1154 - val_accuracy: 0.9682
# Epoch 10/70
# 79/79 [==============================] - 5s 67ms/step - loss: 0.1105 - accuracy: 0.9674 - val_loss: 0.1256 - val_accuracy: 0.9554
# Epoch 11/70
# 79/79 [==============================] - 5s 63ms/step - loss: 0.1312 - accuracy: 0.9546 - val_loss: 0.1234 - val_accuracy: 0.9554
# Epoch 12/70
# 79/79 [==============================] - 5s 61ms/step - loss: 0.1079 - accuracy: 0.9689 - val_loss: 0.1058 - val_accuracy: 0.9618
# Epoch 13/70
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0968 - accuracy: 0.9697 - val_loss: 0.1288 - val_accuracy: 0.9490
# Epoch 14/70
# 79/79 [==============================] - 7s 95ms/step - loss: 0.0859 - accuracy: 0.9761 - val_loss: 0.1167 - val_accuracy: 0.9682
# Epoch 15/70
# 79/79 [==============================] - 7s 92ms/step - loss: 0.1176 - accuracy: 0.9642 - val_loss: 0.1699 - val_accuracy: 0.9554
# Epoch 16/70
# 79/79 [==============================] - 7s 92ms/step - loss: 0.0974 - accuracy: 0.9761 - val_loss: 0.0890 - val_accuracy: 0.9777
# Epoch 17/70
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0953 - accuracy: 0.9753 - val_loss: 0.0789 - val_accuracy: 0.9713
# Epoch 18/70
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0856 - accuracy: 0.9793 - val_loss: 0.0734 - val_accuracy: 0.9745
# Epoch 19/70
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0875 - accuracy: 0.9777 - val_loss: 0.1107 - val_accuracy: 0.9682
# Epoch 20/70
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0753 - accuracy: 0.9801 - val_loss: 0.0704 - val_accuracy: 0.9777
# Epoch 21/70
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0624 - accuracy: 0.9873 - val_loss: 0.0307 - val_accuracy: 0.9968
# Epoch 22/70
# 79/79 [==============================] - 6s 73ms/step - loss: 0.0535 - accuracy: 0.9896 - val_loss: 0.0501 - val_accuracy: 0.9841
# Epoch 23/70
# 79/79 [==============================] - 6s 75ms/step - loss: 0.0520 - accuracy: 0.9889 - val_loss: 0.0536 - val_accuracy: 0.9904
# Epoch 24/70
# 79/79 [==============================] - 8s 101ms/step - loss: 0.0670 - accuracy: 0.9841 - val_loss: 0.0548 - val_accuracy: 0.9777
# Epoch 25/70
# 79/79 [==============================] - 8s 101ms/step - loss: 0.0470 - accuracy: 0.9920 - val_loss: 0.0189 - val_accuracy: 1.0000
# Epoch 26/70
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0469 - accuracy: 0.9912 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 27/70
# 79/79 [==============================] - 5s 66ms/step - loss: 0.0396 - accuracy: 0.9912 - val_loss: 0.0551 - val_accuracy: 0.9777
# Epoch 28/70
# 79/79 [==============================] - 5s 64ms/step - loss: 0.0331 - accuracy: 0.9960 - val_loss: 0.0152 - val_accuracy: 0.9968
# Epoch 29/70
# 79/79 [==============================] - 5s 69ms/step - loss: 0.0572 - accuracy: 0.9904 - val_loss: 0.0385 - val_accuracy: 0.9904
# Epoch 30/70
# 79/79 [==============================] - 7s 89ms/step - loss: 0.0611 - accuracy: 0.9865 - val_loss: 0.0188 - val_accuracy: 1.0000
# Epoch 31/70
# 79/79 [==============================] - 4s 51ms/step - loss: 0.0858 - accuracy: 0.9713 - val_loss: 0.0677 - val_accuracy: 0.9873
# Epoch 32/70
# 79/79 [==============================] - 4s 51ms/step - loss: 0.0440 - accuracy: 0.9912 - val_loss: 0.0371 - val_accuracy: 0.9968
# Epoch 33/70
# 79/79 [==============================] - 3s 42ms/step - loss: 0.0664 - accuracy: 0.9841 - val_loss: 0.1052 - val_accuracy: 0.9713
# Epoch 34/70
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0682 - accuracy: 0.9825 - val_loss: 0.0348 - val_accuracy: 0.9936
# Epoch 35/70
# 79/79 [==============================] - 4s 48ms/step - loss: 0.0291 - accuracy: 0.9976 - val_loss: 0.0305 - val_accuracy: 0.9968
# Epoch 36/70
# 79/79 [==============================] - 4s 56ms/step - loss: 0.0251 - accuracy: 0.9984 - val_loss: 0.0424 - val_accuracy: 0.9936
# Epoch 37/70
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0664 - accuracy: 0.9904 - val_loss: 0.0587 - val_accuracy: 0.9904
# Epoch 38/70
# 79/79 [==============================] - 4s 56ms/step - loss: 0.0425 - accuracy: 0.9936 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 39/70
# 79/79 [==============================] - 13s 162ms/step - loss: 0.0216 - accuracy: 0.9992 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 40/70
# 79/79 [==============================] - 16s 204ms/step - loss: 0.0183 - accuracy: 0.9992 - val_loss: 0.0120 - val_accuracy: 1.0000
# Epoch 41/70
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0186 - accuracy: 0.9992 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 42/70
# 79/79 [==============================] - 4s 46ms/step - loss: 0.0170 - accuracy: 0.9992 - val_loss: 0.0105 - val_accuracy: 1.0000
# Epoch 43/70
# 79/79 [==============================] - 4s 47ms/step - loss: 0.1729 - accuracy: 0.9737 - val_loss: 0.3227 - val_accuracy: 0.9427
# Epoch 44/70
# 79/79 [==============================] - 4s 47ms/step - loss: 0.1760 - accuracy: 0.9530 - val_loss: 0.1112 - val_accuracy: 0.9586
# Epoch 45/70
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0861 - accuracy: 0.9801 - val_loss: 0.0748 - val_accuracy: 0.9777
# Epoch 46/70
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0632 - accuracy: 0.9873 - val_loss: 0.0227 - val_accuracy: 0.9968
# Epoch 47/70
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0504 - accuracy: 0.9889 - val_loss: 0.0708 - val_accuracy: 0.9873
# Epoch 48/70
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0430 - accuracy: 0.9920 - val_loss: 0.0533 - val_accuracy: 0.9936
# Epoch 49/70
# 79/79 [==============================] - 4s 48ms/step - loss: 0.0397 - accuracy: 0.9920 - val_loss: 0.0684 - val_accuracy: 0.9873
# Epoch 50/70
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0388 - accuracy: 0.9936 - val_loss: 0.0473 - val_accuracy: 0.9936
# Epoch 51/70
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0230 - accuracy: 0.9984 - val_loss: 0.0409 - val_accuracy: 0.9968
# Epoch 52/70
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0272 - accuracy: 0.9960 - val_loss: 0.0783 - val_accuracy: 0.9904
# Epoch 53/70
# 79/79 [==============================] - 4s 48ms/step - loss: 0.0204 - accuracy: 0.9984 - val_loss: 0.0384 - val_accuracy: 0.9968
# Epoch 54/70
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0180 - accuracy: 0.9992 - val_loss: 0.0603 - val_accuracy: 0.9936
# Epoch 55/70
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0172 - accuracy: 0.9992 - val_loss: 0.0368 - val_accuracy: 0.9968
# Epoch 56/70
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0234 - accuracy: 0.9976 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 57/70
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0231 - accuracy: 0.9968 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 58/70
# 79/79 [==============================] - 4s 50ms/step - loss: 0.0154 - accuracy: 0.9992 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 59/70
# 79/79 [==============================] - 4s 53ms/step - loss: 0.0172 - accuracy: 0.9992 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 60/70
# 79/79 [==============================] - 5s 63ms/step - loss: 0.0145 - accuracy: 0.9992 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 61/70
# 79/79 [==============================] - 7s 92ms/step - loss: 0.0139 - accuracy: 0.9992 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 62/70
# 79/79 [==============================] - 4s 56ms/step - loss: 0.0203 - accuracy: 0.9976 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 63/70
# 79/79 [==============================] - 4s 51ms/step - loss: 0.0251 - accuracy: 0.9944 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 64/70
# 79/79 [==============================] - 4s 50ms/step - loss: 0.0240 - accuracy: 0.9968 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 65/70
# 79/79 [==============================] - 4s 52ms/step - loss: 0.0303 - accuracy: 0.9936 - val_loss: 0.0199 - val_accuracy: 0.9968
# Epoch 66/70
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0315 - accuracy: 0.9936 - val_loss: 0.0145 - val_accuracy: 1.0000
# Epoch 67/70
# 79/79 [==============================] - 6s 78ms/step - loss: 0.0207 - accuracy: 0.9976 - val_loss: 0.0166 - val_accuracy: 0.9968
# Epoch 68/70
# 79/79 [==============================] - 5s 68ms/step - loss: 0.0153 - accuracy: 0.9976 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 69/70
# 79/79 [==============================] - 6s 76ms/step - loss: 0.0170 - accuracy: 0.9976 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 70/70
# 79/79 [==============================] - 7s 91ms/step - loss: 0.0176 - accuracy: 0.9968 - val_loss: 0.0084 - val_accuracy: 1.0000

# %%
# summarize history for accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
#plt.savefig('accuracy.pdf', dpi=200)
plt.show()
# summarize history for loss
def plot_curves(hist):
  loss = hist.history['loss']
  val_loss = hist.history['val_loss']
  epochs = range(1, len(loss) + 1)


  plt.figure()
  plt.plot(epochs, loss, 'g', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title('Training and validation loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(loc='upper right')
  #plt.savefig('modelTVloss.pdf', dpi=200) 
  plt.show()

plot_curves(hist)

# %%
data_dim = X_raw.shape[2] # = number of features = [{Acc_x, Acc_y, Acc_z, Gyr_*, Max_*, }] = 9
timesteps = X_raw.shape[1] # = 101 = (half_window_size:=50) * 2 + 1
num_classes = 1 # fall?

model = Sequential()
model.add(Conv1D(filters=64, kernel_size=1, padding='same', activation='relu', input_shape=(timesteps, data_dim)))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=128, kernel_size=1, padding='same', activation='relu', input_shape=(timesteps, data_dim)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(128))
model.add(Dense(num_classes, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 101, 64)           640
#
#  max_pooling1d (MaxPooling1D  (None, 50, 64)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 50, 128)           8320
#
#  max_pooling1d_1 (MaxPooling  (None, 25, 128)          0
#  1D)
#
#  lstm_5 (LSTM)               (None, 128)               131584
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 140,673
# Trainable params: 140,673
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
print(len(y_raw_test))
print(len(y_raw_test[y_raw_test == True])/len(y_raw_test))
print(len(y_raw_test[y_raw_test == False])/len(y_raw_test))
# Out:
# 314
# 0.5859872611464968
# 0.4140127388535032

# %%
hist = model.fit(X_raw_train,y_raw_train,batch_size=128,epochs=40,validation_data=(X_raw_test, y_raw_test))
# Out:
# Epoch 1/40
# 10/10 [==============================] - 3s 141ms/step - loss: 0.4651 - accuracy: 0.7858 - val_loss: 0.3244 - val_accuracy: 0.8631
# Epoch 2/40
# 10/10 [==============================] - 1s 151ms/step - loss: 0.2834 - accuracy: 0.8814 - val_loss: 0.2078 - val_accuracy: 0.9108
# Epoch 3/40
# 10/10 [==============================] - 2s 142ms/step - loss: 0.1993 - accuracy: 0.9172 - val_loss: 0.1506 - val_accuracy: 0.9395
# Epoch 4/40
# 10/10 [==============================] - 1s 126ms/step - loss: 0.1289 - accuracy: 0.9411 - val_loss: 0.1170 - val_accuracy: 0.9554
# Epoch 5/40
# 10/10 [==============================] - 1s 108ms/step - loss: 0.1056 - accuracy: 0.9578 - val_loss: 0.0828 - val_accuracy: 0.9713
# Epoch 6/40
# 10/10 [==============================] - 1s 91ms/step - loss: 0.0912 - accuracy: 0.9602 - val_loss: 0.0649 - val_accuracy: 0.9777
# Epoch 7/40
# 10/10 [==============================] - 1s 92ms/step - loss: 0.0552 - accuracy: 0.9777 - val_loss: 0.0485 - val_accuracy: 0.9904
# Epoch 8/40
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0372 - accuracy: 0.9873 - val_loss: 0.0399 - val_accuracy: 0.9873
# Epoch 9/40
# 10/10 [==============================] - 1s 90ms/step - loss: 0.0280 - accuracy: 0.9889 - val_loss: 0.0578 - val_accuracy: 0.9841
# Epoch 10/40
# 10/10 [==============================] - 1s 108ms/step - loss: 0.0567 - accuracy: 0.9793 - val_loss: 0.0619 - val_accuracy: 0.9873
# Epoch 11/40
# 10/10 [==============================] - 1s 108ms/step - loss: 0.0536 - accuracy: 0.9817 - val_loss: 0.0518 - val_accuracy: 0.9873
# Epoch 12/40
# 10/10 [==============================] - 1s 134ms/step - loss: 0.0362 - accuracy: 0.9865 - val_loss: 0.0361 - val_accuracy: 0.9873
# Epoch 13/40
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0267 - accuracy: 0.9912 - val_loss: 0.0339 - val_accuracy: 0.9936
# Epoch 14/40
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0138 - accuracy: 0.9968 - val_loss: 0.0120 - val_accuracy: 0.9936
# Epoch 15/40
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 16/40
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 0.9968
# Epoch 17/40
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9968
# Epoch 18/40
# 10/10 [==============================] - 1s 85ms/step - loss: 8.4800e-04 - accuracy: 1.0000 - val_loss: 0.0107 - val_accuracy: 0.9968
# Epoch 19/40
# 10/10 [==============================] - 1s 86ms/step - loss: 6.8675e-04 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 0.9968
# Epoch 20/40
# 10/10 [==============================] - 1s 86ms/step - loss: 5.7233e-04 - accuracy: 1.0000 - val_loss: 0.0160 - val_accuracy: 0.9968
# Epoch 21/40
# 10/10 [==============================] - 1s 86ms/step - loss: 5.0740e-04 - accuracy: 1.0000 - val_loss: 0.0150 - val_accuracy: 0.9968
# Epoch 22/40
# 10/10 [==============================] - 1s 89ms/step - loss: 4.5317e-04 - accuracy: 1.0000 - val_loss: 0.0134 - val_accuracy: 0.9968
# Epoch 23/40
# 10/10 [==============================] - 1s 85ms/step - loss: 4.1731e-04 - accuracy: 1.0000 - val_loss: 0.0145 - val_accuracy: 0.9968
# Epoch 24/40
# 10/10 [==============================] - 1s 87ms/step - loss: 3.8243e-04 - accuracy: 1.0000 - val_loss: 0.0152 - val_accuracy: 0.9968
# Epoch 25/40
# 10/10 [==============================] - 1s 85ms/step - loss: 3.5348e-04 - accuracy: 1.0000 - val_loss: 0.0154 - val_accuracy: 0.9968
# Epoch 26/40
# 10/10 [==============================] - 1s 84ms/step - loss: 3.2833e-04 - accuracy: 1.0000 - val_loss: 0.0149 - val_accuracy: 0.9968
# Epoch 27/40
# 10/10 [==============================] - 1s 85ms/step - loss: 3.1089e-04 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 0.9968
# Epoch 28/40
# 10/10 [==============================] - 1s 86ms/step - loss: 2.9013e-04 - accuracy: 1.0000 - val_loss: 0.0161 - val_accuracy: 0.9968
# Epoch 29/40
# 10/10 [==============================] - 1s 85ms/step - loss: 2.7304e-04 - accuracy: 1.0000 - val_loss: 0.0162 - val_accuracy: 0.9968
# Epoch 30/40
# 10/10 [==============================] - 1s 85ms/step - loss: 2.5779e-04 - accuracy: 1.0000 - val_loss: 0.0157 - val_accuracy: 0.9968
# Epoch 31/40
# 10/10 [==============================] - 1s 85ms/step - loss: 2.4403e-04 - accuracy: 1.0000 - val_loss: 0.0156 - val_accuracy: 0.9968
# Epoch 32/40
# 10/10 [==============================] - 1s 85ms/step - loss: 2.3069e-04 - accuracy: 1.0000 - val_loss: 0.0162 - val_accuracy: 0.9968
# Epoch 33/40
# 10/10 [==============================] - 1s 85ms/step - loss: 2.2037e-04 - accuracy: 1.0000 - val_loss: 0.0161 - val_accuracy: 0.9968
# Epoch 34/40
# 10/10 [==============================] - 1s 84ms/step - loss: 2.1169e-04 - accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 0.9968
# Epoch 35/40
# 10/10 [==============================] - 1s 85ms/step - loss: 2.0000e-04 - accuracy: 1.0000 - val_loss: 0.0162 - val_accuracy: 0.9968
# Epoch 36/40
# 10/10 [==============================] - 1s 86ms/step - loss: 1.9125e-04 - accuracy: 1.0000 - val_loss: 0.0160 - val_accuracy: 0.9968
# Epoch 37/40
# 10/10 [==============================] - 1s 85ms/step - loss: 1.8314e-04 - accuracy: 1.0000 - val_loss: 0.0167 - val_accuracy: 0.9968
# Epoch 38/40
# 10/10 [==============================] - 1s 90ms/step - loss: 1.7558e-04 - accuracy: 1.0000 - val_loss: 0.0166 - val_accuracy: 0.9968
# Epoch 39/40
# 10/10 [==============================] - 1s 139ms/step - loss: 1.6822e-04 - accuracy: 1.0000 - val_loss: 0.0173 - val_accuracy: 0.9968
# Epoch 40/40
# 10/10 [==============================] - 1s 86ms/step - loss: 1.6115e-04 - accuracy: 1.0000 - val_loss: 0.0170 - val_accuracy: 0.9968

# %%
# summarize history for accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
#plt.savefig('accuracy.pdf', dpi=200)
plt.show()
# summarize history for loss
def plot_curves(hist):
  loss = hist.history['loss']
  val_loss = hist.history['val_loss']
  epochs = range(1, len(loss) + 1)


  plt.figure()
  plt.plot(epochs, loss, 'g', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title('Training and validation loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(loc='upper right')
  #plt.savefig('modelTVloss.pdf', dpi=200) 
  plt.show()

plot_curves(hist)

# %%
scores = model.evaluate(X_raw_test, y_raw_test, verbose=1)
print("Accuracy: {:.2f}%".format(scores[1]*100))
scores, model.metrics_names
# Out:
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0170 - accuracy: 0.9968
# Accuracy: 99.68%
# ([0.01702919229865074, 0.9968152642250061], ['loss', 'accuracy'])

# %%
from sklearn.metrics import accuracy_score
#predictions = model.predict_classes(X_raw_test)  # this is outdated to version 2.5 and above for tensorflow
predictions = (model.predict(X_raw_test) > 0.5).astype("int32")
accuracy_score(y_raw_test, predictions)
# Out:
# 0.9968152866242038

# %% [markdown]
# # second model

# %%
#n_timesteps, n_features, n_outputs = X_raw.shape[2], X_raw.shape[1], 1

# the concept is same in this case:

data_dim = X_raw.shape[2] # = number of features = [{Acc_x, Acc_y, Acc_z, Gyr_*, Max_*, }] = 9
timesteps = X_raw.shape[1] # = 101 = (half_window_size:=50) * 2 + 1
num_classes = 1 # fall?

# %%
#seconf model

model1 = Sequential()
model1.add(LSTM(128, input_shape=(timesteps, data_dim)))
model1.add(Dropout(0.5))
model1.add(Dense(100, activation='sigmoid'))
model1.add(Dropout(0.5))
model1.add(Dense(100, activation='sigmoid'))
model1.add(Dropout(0.5))
model1.add(Dense(num_classes, activation='softmax'))
model1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
print(model1.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 128)               70656
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 100)               12900
#
#  dropout_6 (Dropout)         (None, 100)               0
#
#  dense_5 (Dense)             (None, 100)               10100
#
#  dropout_7 (Dropout)         (None, 100)               0
#
#  dense_6 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 93,757
# Trainable params: 93,757
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model1, show_shapes=True)

# %%
from sklearn.model_selection import train_test_split

X_raw_train, X_raw_test, y_raw_train, y_raw_test = train_test_split(X_raw, y_raw, test_size=0.2, random_state=0)

# %%
print(len(y_raw_test))
print(len(y_raw_test[y_raw_test == True])/len(y_raw_test))
print(len(y_raw_test[y_raw_test == False])/len(y_raw_test))
# Out:
# 314
# 0.5414012738853503
# 0.4585987261146497

# %%
# fit network
batch_size =256
num_epochs = 50
validation_split = 0.20
#hist = model1.fit(X_raw_train, y_raw_train, batch_size=batch_size, validation_split=validation_split, epochs=num_epochs)
hist = model1.fit(X_raw_train,y_raw_train,batch_size=batch_size,epochs=num_epochs,validation_data=(X_raw_test, y_raw_test))
# Out:
# Epoch 1/50
# 2022-05-03 13:13:48.834287: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 13238272 exceeds 10% of free system memory.
# 2022-05-03 13:13:48.837343: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 13238272 exceeds 10% of free system memory.
# 2022-05-03 13:13:48.934069: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 13238272 exceeds 10% of free system memory.
# 2022-05-03 13:13:48.934120: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 13238272 exceeds 10% of free system memory.
# 2/5 [===========>..................] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.5996
# 2022-05-03 13:13:49.189622: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 13238272 exceeds 10% of free system memory.
# 5/5 [==============================] - 3s 385ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 2/50
# 5/5 [==============================] - 1s 306ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 3/50
# 5/5 [==============================] - 2s 345ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 4/50
# 5/5 [==============================] - 2s 339ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 5/50
# 5/5 [==============================] - 2s 325ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 6/50
# 5/5 [==============================] - 1s 275ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 7/50
# 5/5 [==============================] - 1s 272ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 8/50
# 5/5 [==============================] - 1s 280ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 9/50
# 5/5 [==============================] - 1s 274ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 10/50
# 5/5 [==============================] - 1s 276ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 11/50
# 5/5 [==============================] - 1s 278ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 12/50
# 5/5 [==============================] - 1s 274ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 13/50
# 5/5 [==============================] - 1s 271ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 14/50
# 5/5 [==============================] - 1s 271ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 15/50
# 5/5 [==============================] - 1s 271ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 16/50
# 5/5 [==============================] - 2s 539ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 17/50
# 5/5 [==============================] - 2s 403ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 18/50
# 5/5 [==============================] - 1s 271ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 19/50
# 5/5 [==============================] - 1s 301ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 20/50
# 5/5 [==============================] - 1s 292ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 21/50
# 5/5 [==============================] - 1s 275ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 22/50
# 5/5 [==============================] - 1s 272ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 23/50
# 5/5 [==============================] - 2s 326ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 24/50
# 5/5 [==============================] - 2s 333ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 25/50
# 5/5 [==============================] - 2s 324ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 26/50
# 5/5 [==============================] - 2s 347ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 27/50
# 5/5 [==============================] - 3s 432ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 28/50
# 5/5 [==============================] - 2s 327ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 29/50
# 5/5 [==============================] - 2s 413ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 30/50
# 5/5 [==============================] - 2s 313ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 31/50
# 5/5 [==============================] - 2s 317ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 32/50
# 5/5 [==============================] - 1s 302ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 33/50
# 5/5 [==============================] - 2s 363ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 34/50
# 5/5 [==============================] - 1s 302ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 35/50
# 5/5 [==============================] - 2s 372ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 36/50
# 5/5 [==============================] - 1s 284ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 37/50
# 5/5 [==============================] - 1s 286ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 38/50
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 39/50
# 5/5 [==============================] - 1s 306ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 40/50
# 5/5 [==============================] - 2s 314ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 41/50
# 5/5 [==============================] - 2s 359ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 42/50
# 5/5 [==============================] - 2s 354ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 43/50
# 5/5 [==============================] - 2s 331ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 44/50
# 5/5 [==============================] - 2s 409ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 45/50
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 46/50
# 5/5 [==============================] - 1s 297ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 47/50
# 5/5 [==============================] - 2s 355ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 48/50
# 5/5 [==============================] - 2s 339ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 49/50
# 5/5 [==============================] - 2s 395ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414
# Epoch 50/50
# 5/5 [==============================] - 2s 319ms/step - loss: 0.0000e+00 - accuracy: 0.5892 - val_loss: 0.0000e+00 - val_accuracy: 0.5414

# %%
import matplotlib.pyplot as plt

def plot_curves(hist):
  loss = hist.history['loss']
  val_loss = hist.history['val_loss']
  epochs = range(1, len(loss) + 1)

  plt.figure()
  plt.plot(epochs, loss, 'g', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title('Training and validation loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(loc='upper right')

  plt.show()

plot_curves(hist)

# %%
# Activities are the class labels
# It is a 6 class classification

ACTIVITIES = {
    0: 'Acc_X',
    1: 'Acc_Y',
    2: 'Acc_Z',
    3: 'Gyr_X',
    4: 'Gyr_Y',
    5: 'Gyr_Z',
    6: 'Mag_X',
    7: 'Mag_y',
    8: 'Mag_Z'
}

# Utility function to print the confusion matrix
def confusion_matrix_rnn(Y_true, Y_pred):
    Y_true = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_true, axis=1)])
    Y_pred = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_pred, axis=1)])

    #return pd.crosstab(Y_true, Y_pred, rownames=['True'], colnames=['Pred'])
    return metrics.confusion_matrix(Y_true, Y_pred)

# %%
# Confusion Matrix
print(confusion_matrix_rnn(Y_val, best_model.predict(X_val)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6324/3218890254.py in <module>
#       1 # Confusion Matrix
# ----> 2 print(confusion_matrix_rnn(Y_val, best_model.predict(X_val)))
#
# NameError: name 'Y_val' is not defined
