# %% [markdown]
# # Detecting Falls with Wearable Sensors

# %%
import pandas as pd
from sklearn import tree
import numpy as np
import graphviz
from sklearn.metrics import accuracy_score
from sklearn.metrics import fbeta_score  #The F-beta score is the weighted harmonic mean
#of precision and recall, reaching its optimal value at 1 and its worst value at 0.
import numpy as np
from time import time
from IPython.display import display
baseDir='data/FallDataSet' #Directory for data set

def export_decision_tree(clf, feature_names):
    dot_data = tree.export_graphviz(clf,
                                    out_file=None,
                                    feature_names=feature_names,
                                    class_names=['not survived', 'survived'],
                                    filled=True)
    return graphviz.Source(dot_data)

# %% [markdown]
# ## Data input

# %%
from falldetection.feature_extractor import FeatureExtractor 
df = FeatureExtractor.sensor_file_2_df('/media/shailendra/New Volume/Master_Data_Science_Oslo_met/Second_Sem/Machine_learning/Final_project/newProject/data/FallDataSet/101/Testler Export/901/Test_1/340535.txt')
df.head()
# Out:
#         Acc_X     Acc_Y     Acc_Z     Gyr_X     Gyr_Y     Gyr_Z     Mag_X  \
# 155  9.737897  1.062179  0.791073 -0.017405  0.002575 -0.005722 -0.816650
# 156  9.753418  1.071167  0.784302 -0.025940  0.003099  0.005341 -0.816650
# 157  9.707761  1.046896  0.803351 -0.019455  0.017548  0.002670 -0.816650
# 158  9.765625  1.071167  0.752258 -0.040627  0.018358  0.002861 -0.814209
# 159  9.820127  1.035285  0.733662 -0.043821  0.021172  0.001335 -0.816650
#
#         Mag_Y     Mag_Z
# 155  0.521729  0.022461
# 156  0.521729  0.022461
# 157  0.521729  0.019775
# 158  0.521729  0.019531
# 159  0.521729  0.019775

# %%
#Importing data from the relevant DLA

from falldetection.sensor import Sensor 
from falldetection.sensor_files_provider import SensorFilesProvider
from falldetection.sensor_files_to_exclude import get_sensor_files_to_exclude_for
from falldetection.fall_predicate import isFall

def get_sensor_files(baseDir, sensor, sensor_file_filter):
    def get_sensor_files():
        return createSensorFilesProvider().provide_sensor_files()

    def createSensorFilesProvider():
        return SensorFilesProvider(baseDir, sensor, get_sensor_files_to_exclude_for(sensor))

    return list(filter(sensor_file_filter, get_sensor_files()))

fall_sensor_files = get_sensor_files(baseDir, Sensor.RIGHT_THIGH, isFall)
non_fall_sensor_files = get_sensor_files(baseDir, Sensor.RIGHT_THIGH, lambda sensor_file: not isFall(sensor_file))

# %%
# plotting different activies like fall/ non fall and so on (Data visualization)

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from falldetection.feature_extractor import FeatureExtractor

def get_total_acceleration(df):
    return np.sqrt(df['Acc_X'] ** 2 + df['Acc_Y'] ** 2 + df['Acc_Z'] ** 2)

def reindex(series):
    return pd.Series(series.values, name='total_acceleration', index=pd.Index(np.arange(-50, 51, 1)))

def get_reindexed_total_acceleration(sensor_file):
    return reindex(get_total_acceleration(FeatureExtractor.sensor_file_2_df(sensor_file)))

def get_total_accelerations(sensor_files):
    return list(map(get_reindexed_total_acceleration, sensor_files))

def set_labels():
    plt.xlabel('Time (s)',fontsize = 15, fontweight='bold')  # ('Time (1/25 s)')
    plt.ylabel('Total acceleration ($m/s^2$)',fontsize = 15, fontweight='bold')    

def plot_total_accelerations(sensor_files):
    total_accelerations = get_total_accelerations(sensor_files)
    ax = sns.lineplot(data=total_accelerations, ci='sd', legend=True)
    set_labels()
    
def plot_individual_total_accelerations(sensor_files):    
    def set_individual_names(total_accelerations):
        for counter, total_acceleration in enumerate(total_accelerations):
            total_acceleration.name = 'Total_acceleration' + str(counter)
        
    total_accelerations = get_total_accelerations(sensor_files)
    set_individual_names(total_accelerations)
    ax = sns.lineplot(data=total_accelerations, dashes=False, legend=True)
    
    set_labels()

# %%
plot_individual_total_accelerations(fall_sensor_files[:5])
plt.savefig('images/some_fall_total_accelerations.pdf')
plt.show()

# %%
plot_total_accelerations(fall_sensor_files)
plt.savefig('images/fall_total_accelerations.pdf')

# %%
plot_total_accelerations(non_fall_sensor_files)
plt.savefig('images/non_fall_total_accelerations.pdf')

# %%
# plotting different activies like fall/ non fall and so on (Data visualization)

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from falldetection.feature_extractor import FeatureExtractor

def get_total_acceleration(df):
    return np.sqrt(df['Acc_X'] ** 2 + df['Acc_Y'] ** 2 + df['Acc_Z'] ** 2)

def reindex(series):
    return pd.Series(series.values, name='total_acceleration', index=pd.Index(np.arange(-50, 51, 1)))

def get_reindexed_total_acceleration(sensor_file):
    return reindex(get_total_acceleration(FeatureExtractor.sensor_file_2_df(sensor_file)))

def get_total_accelerations(sensor_files):
    return list(map(get_reindexed_total_acceleration, sensor_files))

def set_labels():
    plt.xlabel('Time (s)', fontsize = 15, fontweight='bold')  # ('Time (1/25 s)'
    plt.ylabel('Total acceleration ($m/s^2$)', fontsize =15, fontweight='bold')    

def plot_total_accelerations(sensor_files):
    total_accelerations = get_total_accelerations(sensor_files)
    ax = sns.lineplot(data=total_accelerations, ci='sd', legend=True)
    set_labels()
    
def plot_individual_total_accelerations(sensor_files):    
    def set_individual_names(total_accelerations):
        for counter, total_acceleration in enumerate(total_accelerations):
            total_acceleration.name = 'Total_acceleration' + str(counter)
        
    total_accelerations = get_total_accelerations(sensor_files)
    set_individual_names(total_accelerations)
    #ax = sns.lineplot(data=total_accelerations, dashes=False, legend=True)
    ax =sns.kdeplot(data=total_accelerations , shade=True)
    set_labels()

plot_individual_total_accelerations(non_fall_sensor_files[:5])
plt.savefig('images/some_non_fall_total_accelerations.pdf')

# %%
#sensor on right thigh and waist
from falldetection.sensor import Sensor

csv_file_by_sensor = {Sensor.RIGHT_THIGH: 'data/features_right_thigh.csv', Sensor.WAIST: 'data/features_waist.csv'}
csv_file = csv_file_by_sensor[Sensor.RIGHT_THIGH]

# %%
import os
from falldetection.feature_extractor_workflow import extract_features_and_save, FeatureExtractorWorkflow

def create_extracted_features_file(csv_file, sensor):
    if not os.path.isfile(csv_file):
        extract_features_and_save(sensor=sensor,
                                  baseDir=baseDir,
                                  csv_file=csv_file,
                                  autocovar_num=11,
                                  dft_amplitudes_num=0)

create_extracted_features_file(csv_file_by_sensor[Sensor.RIGHT_THIGH], Sensor.RIGHT_THIGH)
create_extracted_features_file(csv_file_by_sensor[Sensor.WAIST], Sensor.WAIST)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %matplotlib inline

data = pd.read_csv(csv_file, index_col=0)

# Success - Display the first record
display(data.head())    #n=as many as needed
# Out:
#                                           sensorFile   fall  Acc_X_min  Acc_X_max  Acc_X_mean  Acc_X_var  Acc_X_skew  Acc_X_kurtosis  Acc_X_autocovar_lag_1  Acc_X_autocovar_lag_2  Acc_X_autocovar_lag_3  Acc_X_autocovar_lag_4  Acc_X_autocovar_lag_5  Acc_X_autocovar_lag_6  Acc_X_autocovar_lag_7  Acc_X_autocovar_lag_8  Acc_X_autocovar_lag_9  Acc_X_autocovar_lag_10  Acc_X_autocovar_lag_11  Acc_Y_min  Acc_Y_max  Acc_Y_mean  Acc_Y_var  Acc_Y_skew  Acc_Y_kurtosis  Acc_Y_autocovar_lag_1  Acc_Y_autocovar_lag_2  Acc_Y_autocovar_lag_3  Acc_Y_autocovar_lag_4  Acc_Y_autocovar_lag_5  Acc_Y_autocovar_lag_6  Acc_Y_autocovar_lag_7  Acc_Y_autocovar_lag_8  Acc_Y_autocovar_lag_9  Acc_Y_autocovar_lag_10  Acc_Y_autocovar_lag_11  Acc_Z_min  Acc_Z_max  Acc_Z_mean  Acc_Z_var  Acc_Z_skew  Acc_Z_kurtosis  Acc_Z_autocovar_lag_1  Acc_Z_autocovar_lag_2  Acc_Z_autocovar_lag_3  Acc_Z_autocovar_lag_4  Acc_Z_autocovar_lag_5  Acc_Z_autocovar_lag_6  Acc_Z_autocovar_lag_7  Acc_Z_autocovar_lag_8  Acc_Z_autocovar_lag_9  \
# 0  data/FallDataSet/101/Testler Export/802/Test_4...  False   4.597473  16.176939    9.371301   2.628580    0.911441        3.541434               1.678807               0.151347              -0.739682              -0.957049              -0.825571              -0.361732              -0.021460              -0.094988              -0.376303               -0.570615               -0.613772  -3.427529   2.119994   -0.398477   1.197303   -0.501028        0.529118               0.878305               0.416364               0.126367              -0.030061              -0.056597               0.054419               0.089898               0.003392              -0.015369                0.069596                0.051978   0.998425   6.542873    3.035454   1.145468    0.374688        0.594420               0.959414               0.663527               0.366912               0.115107               0.007818              -0.018418              -0.028478              -0.076136              -0.160418
# 1  data/FallDataSet/101/Testler Export/803/Test_1...  False   0.927734  21.058655    9.801436  33.440234    0.286469       -1.192471              23.826426               4.343578             -13.102570             -22.705950             -24.542798             -19.199858              -6.335627              12.085995              26.793747               27.631057               14.164719  -5.561900   6.168294   -0.177329   5.368146    0.253341        1.067869               2.952709               1.228112               1.203936               0.838892              -0.187301              -1.068701              -1.292931              -1.618419              -3.755128               -3.817113               -1.669153  -2.191973   6.176758    1.633364   5.202874   -0.046526       -1.255640               3.925334               1.310397              -1.800534              -4.030999              -4.532042              -3.184207              -0.507004               2.311134               4.161301
# 2  data/FallDataSet/101/Testler Export/803/Test_2...  False   0.397563  21.265912    9.725431  40.427378    0.169519       -1.343237              28.655823               4.781240             -17.476077             -29.836935             -30.923475             -21.481118              -2.482121              20.181225              34.607734               30.822636               12.001411  -6.915212   6.536865   -0.234838   5.577954    0.066424        1.401981               2.166793              -0.068059               0.735277               0.677589              -0.345715              -0.802104              -0.251115              -1.134686              -4.137664               -3.113853               -0.340973  -2.085876   6.524658    1.793985   6.000285    0.021022       -1.319290               4.411590               1.120413              -2.400525              -4.818507              -5.056611              -3.162510               0.070632               3.210865               4.891293
# 3  data/FallDataSet/101/Testler Export/803/Test_3...  False  -0.485229  21.955872    9.640511  47.161436    0.222504       -1.310149              33.123833               4.217760             -21.421921             -34.226704             -34.970838             -24.548683              -2.511337              24.792808              41.726149               35.490290               11.181147  -5.890512   6.324768   -0.196868   6.166606    0.343380        1.082675               2.739671               0.313216               0.771336               0.868668              -0.381860              -1.065671              -0.536944              -1.492446              -4.661175               -3.327379               -0.659586  -2.237201   6.297493    1.875507   6.009118   -0.127945       -1.321008               4.337453               1.156383              -2.376663              -4.980900              -5.293504              -3.298557               0.104452               3.381181               5.179111
# 4  data/FallDataSet/101/Testler Export/804/Test_1...  False   8.437753   9.976053    9.300462   0.093432   -0.404062        0.428661               0.072309               0.050691               0.035434               0.017760               0.010346               0.012580               0.013402               0.015759               0.014517                0.009059                0.000705  -0.411320   0.428772   -0.039518   0.050725    0.121676       -1.050316               0.037818               0.030645               0.034974               0.032221               0.027917               0.032276               0.033357               0.028403               0.029625                0.028867                0.027556  -5.242157   2.923346   -2.784108   3.479533    1.435584        1.665802               3.270075               3.060340               2.845711               2.626288               2.411007               2.201964               2.003315               1.805250               1.608153
#
#    Acc_Z_autocovar_lag_10  Acc_Z_autocovar_lag_11  Gyr_X_min  Gyr_X_max  Gyr_X_mean  Gyr_X_var  Gyr_X_skew  Gyr_X_kurtosis  Gyr_X_autocovar_lag_1  Gyr_X_autocovar_lag_2  Gyr_X_autocovar_lag_3  Gyr_X_autocovar_lag_4  Gyr_X_autocovar_lag_5  Gyr_X_autocovar_lag_6  Gyr_X_autocovar_lag_7  Gyr_X_autocovar_lag_8  Gyr_X_autocovar_lag_9  Gyr_X_autocovar_lag_10  Gyr_X_autocovar_lag_11  Gyr_Y_min  Gyr_Y_max  Gyr_Y_mean  Gyr_Y_var  Gyr_Y_skew  Gyr_Y_kurtosis  Gyr_Y_autocovar_lag_1  Gyr_Y_autocovar_lag_2  Gyr_Y_autocovar_lag_3  Gyr_Y_autocovar_lag_4  Gyr_Y_autocovar_lag_5  Gyr_Y_autocovar_lag_6  Gyr_Y_autocovar_lag_7  Gyr_Y_autocovar_lag_8  Gyr_Y_autocovar_lag_9  Gyr_Y_autocovar_lag_10  Gyr_Y_autocovar_lag_11  Gyr_Z_min  Gyr_Z_max  Gyr_Z_mean  Gyr_Z_var  Gyr_Z_skew  Gyr_Z_kurtosis  Gyr_Z_autocovar_lag_1  Gyr_Z_autocovar_lag_2  Gyr_Z_autocovar_lag_3  Gyr_Z_autocovar_lag_4  Gyr_Z_autocovar_lag_5  Gyr_Z_autocovar_lag_6  Gyr_Z_autocovar_lag_7  Gyr_Z_autocovar_lag_8  Gyr_Z_autocovar_lag_9  \
# 0               -0.220864               -0.199297  -0.729733   0.768550   -0.025268   0.096762   -0.150801        0.162428               0.080819               0.050844               0.021899              -0.000659              -0.011707              -0.013646              -0.010212              -0.003578               0.001283                0.002531               -0.001399  -0.775762   0.326210    0.022363   0.055121   -1.294349        1.285619               0.047757               0.032257               0.014440              -0.002138              -0.016557              -0.026447              -0.030416              -0.029336              -0.023301               -0.013017                0.000388  -0.451152   0.435264   -0.005884   0.027069   -0.119397        0.957447               0.022928               0.015783               0.010556               0.006781               0.002913              -0.000350              -0.002034              -0.003398              -0.005706
# 1                4.227218                2.397005  -1.921164   1.846363   -0.057747   0.950754    0.013071       -1.003187               0.847611               0.645871               0.420160               0.193430              -0.043727              -0.281444              -0.495294              -0.689067              -0.818059               -0.819282               -0.696202  -0.689136   0.945143   -0.003560   0.178496    0.262737       -0.813415               0.126279               0.034137              -0.058099              -0.120249              -0.132727              -0.096163              -0.020365               0.066172               0.131901                0.129054                0.060830  -1.233404   1.064037   -0.002396   0.330738   -0.112388       -0.968058               0.294639               0.230346               0.155781               0.070813              -0.014087              -0.095424              -0.174793              -0.235907              -0.267818
# 2                4.347333                1.853562  -1.924624   2.055617    0.066446   1.087859   -0.145001       -0.972171               0.957356               0.698429               0.427387               0.184992              -0.057448              -0.317975              -0.574313              -0.812995              -0.945196               -0.908897               -0.729176  -0.692167   0.933286   -0.026665   0.149517    0.447470       -0.689503               0.095353               0.018265              -0.036486              -0.077950              -0.083590              -0.057643              -0.016803               0.034626               0.072663                0.064909                0.021521  -1.314816   1.108291    0.024439   0.343809   -0.403051       -0.741917               0.289905               0.217457               0.146987               0.055277              -0.038962              -0.119788              -0.197195              -0.250508              -0.267854
# 3                4.571986                1.888005  -2.121062   1.924283   -0.085754   1.088749   -0.043902       -0.914780               0.947997               0.678262               0.418042               0.179857              -0.064322              -0.309918              -0.551300              -0.805262              -0.952145               -0.907637               -0.702238  -0.656544   1.119067   -0.008330   0.111802    0.654742        0.478688               0.068233               0.017477              -0.010288              -0.036499              -0.050230              -0.043609              -0.025254               0.006864               0.035645                0.028065               -0.004460  -1.219803   1.267998   -0.029431   0.330170    0.007869       -0.948447               0.287709               0.221563               0.150747               0.055850              -0.041047              -0.118877              -0.190065              -0.244512              -0.262591
# 4                1.425916                1.245272  -0.228883   0.136810   -0.013888   0.006564   -0.722347       -0.193566               0.005677               0.004408               0.003405               0.002362               0.001440               0.000934               0.000507               0.000041               0.000007                0.000281                0.000422  -0.773985   0.378040   -0.205690   0.101950   -0.172342       -1.135720               0.099803               0.096729               0.092917               0.088550               0.084051               0.079623               0.075419               0.071054               0.066466                0.061702                0.056980  -0.081780   0.126411    0.012660   0.002289    0.241269       -0.547826               0.002036               0.001651               0.001317               0.000970               0.000691               0.000580               0.000569               0.000623               0.000726
#
#    Gyr_Z_autocovar_lag_10  Gyr_Z_autocovar_lag_11  Mag_X_min  Mag_X_max  Mag_X_mean  Mag_X_var  Mag_X_skew  Mag_X_kurtosis  Mag_X_autocovar_lag_1  Mag_X_autocovar_lag_2  Mag_X_autocovar_lag_3  Mag_X_autocovar_lag_4  Mag_X_autocovar_lag_5  Mag_X_autocovar_lag_6  Mag_X_autocovar_lag_7  Mag_X_autocovar_lag_8  Mag_X_autocovar_lag_9  Mag_X_autocovar_lag_10  Mag_X_autocovar_lag_11  Mag_Y_min  Mag_Y_max  Mag_Y_mean  Mag_Y_var  Mag_Y_skew  Mag_Y_kurtosis  Mag_Y_autocovar_lag_1  Mag_Y_autocovar_lag_2  Mag_Y_autocovar_lag_3  Mag_Y_autocovar_lag_4  Mag_Y_autocovar_lag_5  Mag_Y_autocovar_lag_6  Mag_Y_autocovar_lag_7  Mag_Y_autocovar_lag_8  Mag_Y_autocovar_lag_9  Mag_Y_autocovar_lag_10  Mag_Y_autocovar_lag_11  Mag_Z_min  Mag_Z_max  Mag_Z_mean  Mag_Z_var  Mag_Z_skew  Mag_Z_kurtosis  Mag_Z_autocovar_lag_1  Mag_Z_autocovar_lag_2  Mag_Z_autocovar_lag_3  Mag_Z_autocovar_lag_4  Mag_Z_autocovar_lag_5  Mag_Z_autocovar_lag_6  Mag_Z_autocovar_lag_7  Mag_Z_autocovar_lag_8  Mag_Z_autocovar_lag_9  \
# 0               -0.007947               -0.009021  -0.775146  -0.618164   -0.683018   0.001454   -0.121862       -0.060797               0.001413               0.001349               0.001264               0.001164               0.001059               0.000952               0.000849               0.000754               0.000674                0.000604                0.000544  -0.607910  -0.523682   -0.565306   0.000378    0.613932       -0.679603               0.000350               0.000308               0.000260               0.000214               0.000171               0.000135               0.000104               0.000068               0.000027               -0.000016               -0.000060  -0.532471  -0.310791   -0.434106   0.004101   -0.031054       -1.052086               0.003972               0.003768               0.003507               0.003209               0.002898               0.002601               0.002342               0.002128               0.001954
# 1               -0.272454               -0.247691  -0.905029  -0.693359   -0.794361   0.002719   -0.167695       -0.635155               0.002572               0.002307               0.001949               0.001545               0.001120               0.000714               0.000357               0.000091              -0.000073               -0.000120               -0.000050   0.344971   0.697510    0.562577   0.009231   -0.533359       -0.569435               0.008900               0.008066               0.006822               0.005307               0.003667               0.002055               0.000618              -0.000511              -0.001228               -0.001478               -0.001255  -0.068115   0.339844    0.165073   0.012605   -0.351763       -0.908481               0.012208               0.011301               0.010057               0.008625               0.007144               0.005732               0.004485               0.003464               0.002726
# 2               -0.258535               -0.222871  -0.923584  -0.681396   -0.804182   0.003292   -0.014337       -0.605762               0.003150               0.002844               0.002429               0.001946               0.001430               0.000937               0.000517               0.000204               0.000015               -0.000044                0.000029   0.371826   0.666504    0.559326   0.005686   -0.536706       -0.479134               0.005291               0.004504               0.003400               0.002108               0.000776              -0.000462              -0.001460              -0.002096              -0.002306               -0.002099               -0.001535  -0.057373   0.346924    0.128150   0.012469    0.021336       -1.022253               0.011875               0.010878               0.009689               0.008370               0.006967               0.005678               0.004661               0.003975               0.003636
# 3               -0.255474               -0.218805  -0.877686  -0.650391   -0.777172   0.002486   -0.094192       -0.427093               0.002308               0.002012               0.001626               0.001190               0.000738               0.000334               0.000004              -0.000236              -0.000361               -0.000357               -0.000226   0.353271   0.676758    0.553928   0.006754   -0.546487       -0.386242               0.006496               0.005825               0.004823               0.003601               0.002292               0.001031              -0.000049              -0.000849              -0.001292               -0.001354               -0.001044  -0.077148   0.309326    0.117659   0.010056    0.011291       -0.859877               0.009748               0.009046               0.008086               0.006967               0.005793               0.004640               0.003593               0.002733               0.002176
# 4                0.000816                0.000833  -1.042480  -0.642578   -0.955450   0.007354    2.043311        4.119613               0.006813               0.006263               0.005705               0.005147               0.004598               0.004061               0.003542               0.003041               0.002560                0.002112                0.001691   0.129883   0.234131    0.186190   0.001029   -0.271615       -1.267864               0.001023               0.001014               0.001000               0.000983               0.000962               0.000939               0.000913               0.000885               0.000856                0.000825                0.000792  -0.917725  -0.187744   -0.412032   0.029454   -1.440117        1.511414               0.027835               0.026190               0.024481               0.022755               0.021013               0.019238               0.017458               0.015693               0.013964
#
#    Mag_Z_autocovar_lag_10  Mag_Z_autocovar_lag_11
# 0                0.001821                0.001719
# 1                0.002307                0.002243
# 2                0.003671                0.004008
# 3                0.001995                0.002166
# 4                0.012236                0.010556

# %%
n_records = len(data)

n_fall = len(data[data['fall'] == True])
n_adl = len(data[data['fall'] == False])

def fall_percent(y):
    return (len(y[y == True]) / len(y)) * 100    

# Print the results
print("Total number of records: {}".format(n_records))
print("Number of falls: {}".format(n_fall))
print("Number of Activities of Daily Life: {}".format(n_adl))
print("Percentage of falls: {:.2f}%".format(fall_percent(data['fall'])))
print("Percentage of Activities of Daily Life: {:.2f}%".format(100 - fall_percent(data['fall'])))
# Out:
# Total number of records: 1570
# Number of falls: 910
# Number of Activities of Daily Life: 660
# Percentage of falls: 57.96%
# Percentage of Activities of Daily Life: 42.04%

# %%
y_feature = data['fall']
X_feature = data.drop(columns=['fall', 'sensorFile'])
X_feature.head()
# Out:
#    Acc_X_min  Acc_X_max  Acc_X_mean  Acc_X_var  Acc_X_skew  Acc_X_kurtosis  Acc_X_autocovar_lag_1  Acc_X_autocovar_lag_2  Acc_X_autocovar_lag_3  Acc_X_autocovar_lag_4  Acc_X_autocovar_lag_5  Acc_X_autocovar_lag_6  Acc_X_autocovar_lag_7  Acc_X_autocovar_lag_8  Acc_X_autocovar_lag_9  Acc_X_autocovar_lag_10  Acc_X_autocovar_lag_11  Acc_Y_min  Acc_Y_max  Acc_Y_mean  Acc_Y_var  Acc_Y_skew  Acc_Y_kurtosis  Acc_Y_autocovar_lag_1  Acc_Y_autocovar_lag_2  Acc_Y_autocovar_lag_3  Acc_Y_autocovar_lag_4  Acc_Y_autocovar_lag_5  Acc_Y_autocovar_lag_6  Acc_Y_autocovar_lag_7  Acc_Y_autocovar_lag_8  Acc_Y_autocovar_lag_9  Acc_Y_autocovar_lag_10  Acc_Y_autocovar_lag_11  Acc_Z_min  Acc_Z_max  Acc_Z_mean  Acc_Z_var  Acc_Z_skew  Acc_Z_kurtosis  Acc_Z_autocovar_lag_1  Acc_Z_autocovar_lag_2  Acc_Z_autocovar_lag_3  Acc_Z_autocovar_lag_4  Acc_Z_autocovar_lag_5  Acc_Z_autocovar_lag_6  Acc_Z_autocovar_lag_7  Acc_Z_autocovar_lag_8  Acc_Z_autocovar_lag_9  Acc_Z_autocovar_lag_10  Acc_Z_autocovar_lag_11  Gyr_X_min  \
# 0   4.597473  16.176939    9.371301   2.628580    0.911441        3.541434               1.678807               0.151347              -0.739682              -0.957049              -0.825571              -0.361732              -0.021460              -0.094988              -0.376303               -0.570615               -0.613772  -3.427529   2.119994   -0.398477   1.197303   -0.501028        0.529118               0.878305               0.416364               0.126367              -0.030061              -0.056597               0.054419               0.089898               0.003392              -0.015369                0.069596                0.051978   0.998425   6.542873    3.035454   1.145468    0.374688        0.594420               0.959414               0.663527               0.366912               0.115107               0.007818              -0.018418              -0.028478              -0.076136              -0.160418               -0.220864               -0.199297  -0.729733
# 1   0.927734  21.058655    9.801436  33.440234    0.286469       -1.192471              23.826426               4.343578             -13.102570             -22.705950             -24.542798             -19.199858              -6.335627              12.085995              26.793747               27.631057               14.164719  -5.561900   6.168294   -0.177329   5.368146    0.253341        1.067869               2.952709               1.228112               1.203936               0.838892              -0.187301              -1.068701              -1.292931              -1.618419              -3.755128               -3.817113               -1.669153  -2.191973   6.176758    1.633364   5.202874   -0.046526       -1.255640               3.925334               1.310397              -1.800534              -4.030999              -4.532042              -3.184207              -0.507004               2.311134               4.161301                4.227218                2.397005  -1.921164
# 2   0.397563  21.265912    9.725431  40.427378    0.169519       -1.343237              28.655823               4.781240             -17.476077             -29.836935             -30.923475             -21.481118              -2.482121              20.181225              34.607734               30.822636               12.001411  -6.915212   6.536865   -0.234838   5.577954    0.066424        1.401981               2.166793              -0.068059               0.735277               0.677589              -0.345715              -0.802104              -0.251115              -1.134686              -4.137664               -3.113853               -0.340973  -2.085876   6.524658    1.793985   6.000285    0.021022       -1.319290               4.411590               1.120413              -2.400525              -4.818507              -5.056611              -3.162510               0.070632               3.210865               4.891293                4.347333                1.853562  -1.924624
# 3  -0.485229  21.955872    9.640511  47.161436    0.222504       -1.310149              33.123833               4.217760             -21.421921             -34.226704             -34.970838             -24.548683              -2.511337              24.792808              41.726149               35.490290               11.181147  -5.890512   6.324768   -0.196868   6.166606    0.343380        1.082675               2.739671               0.313216               0.771336               0.868668              -0.381860              -1.065671              -0.536944              -1.492446              -4.661175               -3.327379               -0.659586  -2.237201   6.297493    1.875507   6.009118   -0.127945       -1.321008               4.337453               1.156383              -2.376663              -4.980900              -5.293504              -3.298557               0.104452               3.381181               5.179111                4.571986                1.888005  -2.121062
# 4   8.437753   9.976053    9.300462   0.093432   -0.404062        0.428661               0.072309               0.050691               0.035434               0.017760               0.010346               0.012580               0.013402               0.015759               0.014517                0.009059                0.000705  -0.411320   0.428772   -0.039518   0.050725    0.121676       -1.050316               0.037818               0.030645               0.034974               0.032221               0.027917               0.032276               0.033357               0.028403               0.029625                0.028867                0.027556  -5.242157   2.923346   -2.784108   3.479533    1.435584        1.665802               3.270075               3.060340               2.845711               2.626288               2.411007               2.201964               2.003315               1.805250               1.608153                1.425916                1.245272  -0.228883
#
#    Gyr_X_max  Gyr_X_mean  Gyr_X_var  Gyr_X_skew  Gyr_X_kurtosis  Gyr_X_autocovar_lag_1  Gyr_X_autocovar_lag_2  Gyr_X_autocovar_lag_3  Gyr_X_autocovar_lag_4  Gyr_X_autocovar_lag_5  Gyr_X_autocovar_lag_6  Gyr_X_autocovar_lag_7  Gyr_X_autocovar_lag_8  Gyr_X_autocovar_lag_9  Gyr_X_autocovar_lag_10  Gyr_X_autocovar_lag_11  Gyr_Y_min  Gyr_Y_max  Gyr_Y_mean  Gyr_Y_var  Gyr_Y_skew  Gyr_Y_kurtosis  Gyr_Y_autocovar_lag_1  Gyr_Y_autocovar_lag_2  Gyr_Y_autocovar_lag_3  Gyr_Y_autocovar_lag_4  Gyr_Y_autocovar_lag_5  Gyr_Y_autocovar_lag_6  Gyr_Y_autocovar_lag_7  Gyr_Y_autocovar_lag_8  Gyr_Y_autocovar_lag_9  Gyr_Y_autocovar_lag_10  Gyr_Y_autocovar_lag_11  Gyr_Z_min  Gyr_Z_max  Gyr_Z_mean  Gyr_Z_var  Gyr_Z_skew  Gyr_Z_kurtosis  Gyr_Z_autocovar_lag_1  Gyr_Z_autocovar_lag_2  Gyr_Z_autocovar_lag_3  Gyr_Z_autocovar_lag_4  Gyr_Z_autocovar_lag_5  Gyr_Z_autocovar_lag_6  Gyr_Z_autocovar_lag_7  Gyr_Z_autocovar_lag_8  Gyr_Z_autocovar_lag_9  Gyr_Z_autocovar_lag_10  Gyr_Z_autocovar_lag_11  Mag_X_min  Mag_X_max  \
# 0   0.768550   -0.025268   0.096762   -0.150801        0.162428               0.080819               0.050844               0.021899              -0.000659              -0.011707              -0.013646              -0.010212              -0.003578               0.001283                0.002531               -0.001399  -0.775762   0.326210    0.022363   0.055121   -1.294349        1.285619               0.047757               0.032257               0.014440              -0.002138              -0.016557              -0.026447              -0.030416              -0.029336              -0.023301               -0.013017                0.000388  -0.451152   0.435264   -0.005884   0.027069   -0.119397        0.957447               0.022928               0.015783               0.010556               0.006781               0.002913              -0.000350              -0.002034              -0.003398              -0.005706               -0.007947               -0.009021  -0.775146  -0.618164
# 1   1.846363   -0.057747   0.950754    0.013071       -1.003187               0.847611               0.645871               0.420160               0.193430              -0.043727              -0.281444              -0.495294              -0.689067              -0.818059               -0.819282               -0.696202  -0.689136   0.945143   -0.003560   0.178496    0.262737       -0.813415               0.126279               0.034137              -0.058099              -0.120249              -0.132727              -0.096163              -0.020365               0.066172               0.131901                0.129054                0.060830  -1.233404   1.064037   -0.002396   0.330738   -0.112388       -0.968058               0.294639               0.230346               0.155781               0.070813              -0.014087              -0.095424              -0.174793              -0.235907              -0.267818               -0.272454               -0.247691  -0.905029  -0.693359
# 2   2.055617    0.066446   1.087859   -0.145001       -0.972171               0.957356               0.698429               0.427387               0.184992              -0.057448              -0.317975              -0.574313              -0.812995              -0.945196               -0.908897               -0.729176  -0.692167   0.933286   -0.026665   0.149517    0.447470       -0.689503               0.095353               0.018265              -0.036486              -0.077950              -0.083590              -0.057643              -0.016803               0.034626               0.072663                0.064909                0.021521  -1.314816   1.108291    0.024439   0.343809   -0.403051       -0.741917               0.289905               0.217457               0.146987               0.055277              -0.038962              -0.119788              -0.197195              -0.250508              -0.267854               -0.258535               -0.222871  -0.923584  -0.681396
# 3   1.924283   -0.085754   1.088749   -0.043902       -0.914780               0.947997               0.678262               0.418042               0.179857              -0.064322              -0.309918              -0.551300              -0.805262              -0.952145               -0.907637               -0.702238  -0.656544   1.119067   -0.008330   0.111802    0.654742        0.478688               0.068233               0.017477              -0.010288              -0.036499              -0.050230              -0.043609              -0.025254               0.006864               0.035645                0.028065               -0.004460  -1.219803   1.267998   -0.029431   0.330170    0.007869       -0.948447               0.287709               0.221563               0.150747               0.055850              -0.041047              -0.118877              -0.190065              -0.244512              -0.262591               -0.255474               -0.218805  -0.877686  -0.650391
# 4   0.136810   -0.013888   0.006564   -0.722347       -0.193566               0.005677               0.004408               0.003405               0.002362               0.001440               0.000934               0.000507               0.000041               0.000007                0.000281                0.000422  -0.773985   0.378040   -0.205690   0.101950   -0.172342       -1.135720               0.099803               0.096729               0.092917               0.088550               0.084051               0.079623               0.075419               0.071054               0.066466                0.061702                0.056980  -0.081780   0.126411    0.012660   0.002289    0.241269       -0.547826               0.002036               0.001651               0.001317               0.000970               0.000691               0.000580               0.000569               0.000623               0.000726                0.000816                0.000833  -1.042480  -0.642578
#
#    Mag_X_mean  Mag_X_var  Mag_X_skew  Mag_X_kurtosis  Mag_X_autocovar_lag_1  Mag_X_autocovar_lag_2  Mag_X_autocovar_lag_3  Mag_X_autocovar_lag_4  Mag_X_autocovar_lag_5  Mag_X_autocovar_lag_6  Mag_X_autocovar_lag_7  Mag_X_autocovar_lag_8  Mag_X_autocovar_lag_9  Mag_X_autocovar_lag_10  Mag_X_autocovar_lag_11  Mag_Y_min  Mag_Y_max  Mag_Y_mean  Mag_Y_var  Mag_Y_skew  Mag_Y_kurtosis  Mag_Y_autocovar_lag_1  Mag_Y_autocovar_lag_2  Mag_Y_autocovar_lag_3  Mag_Y_autocovar_lag_4  Mag_Y_autocovar_lag_5  Mag_Y_autocovar_lag_6  Mag_Y_autocovar_lag_7  Mag_Y_autocovar_lag_8  Mag_Y_autocovar_lag_9  Mag_Y_autocovar_lag_10  Mag_Y_autocovar_lag_11  Mag_Z_min  Mag_Z_max  Mag_Z_mean  Mag_Z_var  Mag_Z_skew  Mag_Z_kurtosis  Mag_Z_autocovar_lag_1  Mag_Z_autocovar_lag_2  Mag_Z_autocovar_lag_3  Mag_Z_autocovar_lag_4  Mag_Z_autocovar_lag_5  Mag_Z_autocovar_lag_6  Mag_Z_autocovar_lag_7  Mag_Z_autocovar_lag_8  Mag_Z_autocovar_lag_9  Mag_Z_autocovar_lag_10  Mag_Z_autocovar_lag_11
# 0   -0.683018   0.001454   -0.121862       -0.060797               0.001413               0.001349               0.001264               0.001164               0.001059               0.000952               0.000849               0.000754               0.000674                0.000604                0.000544  -0.607910  -0.523682   -0.565306   0.000378    0.613932       -0.679603               0.000350               0.000308               0.000260               0.000214               0.000171               0.000135               0.000104               0.000068               0.000027               -0.000016               -0.000060  -0.532471  -0.310791   -0.434106   0.004101   -0.031054       -1.052086               0.003972               0.003768               0.003507               0.003209               0.002898               0.002601               0.002342               0.002128               0.001954                0.001821                0.001719
# 1   -0.794361   0.002719   -0.167695       -0.635155               0.002572               0.002307               0.001949               0.001545               0.001120               0.000714               0.000357               0.000091              -0.000073               -0.000120               -0.000050   0.344971   0.697510    0.562577   0.009231   -0.533359       -0.569435               0.008900               0.008066               0.006822               0.005307               0.003667               0.002055               0.000618              -0.000511              -0.001228               -0.001478               -0.001255  -0.068115   0.339844    0.165073   0.012605   -0.351763       -0.908481               0.012208               0.011301               0.010057               0.008625               0.007144               0.005732               0.004485               0.003464               0.002726                0.002307                0.002243
# 2   -0.804182   0.003292   -0.014337       -0.605762               0.003150               0.002844               0.002429               0.001946               0.001430               0.000937               0.000517               0.000204               0.000015               -0.000044                0.000029   0.371826   0.666504    0.559326   0.005686   -0.536706       -0.479134               0.005291               0.004504               0.003400               0.002108               0.000776              -0.000462              -0.001460              -0.002096              -0.002306               -0.002099               -0.001535  -0.057373   0.346924    0.128150   0.012469    0.021336       -1.022253               0.011875               0.010878               0.009689               0.008370               0.006967               0.005678               0.004661               0.003975               0.003636                0.003671                0.004008
# 3   -0.777172   0.002486   -0.094192       -0.427093               0.002308               0.002012               0.001626               0.001190               0.000738               0.000334               0.000004              -0.000236              -0.000361               -0.000357               -0.000226   0.353271   0.676758    0.553928   0.006754   -0.546487       -0.386242               0.006496               0.005825               0.004823               0.003601               0.002292               0.001031              -0.000049              -0.000849              -0.001292               -0.001354               -0.001044  -0.077148   0.309326    0.117659   0.010056    0.011291       -0.859877               0.009748               0.009046               0.008086               0.006967               0.005793               0.004640               0.003593               0.002733               0.002176                0.001995                0.002166
# 4   -0.955450   0.007354    2.043311        4.119613               0.006813               0.006263               0.005705               0.005147               0.004598               0.004061               0.003542               0.003041               0.002560                0.002112                0.001691   0.129883   0.234131    0.186190   0.001029   -0.271615       -1.267864               0.001023               0.001014               0.001000               0.000983               0.000962               0.000939               0.000913               0.000885               0.000856                0.000825                0.000792  -0.917725  -0.187744   -0.412032   0.029454   -1.440117        1.511414               0.027835               0.026190               0.024481               0.022755               0.021013               0.019238               0.017458               0.015693               0.013964                0.012236                0.010556

# %%
#information of the data set
from sklearn.model_selection import train_test_split

X_feature_train, X_feature_test, y_feature_train, y_feature_test = train_test_split(X_feature,y_feature,test_size=0.2,random_state=0)

# Show the results of the split
print("Training set has {} samples.".format(X_feature_train.shape[0]))
print("Testing set has {} samples.".format(X_feature_test.shape[0]))
    
print("Percentage of train falls: {:.2f}%".format(fall_percent(y_feature_train)))
print("Percentage of test falls: {:.2f}%".format(fall_percent(y_feature_test)))
# Out:
# Training set has 1256 samples.
# Testing set has 314 samples.
# Percentage of train falls: 58.92%
# Percentage of test falls: 54.14%

# %% [markdown]
# ### always fall classifier, always adl classifier and random classifier

# %%
always_fall_prediction = np.array([True]*len(X_feature_test))
always_adl_prediction = np.array([False]*len(X_feature_test))

# %%
from sklearn.metrics import accuracy_score

random_prediction = np.random.choice([True, False], len(X_feature_test))

print("accuracy_score(always_fall_prediction): {0:.0f}%".format(accuracy_score(y_feature_test, always_fall_prediction) * 100))
print("accuracy_score(always_adl_prediction): {0:.0f}%".format(accuracy_score(y_feature_test, always_adl_prediction) * 100))
print("accuracy_score(random_prediction): {0:.0f}%".format(accuracy_score(y_feature_test, random_prediction) * 100))
# Out:
# accuracy_score(always_fall_prediction): 54%
# accuracy_score(always_adl_prediction): 46%
# accuracy_score(random_prediction): 47%

# %% [markdown]
# ### GaussianNB

# %%
from sklearn.decomposition import PCA  #PCA = Principal componebt analysis

pca = PCA(n_components=1).fit(X_feature_train)

# %%
print("{0:.0f}% variance in the data is explained by the first principal component.".format(pca.explained_variance_ratio_[0] * 100))
# Out:
# 99% variance in the data is explained by the first principal component.

# %%
#import visuals as vs
#pca_results = vs.pca_results(X_feature_train, pca)

# %%
X_feature_train_Acc_Z_var = X_feature_train[['Acc_Z_var']]
X_feature_test_Acc_Z_var = X_feature_test[['Acc_Z_var']]

# %%
from sklearn.naive_bayes import GaussianNB

benchmark_clf = GaussianNB().fit(X_feature_train_Acc_Z_var, y_feature_train)
benchmark_score = accuracy_score(y_feature_test, benchmark_clf.predict(X_feature_test_Acc_Z_var))
print("{0:.0f}%".format(benchmark_score * 100))
# Out:
# 68%

# %% [markdown]
# So the benchmark is a GaussianNB classifier yielding an accuracy of about the above obtained results...%.

# %% [markdown]
# ## Data Preprocessing
# ### Standard Machine Learning Classifiers

# %% [markdown]
# ### LSTM Recurrent Neural Networks

# %%
from falldetection.time_series_extractor_workflow import extract_time_series
from falldetection.sensor import Sensor

X_raw, y_raw = extract_time_series(
    sensor=Sensor.RIGHT_THIGH,
    baseDir=baseDir,
    columns=['Acc_X', 'Acc_Y', 'Acc_Z', 'Gyr_X', 'Gyr_Y', 'Gyr_Z', 'Mag_X', 'Mag_Y', 'Mag_Z'])

# %% [markdown]
# ## Implementation
# ### Standard Machine Learning Classifiers

# %%
import pandas as pd
import visuals as vs
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

def train_predict_multiple(classifiers, X_train, y_train, X_test, y_test, scorer):
    def train_predict(classifier):
        classifier = classifier.fit(X_train, y_train)
        return scorer(y_test, classifier.predict(X_test))

    results = {'Classifier': list(classifiers.keys()),
               'Score': list(map(train_predict, classifiers.values()))}
    return pd.DataFrame(results).sort_values(by='Score', ascending=True)

def plot_training_results(df):
    ax = df.plot.bar(x='Classifier', y='Score', color=['C2', 'C4', 'C6', 'C8'], legend=False, rot=0)
    ax.set_xlabel('Classifier',fontsize = 15, fontweight='bold')
    ax.set_ylabel('Score',fontsize = 15, fontweight='bold')
    #ax.axhline(y=benchmark_score,xmin=-0.1,xmax=5.0,linewidth=2,color='r',linestyle='dashed')


classifiers = {'SVC': SVC(random_state=0),
               'DecisionTree': DecisionTreeClassifier(random_state=0),
               'Random Forest': RandomForestClassifier(random_state=0),
               'K Neighbors': KNeighborsClassifier(n_neighbors=3)}

df = train_predict_multiple(classifiers,X_feature_train,y_feature_train,X_feature_test,y_feature_test,scorer=accuracy_score)

plot_training_results(df)
plt.savefig('images/scoresByClassifier.pdf')
display(df)
# Out:
#       Classifier     Score
# 0            SVC  0.949045
# 1   DecisionTree  0.987261
# 2  Random Forest  1.000000
# 3    K Neighbors  1.000000

# %% [markdown]
# ### LSTM Recurrent Neural Networks

# %%
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.preprocessing import sequence
from keras.layers.convolutional import Conv1D
from keras.layers import ConvLSTM1D
from keras.layers import Flatten
from keras.layers.convolutional import MaxPooling1D
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.layers import TimeDistributed
from keras.layers import Dropout
from numpy import array
# Importing libraries
import numpy as np
import pandas as pd
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
#from keras.utils import to_categorical
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers.core import Dense, Dropout
# Out:
# 2022-05-11 22:21:50.457080: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/shailendra/rsoftware/root/lib/:/home/shailendra/rsoftware/root/lib:/home/shailendra/CLHEP/2.4.1.0-install/lib/:/home/shailendra/geant4/geant4.10.05.p01-build/BuildProducts/lib:/home/shailendra/geant4/geant4.10.05.p01-install/lib:/usr/lib/x86_64-linux-gnu/usr/lib:/usr/local/lib:/Applications/autotools/lib:/home/shailendra/CLHEP/2.4.1.0-install/lib:/home/shailendra/geant4/geant4.10.05.p01-install/lib:/home/shailendra/rsoftware/root/lib:/usr/local/lib:/usr/lib:/home/shailendra/anaroot/lib:/home/shailendra/geant4/geant4.10.05.p01-install/lib
# 2022-05-11 22:21:50.457171: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
from sklearn.model_selection import train_test_split

X_raw_train, X_raw_test, y_raw_train, y_raw_test = train_test_split(X_raw, y_raw, test_size=0.2, random_state=42)
X_raw_train, X_raw_test, X_val, Y_val = train_test_split(X_raw, y_raw, test_size=0.2, random_state=42)

# Initializing parameters
epochs = 100
batch_size = 64
n_hidden = 32
# Utility function to count the number of classes
def _count_classes(y):
    return len(set([tuple(category) for category in y]))
timesteps = len(X_raw_train[0])
input_dim = len(X_raw_train[0][0])
n_classes = _count_classes(y_raw_train)
n_classes  = 1
print(timesteps)
print(input_dim)
print(len(X_raw_train))
# Out:
# 101
# 9
# 1256

# %% [markdown]
# # Base Model

# %%
# Initiliazing the sequential model
model = Sequential()
model.add(LSTM(n_hidden, input_shape=(timesteps, input_dim)))
model.add(Dropout(0.5))
model.add(Dense(n_classes, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# 2022-05-11 22:21:55.803510: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/shailendra/rsoftware/root/lib/:/home/shailendra/rsoftware/root/lib:/home/shailendra/CLHEP/2.4.1.0-install/lib/:/home/shailendra/geant4/geant4.10.05.p01-build/BuildProducts/lib:/home/shailendra/geant4/geant4.10.05.p01-install/lib:/usr/lib/x86_64-linux-gnu/usr/lib:/usr/local/lib:/Applications/autotools/lib:/home/shailendra/CLHEP/2.4.1.0-install/lib:/home/shailendra/geant4/geant4.10.05.p01-install/lib:/home/shailendra/rsoftware/root/lib:/usr/local/lib:/usr/lib:/home/shailendra/anaroot/lib:/home/shailendra/geant4/geant4.10.05.p01-install/lib
# 2022-05-11 22:21:55.803546: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-05-11 22:21:55.803568: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (shailendra-Inspiron-7570): /proc/driver/nvidia/version does not exist
# 2022-05-11 22:21:55.804383: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 32)                5376
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 5,409
# Trainable params: 5,409
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model, show_shapes=True,to_file="images/basemodel.pdf", dpi=120)

# %%
# Training the model
hist = model.fit(X_raw_train,
          y_raw_train,
          batch_size=batch_size,
          validation_data=(X_raw_test, y_raw_test),
          epochs=epochs)

#hist = model.fit(X_raw_train,y_raw_train,batch_size=128,epochs=40,validation_data=(X_raw_test, y_raw_test))
# Out:
# Epoch 1/100
# 20/20 [==============================] - 3s 58ms/step - loss: 0.6813 - accuracy: 0.5916 - val_loss: 0.5603 - val_accuracy: 0.8057
# Epoch 2/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.5452 - accuracy: 0.7492 - val_loss: 0.4814 - val_accuracy: 0.8280
# Epoch 3/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.4859 - accuracy: 0.8002 - val_loss: 0.4385 - val_accuracy: 0.8344
# Epoch 4/100
# 20/20 [==============================] - 1s 39ms/step - loss: 0.4503 - accuracy: 0.8225 - val_loss: 0.4056 - val_accuracy: 0.8503
# Epoch 5/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.4296 - accuracy: 0.8336 - val_loss: 0.3807 - val_accuracy: 0.8599
# Epoch 6/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.4108 - accuracy: 0.8408 - val_loss: 0.3532 - val_accuracy: 0.8631
# Epoch 7/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.3841 - accuracy: 0.8559 - val_loss: 0.3332 - val_accuracy: 0.8726
# Epoch 8/100
# 20/20 [==============================] - 1s 40ms/step - loss: 0.3387 - accuracy: 0.8654 - val_loss: 0.2958 - val_accuracy: 0.8822
# Epoch 9/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.3033 - accuracy: 0.8854 - val_loss: 0.2514 - val_accuracy: 0.9076
# Epoch 10/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.2672 - accuracy: 0.8973 - val_loss: 0.2426 - val_accuracy: 0.9013
# Epoch 11/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.2284 - accuracy: 0.9092 - val_loss: 0.2101 - val_accuracy: 0.9172
# Epoch 12/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.2009 - accuracy: 0.9244 - val_loss: 0.1703 - val_accuracy: 0.9427
# Epoch 13/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1719 - accuracy: 0.9411 - val_loss: 0.1987 - val_accuracy: 0.9395
# Epoch 14/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.2093 - accuracy: 0.9331 - val_loss: 0.1723 - val_accuracy: 0.9299
# Epoch 15/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.1743 - accuracy: 0.9443 - val_loss: 0.1487 - val_accuracy: 0.9490
# Epoch 16/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.1422 - accuracy: 0.9610 - val_loss: 0.1178 - val_accuracy: 0.9650
# Epoch 17/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1648 - accuracy: 0.9427 - val_loss: 0.1456 - val_accuracy: 0.9299
# Epoch 18/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1868 - accuracy: 0.9355 - val_loss: 0.1404 - val_accuracy: 0.9554
# Epoch 19/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1343 - accuracy: 0.9610 - val_loss: 0.0928 - val_accuracy: 0.9745
# Epoch 20/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.1067 - accuracy: 0.9697 - val_loss: 0.0780 - val_accuracy: 0.9809
# Epoch 21/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0942 - accuracy: 0.9705 - val_loss: 0.0809 - val_accuracy: 0.9745
# Epoch 22/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0863 - accuracy: 0.9721 - val_loss: 0.0648 - val_accuracy: 0.9841
# Epoch 23/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0816 - accuracy: 0.9777 - val_loss: 0.0584 - val_accuracy: 0.9841
# Epoch 24/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0662 - accuracy: 0.9825 - val_loss: 0.0692 - val_accuracy: 0.9809
# Epoch 25/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0699 - accuracy: 0.9841 - val_loss: 0.0500 - val_accuracy: 0.9841
# Epoch 26/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0705 - accuracy: 0.9825 - val_loss: 0.0424 - val_accuracy: 0.9904
# Epoch 27/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0621 - accuracy: 0.9801 - val_loss: 0.0416 - val_accuracy: 0.9904
# Epoch 28/100
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0717 - accuracy: 0.9785 - val_loss: 0.0743 - val_accuracy: 0.9745
# Epoch 29/100
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0462 - accuracy: 0.9873 - val_loss: 0.0363 - val_accuracy: 0.9904
# Epoch 30/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0392 - accuracy: 0.9936 - val_loss: 0.0316 - val_accuracy: 0.9904
# Epoch 31/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0587 - accuracy: 0.9849 - val_loss: 0.0774 - val_accuracy: 0.9713
# Epoch 32/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0538 - accuracy: 0.9873 - val_loss: 0.0695 - val_accuracy: 0.9809
# Epoch 33/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0750 - accuracy: 0.9785 - val_loss: 0.0790 - val_accuracy: 0.9745
# Epoch 34/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0498 - accuracy: 0.9881 - val_loss: 0.0583 - val_accuracy: 0.9841
# Epoch 35/100
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0376 - accuracy: 0.9920 - val_loss: 0.0572 - val_accuracy: 0.9809
# Epoch 36/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0444 - accuracy: 0.9896 - val_loss: 0.0603 - val_accuracy: 0.9745
# Epoch 37/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0486 - accuracy: 0.9896 - val_loss: 0.0428 - val_accuracy: 0.9873
# Epoch 38/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0299 - accuracy: 0.9952 - val_loss: 0.0295 - val_accuracy: 0.9873
# Epoch 39/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0343 - accuracy: 0.9920 - val_loss: 0.0273 - val_accuracy: 0.9936
# Epoch 40/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0307 - accuracy: 0.9928 - val_loss: 0.0266 - val_accuracy: 0.9904
# Epoch 41/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0240 - accuracy: 0.9936 - val_loss: 0.0483 - val_accuracy: 0.9873
# Epoch 42/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0218 - accuracy: 0.9960 - val_loss: 0.0531 - val_accuracy: 0.9873
# Epoch 43/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0192 - accuracy: 0.9976 - val_loss: 0.0307 - val_accuracy: 0.9904
# Epoch 44/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0138 - accuracy: 0.9992 - val_loss: 0.0237 - val_accuracy: 0.9936
# Epoch 45/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0335 - accuracy: 0.9920 - val_loss: 0.0123 - val_accuracy: 1.0000
# Epoch 46/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0177 - accuracy: 0.9984 - val_loss: 0.0207 - val_accuracy: 0.9936
# Epoch 47/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0497 - accuracy: 0.9833 - val_loss: 0.1371 - val_accuracy: 0.9490
# Epoch 48/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0982 - accuracy: 0.9745 - val_loss: 0.0652 - val_accuracy: 0.9713
# Epoch 49/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0550 - accuracy: 0.9865 - val_loss: 0.0287 - val_accuracy: 0.9968
# Epoch 50/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0323 - accuracy: 0.9928 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 51/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0229 - accuracy: 0.9952 - val_loss: 0.0114 - val_accuracy: 0.9968
# Epoch 52/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0199 - accuracy: 0.9960 - val_loss: 0.0581 - val_accuracy: 0.9841
# Epoch 53/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0381 - accuracy: 0.9904 - val_loss: 0.0143 - val_accuracy: 0.9968
# Epoch 54/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0256 - accuracy: 0.9944 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 55/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0130 - accuracy: 0.9992 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 56/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0121 - accuracy: 0.9992 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 57/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 58/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 59/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0068 - accuracy: 0.9992 - val_loss: 0.0098 - val_accuracy: 0.9936
# Epoch 60/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0105 - accuracy: 0.9984 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 61/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0071 - accuracy: 0.9992 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 62/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0083 - accuracy: 0.9984 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 63/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0074 - accuracy: 0.9992 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 64/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 65/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 66/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 67/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 68/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 69/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 70/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0055 - accuracy: 0.9992 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 71/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 72/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 73/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 74/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 75/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0081 - accuracy: 0.9984 - val_loss: 0.0752 - val_accuracy: 0.9841
# Epoch 76/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.1007 - accuracy: 0.9697 - val_loss: 0.0610 - val_accuracy: 0.9745
# Epoch 77/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0517 - accuracy: 0.9865 - val_loss: 0.0153 - val_accuracy: 0.9968
# Epoch 78/100
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0161 - accuracy: 0.9968 - val_loss: 0.0102 - val_accuracy: 0.9968
# Epoch 79/100
# 20/20 [==============================] - 1s 43ms/step - loss: 0.0116 - accuracy: 0.9976 - val_loss: 0.0263 - val_accuracy: 0.9904
# Epoch 80/100
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0079 - accuracy: 0.9976 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 81/100
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 82/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 83/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 84/100
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 85/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0046 - accuracy: 0.9992 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 86/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 87/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 88/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 0.9968
# Epoch 89/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0052 - accuracy: 0.9992 - val_loss: 0.0250 - val_accuracy: 0.9936
# Epoch 90/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0475 - val_accuracy: 0.9904
# Epoch 91/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0524 - val_accuracy: 0.9904
# Epoch 92/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 0.9968
# Epoch 93/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 94/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 0.9968
# Epoch 95/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.0125 - val_accuracy: 0.9968
# Epoch 96/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 0.9968
# Epoch 97/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 98/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0040 - accuracy: 0.9992 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 99/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0125 - val_accuracy: 0.9968
# Epoch 100/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 0.9968

# %%
# summarize history for accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy',fontsize=15, fontweight = 'bold')
plt.xlabel('epoch',fontsize=15, fontweight = 'bold')
plt.legend(['training accuracy', 'testing accuracy'], loc='center right')
plt.savefig('images/accuracybasemodel.pdf', dpi=200)
plt.show()
# summarize history for loss
def plot_curves(hist):
  loss = hist.history['loss']
  val_loss = hist.history['val_loss']
  epochs = range(1, len(loss) + 1)


  plt.figure()
  plt.plot(epochs, loss, 'g', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title('Training and validation loss')
  plt.xlabel('Epoch',fontsize=15, fontweight = 'bold')
  plt.ylabel('Loss',fontsize=15, fontweight = 'bold')
  plt.legend(loc='upper right')
  plt.savefig('images/modelTVloss_model1.pdf', dpi=200) 
  plt.show()

plot_curves(hist)

# %% [markdown]
# # MultiLayer LSTM

# %%
from sklearn import linear_model
from sklearn import metrics
from sklearn.svm import LinearSVC
from sklearn.model_selection import GridSearchCV

# %%
# Initiliazing the sequential model
model1 = Sequential()
model1.add(LSTM(100,return_sequences=True,input_shape=(timesteps, input_dim)))
model1.add(Dropout(0.5))
model1.add(LSTM(100,input_shape=(timesteps, input_dim)))
model1.add(Dropout(0.6))
model1.add(Dense(n_classes, activation='sigmoid'))  #why sigmoid?? it is not a multiclass dataset
model1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])##why not categorical??? 
model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 101, 100)          44000
#
#  dropout_1 (Dropout)         (None, 101, 100)          0
#
#  lstm_2 (LSTM)               (None, 100)               80400
#
#  dropout_2 (Dropout)         (None, 100)               0
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 124,501
# Trainable params: 124,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model1, show_shapes=True,to_file="images/model_1.pdf", dpi=120)

# %%
# Training the model
hist = model1.fit(X_raw_train,
          y_raw_train,
          batch_size=32,
          validation_data=(X_raw_test, y_raw_test),
          epochs=epochs)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 8s 129ms/step - loss: 0.4457 - accuracy: 0.8081 - val_loss: 0.3523 - val_accuracy: 0.8662
# Epoch 2/100
# 40/40 [==============================] - 4s 108ms/step - loss: 0.3379 - accuracy: 0.8654 - val_loss: 0.2888 - val_accuracy: 0.8854
# Epoch 3/100
# 40/40 [==============================] - 4s 109ms/step - loss: 0.2679 - accuracy: 0.8854 - val_loss: 0.2194 - val_accuracy: 0.9204
# Epoch 4/100
# 40/40 [==============================] - 4s 108ms/step - loss: 0.2296 - accuracy: 0.9124 - val_loss: 0.1868 - val_accuracy: 0.9236
# Epoch 5/100
# 40/40 [==============================] - 5s 114ms/step - loss: 0.1999 - accuracy: 0.9260 - val_loss: 0.1631 - val_accuracy: 0.9331
# Epoch 6/100
# 40/40 [==============================] - 6s 146ms/step - loss: 0.1668 - accuracy: 0.9363 - val_loss: 0.1654 - val_accuracy: 0.9236
# Epoch 7/100
# 40/40 [==============================] - 7s 171ms/step - loss: 0.1511 - accuracy: 0.9403 - val_loss: 0.1485 - val_accuracy: 0.9395
# Epoch 8/100
# 40/40 [==============================] - 8s 191ms/step - loss: 0.2575 - accuracy: 0.9053 - val_loss: 0.3220 - val_accuracy: 0.8758
# Epoch 9/100
# 40/40 [==============================] - 8s 184ms/step - loss: 0.2144 - accuracy: 0.9236 - val_loss: 0.2340 - val_accuracy: 0.9363
# Epoch 10/100
# 40/40 [==============================] - 5s 130ms/step - loss: 0.1834 - accuracy: 0.9387 - val_loss: 0.1244 - val_accuracy: 0.9459
# Epoch 11/100
# 40/40 [==============================] - 5s 115ms/step - loss: 0.0988 - accuracy: 0.9650 - val_loss: 0.0401 - val_accuracy: 0.9873
# Epoch 12/100
# 40/40 [==============================] - 5s 116ms/step - loss: 0.0410 - accuracy: 0.9873 - val_loss: 0.0178 - val_accuracy: 0.9968
# Epoch 13/100
# 40/40 [==============================] - 5s 117ms/step - loss: 0.0397 - accuracy: 0.9857 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 14/100
# 40/40 [==============================] - 5s 115ms/step - loss: 0.0500 - accuracy: 0.9817 - val_loss: 0.1486 - val_accuracy: 0.9586
# Epoch 15/100
# 40/40 [==============================] - 5s 128ms/step - loss: 0.0457 - accuracy: 0.9849 - val_loss: 0.0146 - val_accuracy: 0.9968
# Epoch 16/100
# 40/40 [==============================] - 5s 112ms/step - loss: 0.0220 - accuracy: 0.9936 - val_loss: 0.0142 - val_accuracy: 0.9936
# Epoch 17/100
# 40/40 [==============================] - 5s 114ms/step - loss: 0.0176 - accuracy: 0.9952 - val_loss: 0.0260 - val_accuracy: 0.9936
# Epoch 18/100
# 40/40 [==============================] - 5s 123ms/step - loss: 0.0189 - accuracy: 0.9944 - val_loss: 0.0230 - val_accuracy: 0.9968
# Epoch 19/100
# 40/40 [==============================] - 5s 125ms/step - loss: 0.0042 - accuracy: 0.9992 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 20/100
# 40/40 [==============================] - 5s 127ms/step - loss: 0.0136 - accuracy: 0.9960 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 21/100
# 40/40 [==============================] - 5s 115ms/step - loss: 0.0118 - accuracy: 0.9952 - val_loss: 0.0131 - val_accuracy: 0.9936
# Epoch 22/100
# 40/40 [==============================] - 5s 131ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.0135 - val_accuracy: 0.9968
# Epoch 23/100
# 40/40 [==============================] - 5s 132ms/step - loss: 0.0076 - accuracy: 0.9992 - val_loss: 0.0350 - val_accuracy: 0.9841
# Epoch 24/100
# 40/40 [==============================] - 6s 142ms/step - loss: 0.0333 - accuracy: 0.9889 - val_loss: 0.0509 - val_accuracy: 0.9682
# Epoch 25/100
# 40/40 [==============================] - 6s 144ms/step - loss: 0.0351 - accuracy: 0.9889 - val_loss: 0.0097 - val_accuracy: 0.9968
# Epoch 26/100
# 40/40 [==============================] - 6s 140ms/step - loss: 0.0052 - accuracy: 0.9992 - val_loss: 0.0630 - val_accuracy: 0.9873
# Epoch 27/100
# 40/40 [==============================] - 5s 135ms/step - loss: 0.0318 - accuracy: 0.9912 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 28/100
# 40/40 [==============================] - 5s 115ms/step - loss: 0.0099 - accuracy: 0.9968 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 29/100
# 40/40 [==============================] - 5s 114ms/step - loss: 0.0117 - accuracy: 0.9968 - val_loss: 0.0778 - val_accuracy: 0.9873
# Epoch 30/100
# 40/40 [==============================] - 5s 115ms/step - loss: 0.0077 - accuracy: 0.9968 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 31/100
# 40/40 [==============================] - 6s 139ms/step - loss: 0.0087 - accuracy: 0.9976 - val_loss: 0.0708 - val_accuracy: 0.9873
# Epoch 32/100
# 40/40 [==============================] - 5s 125ms/step - loss: 0.0254 - accuracy: 0.9920 - val_loss: 0.0421 - val_accuracy: 0.9841
# Epoch 33/100
# 40/40 [==============================] - 5s 114ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 34/100
# 40/40 [==============================] - 5s 133ms/step - loss: 0.0305 - accuracy: 0.9928 - val_loss: 0.1261 - val_accuracy: 0.9713
# Epoch 35/100
# 40/40 [==============================] - 5s 126ms/step - loss: 0.0881 - accuracy: 0.9682 - val_loss: 0.0240 - val_accuracy: 0.9873
# Epoch 36/100
# 40/40 [==============================] - 5s 128ms/step - loss: 0.0211 - accuracy: 0.9928 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 37/100
# 40/40 [==============================] - 6s 160ms/step - loss: 0.0102 - accuracy: 0.9984 - val_loss: 0.0046 - val_accuracy: 0.9968
# Epoch 38/100
# 40/40 [==============================] - 5s 128ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 39/100
# 40/40 [==============================] - 5s 128ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 40/100
# 40/40 [==============================] - 5s 120ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 9.2015e-04 - val_accuracy: 1.0000
# Epoch 41/100
# 40/40 [==============================] - 5s 119ms/step - loss: 9.4633e-04 - accuracy: 1.0000 - val_loss: 5.7408e-04 - val_accuracy: 1.0000
# Epoch 42/100
# 40/40 [==============================] - 5s 119ms/step - loss: 7.0115e-04 - accuracy: 1.0000 - val_loss: 4.2845e-04 - val_accuracy: 1.0000
# Epoch 43/100
# 40/40 [==============================] - 5s 129ms/step - loss: 5.3933e-04 - accuracy: 1.0000 - val_loss: 3.4795e-04 - val_accuracy: 1.0000
# Epoch 44/100
# 40/40 [==============================] - 5s 119ms/step - loss: 5.0235e-04 - accuracy: 1.0000 - val_loss: 2.9312e-04 - val_accuracy: 1.0000
# Epoch 45/100
# 40/40 [==============================] - 5s 117ms/step - loss: 4.6337e-04 - accuracy: 1.0000 - val_loss: 2.4516e-04 - val_accuracy: 1.0000
# Epoch 46/100
# 40/40 [==============================] - 5s 115ms/step - loss: 4.6170e-04 - accuracy: 1.0000 - val_loss: 2.0676e-04 - val_accuracy: 1.0000
# Epoch 47/100
# 40/40 [==============================] - 5s 124ms/step - loss: 4.5726e-04 - accuracy: 1.0000 - val_loss: 1.6718e-04 - val_accuracy: 1.0000
# Epoch 48/100
# 40/40 [==============================] - 5s 124ms/step - loss: 3.1791e-04 - accuracy: 1.0000 - val_loss: 1.4347e-04 - val_accuracy: 1.0000
# Epoch 49/100
# 40/40 [==============================] - 5s 124ms/step - loss: 3.5120e-04 - accuracy: 1.0000 - val_loss: 1.2652e-04 - val_accuracy: 1.0000
# Epoch 50/100
# 40/40 [==============================] - 5s 127ms/step - loss: 2.8975e-04 - accuracy: 1.0000 - val_loss: 1.1393e-04 - val_accuracy: 1.0000
# Epoch 51/100
# 40/40 [==============================] - 6s 139ms/step - loss: 2.6928e-04 - accuracy: 1.0000 - val_loss: 1.0225e-04 - val_accuracy: 1.0000
# Epoch 52/100
# 40/40 [==============================] - 5s 134ms/step - loss: 2.4087e-04 - accuracy: 1.0000 - val_loss: 9.2979e-05 - val_accuracy: 1.0000
# Epoch 53/100
# 40/40 [==============================] - 5s 120ms/step - loss: 2.6990e-04 - accuracy: 1.0000 - val_loss: 8.3642e-05 - val_accuracy: 1.0000
# Epoch 54/100
# 40/40 [==============================] - 5s 116ms/step - loss: 2.1838e-04 - accuracy: 1.0000 - val_loss: 7.6711e-05 - val_accuracy: 1.0000
# Epoch 55/100
# 40/40 [==============================] - 5s 118ms/step - loss: 1.9980e-04 - accuracy: 1.0000 - val_loss: 7.1265e-05 - val_accuracy: 1.0000
# Epoch 56/100
# 40/40 [==============================] - 5s 120ms/step - loss: 2.0438e-04 - accuracy: 1.0000 - val_loss: 6.6188e-05 - val_accuracy: 1.0000
# Epoch 57/100
# 40/40 [==============================] - 5s 123ms/step - loss: 1.9518e-04 - accuracy: 1.0000 - val_loss: 6.1311e-05 - val_accuracy: 1.0000
# Epoch 58/100
# 40/40 [==============================] - 5s 123ms/step - loss: 1.8466e-04 - accuracy: 1.0000 - val_loss: 5.7226e-05 - val_accuracy: 1.0000
# Epoch 59/100
# 40/40 [==============================] - 4s 111ms/step - loss: 1.7648e-04 - accuracy: 1.0000 - val_loss: 5.3265e-05 - val_accuracy: 1.0000
# Epoch 60/100
# 40/40 [==============================] - 5s 123ms/step - loss: 1.6173e-04 - accuracy: 1.0000 - val_loss: 4.9757e-05 - val_accuracy: 1.0000
# Epoch 61/100
# 40/40 [==============================] - 4s 111ms/step - loss: 1.5184e-04 - accuracy: 1.0000 - val_loss: 4.6649e-05 - val_accuracy: 1.0000
# Epoch 62/100
# 40/40 [==============================] - 4s 111ms/step - loss: 1.5169e-04 - accuracy: 1.0000 - val_loss: 4.3914e-05 - val_accuracy: 1.0000
# Epoch 63/100
# 40/40 [==============================] - 4s 110ms/step - loss: 1.6857e-04 - accuracy: 1.0000 - val_loss: 4.0933e-05 - val_accuracy: 1.0000
# Epoch 64/100
# 40/40 [==============================] - 5s 118ms/step - loss: 1.6299e-04 - accuracy: 1.0000 - val_loss: 3.8382e-05 - val_accuracy: 1.0000
# Epoch 65/100
# 40/40 [==============================] - 5s 124ms/step - loss: 1.4064e-04 - accuracy: 1.0000 - val_loss: 3.6315e-05 - val_accuracy: 1.0000
# Epoch 66/100
# 40/40 [==============================] - 4s 109ms/step - loss: 1.1755e-04 - accuracy: 1.0000 - val_loss: 3.4247e-05 - val_accuracy: 1.0000
# Epoch 67/100
# 40/40 [==============================] - 5s 113ms/step - loss: 1.2147e-04 - accuracy: 1.0000 - val_loss: 3.2496e-05 - val_accuracy: 1.0000
# Epoch 68/100
# 40/40 [==============================] - 5s 126ms/step - loss: 1.2651e-04 - accuracy: 1.0000 - val_loss: 3.0691e-05 - val_accuracy: 1.0000
# Epoch 69/100
# 40/40 [==============================] - 5s 113ms/step - loss: 1.0465e-04 - accuracy: 1.0000 - val_loss: 2.9350e-05 - val_accuracy: 1.0000
# Epoch 70/100
# 40/40 [==============================] - 5s 114ms/step - loss: 1.1158e-04 - accuracy: 1.0000 - val_loss: 2.7862e-05 - val_accuracy: 1.0000
# Epoch 71/100
# 40/40 [==============================] - 6s 149ms/step - loss: 9.4720e-05 - accuracy: 1.0000 - val_loss: 2.6527e-05 - val_accuracy: 1.0000
# Epoch 72/100
# 40/40 [==============================] - 7s 182ms/step - loss: 1.0406e-04 - accuracy: 1.0000 - val_loss: 2.5452e-05 - val_accuracy: 1.0000
# Epoch 73/100
# 40/40 [==============================] - 5s 113ms/step - loss: 8.6543e-05 - accuracy: 1.0000 - val_loss: 2.4248e-05 - val_accuracy: 1.0000
# Epoch 74/100
# 40/40 [==============================] - 5s 115ms/step - loss: 9.0853e-05 - accuracy: 1.0000 - val_loss: 2.3268e-05 - val_accuracy: 1.0000
# Epoch 75/100
# 40/40 [==============================] - 5s 122ms/step - loss: 8.8631e-05 - accuracy: 1.0000 - val_loss: 2.2183e-05 - val_accuracy: 1.0000
# Epoch 76/100
# 40/40 [==============================] - 4s 108ms/step - loss: 8.7487e-05 - accuracy: 1.0000 - val_loss: 2.1173e-05 - val_accuracy: 1.0000
# Epoch 77/100
# 40/40 [==============================] - 5s 112ms/step - loss: 6.9670e-05 - accuracy: 1.0000 - val_loss: 2.0312e-05 - val_accuracy: 1.0000
# Epoch 78/100
# 40/40 [==============================] - 5s 121ms/step - loss: 7.9637e-05 - accuracy: 1.0000 - val_loss: 1.9505e-05 - val_accuracy: 1.0000
# Epoch 79/100
# 40/40 [==============================] - 5s 116ms/step - loss: 7.2818e-05 - accuracy: 1.0000 - val_loss: 1.8708e-05 - val_accuracy: 1.0000
# Epoch 80/100
# 40/40 [==============================] - 5s 123ms/step - loss: 6.7780e-05 - accuracy: 1.0000 - val_loss: 1.7969e-05 - val_accuracy: 1.0000
# Epoch 81/100
# 40/40 [==============================] - 4s 111ms/step - loss: 6.8295e-05 - accuracy: 1.0000 - val_loss: 1.7306e-05 - val_accuracy: 1.0000
# Epoch 82/100
# 40/40 [==============================] - 5s 115ms/step - loss: 6.0126e-05 - accuracy: 1.0000 - val_loss: 1.6699e-05 - val_accuracy: 1.0000
# Epoch 83/100
# 40/40 [==============================] - 5s 115ms/step - loss: 6.4987e-05 - accuracy: 1.0000 - val_loss: 1.6130e-05 - val_accuracy: 1.0000
# Epoch 84/100
# 40/40 [==============================] - 5s 118ms/step - loss: 5.8820e-05 - accuracy: 1.0000 - val_loss: 1.5545e-05 - val_accuracy: 1.0000
# Epoch 85/100
# 40/40 [==============================] - 5s 114ms/step - loss: 6.0901e-05 - accuracy: 1.0000 - val_loss: 1.4942e-05 - val_accuracy: 1.0000
# Epoch 86/100
# 40/40 [==============================] - 5s 116ms/step - loss: 8.1577e-05 - accuracy: 1.0000 - val_loss: 1.4255e-05 - val_accuracy: 1.0000
# Epoch 87/100
# 40/40 [==============================] - 5s 116ms/step - loss: 5.8759e-05 - accuracy: 1.0000 - val_loss: 1.3761e-05 - val_accuracy: 1.0000
# Epoch 88/100
# 40/40 [==============================] - 5s 115ms/step - loss: 6.2768e-05 - accuracy: 1.0000 - val_loss: 1.3211e-05 - val_accuracy: 1.0000
# Epoch 89/100
# 40/40 [==============================] - 5s 116ms/step - loss: 5.7844e-05 - accuracy: 1.0000 - val_loss: 1.2742e-05 - val_accuracy: 1.0000
# Epoch 90/100
# 40/40 [==============================] - 5s 117ms/step - loss: 5.2997e-05 - accuracy: 1.0000 - val_loss: 1.2274e-05 - val_accuracy: 1.0000
# Epoch 91/100
# 40/40 [==============================] - 7s 185ms/step - loss: 4.7581e-05 - accuracy: 1.0000 - val_loss: 1.1885e-05 - val_accuracy: 1.0000
# Epoch 92/100
# 40/40 [==============================] - 6s 131ms/step - loss: 5.5847e-05 - accuracy: 1.0000 - val_loss: 1.1409e-05 - val_accuracy: 1.0000
# Epoch 93/100
# 40/40 [==============================] - 5s 131ms/step - loss: 4.7160e-05 - accuracy: 1.0000 - val_loss: 1.1034e-05 - val_accuracy: 1.0000
# Epoch 94/100
# 40/40 [==============================] - 5s 122ms/step - loss: 4.9636e-05 - accuracy: 1.0000 - val_loss: 1.0663e-05 - val_accuracy: 1.0000
# Epoch 95/100
# 40/40 [==============================] - 5s 120ms/step - loss: 4.5342e-05 - accuracy: 1.0000 - val_loss: 1.0325e-05 - val_accuracy: 1.0000
# Epoch 96/100
# 40/40 [==============================] - 5s 120ms/step - loss: 4.8682e-05 - accuracy: 1.0000 - val_loss: 9.9765e-06 - val_accuracy: 1.0000
# Epoch 97/100
# 40/40 [==============================] - 5s 116ms/step - loss: 3.9818e-05 - accuracy: 1.0000 - val_loss: 9.6652e-06 - val_accuracy: 1.0000
# Epoch 98/100
# 40/40 [==============================] - 5s 124ms/step - loss: 3.9086e-05 - accuracy: 1.0000 - val_loss: 9.3789e-06 - val_accuracy: 1.0000
# Epoch 99/100
# 40/40 [==============================] - 5s 122ms/step - loss: 4.2482e-05 - accuracy: 1.0000 - val_loss: 9.0683e-06 - val_accuracy: 1.0000
# Epoch 100/100
# 40/40 [==============================] - 5s 118ms/step - loss: 3.4776e-05 - accuracy: 1.0000 - val_loss: 8.8095e-06 - val_accuracy: 1.0000

# %%
# summarize history for accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy',fontsize=15, fontweight = 'bold')
plt.xlabel('epoch',fontsize=15, fontweight = 'bold')
plt.legend(['training accuracy', 'testing accuracy'], loc='center right')
plt.savefig('images/accuracybasemodel.pdf', dpi=200)
plt.show()
# summarize history for loss
def plot_curves(hist):
  loss = hist.history['loss']
  val_loss = hist.history['val_loss']
  epochs = range(1, len(loss) + 1)


  plt.figure()
  plt.plot(epochs, loss, 'g', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title('Training and validation loss')
  plt.xlabel('Epoch',fontsize=15, fontweight = 'bold')
  plt.ylabel('Loss',fontsize=15, fontweight = 'bold')
  plt.legend(loc='upper right')
  plt.savefig('images/modelTVloss_model1.pdf', dpi=200) 
  plt.show()

plot_curves(hist)

# %%
''''from keras.regularizers import l2  # dont yielded good outputs with regularization
# Initiliazing the sequential model
model = Sequential()
# Configuring the parameters
model.add(LSTM(128,recurrent_regularizer=l2(0.003),return_sequences=True,input_shape=(timesteps, input_dim)))
# Adding a dropout layer
model.add(Dropout(0.5))

model.add(LSTM(100,input_shape=(timesteps, input_dim)))
# Adding a dropout layer
model.add(Dropout(0.6))
# Adding a dense output layer with sigmoid activation
model.add(Dense(n_classes, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

# Training the model
hist = model.fit(X_raw_train,
          y_raw_train,
          batch_size=batch_size,
          validation_data=(X_raw_test, y_raw_test),
          epochs=epochs)

# summarize history for accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
#plt.savefig('accuracy.pdf', dpi=200)
plt.show()
# summarize history for loss
def plot_curves(hist):
  loss = hist.history['loss']
  val_loss = hist.history['val_loss']
  epochs = range(1, len(loss) + 1)


  plt.figure()
  plt.plot(epochs, loss, 'g', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title('Training and validation loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(loc='upper right')
  #plt.savefig('modelTVloss.pdf', dpi=200) 
  plt.show()

plot_curves(hist)'''
# Out:
# "'from keras.regularizers import l2  # dont yielded good outputs with regularization\n# Initiliazing the sequential model\nmodel = Sequential()\n# Configuring the parameters\nmodel.add(LSTM(128,recurrent_regularizer=l2(0.003),return_sequences=True,input_shape=(timesteps, input_dim)))\n# Adding a dropout layer\nmodel.add(Dropout(0.5))\n\nmodel.add(LSTM(100,input_shape=(timesteps, input_dim)))\n# Adding a dropout layer\nmodel.add(Dropout(0.6))\n# Adding a dense output layer with sigmoid activation\nmodel.add(Dense(n_classes, activation='sigmoid'))\n\nmodel.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])\nmodel.summary()\n\n# Training the model\nhist = model.fit(X_raw_train,\n          y_raw_train,\n          batch_size=batch_size,\n          validation_data=(X_raw_test, y_raw_test),\n          epochs=epochs)\n\n# summarize history for accuracy\nplt.plot(hist.history['accuracy'])\nplt.plot(hist.history['val_accuracy'])\nplt.title('Model Accuracy')\nplt.ylabel('accuracy')\nplt.xlabel('epoch')\nplt.legend(['train', 'test'], loc='upper left')\n#plt.savefig('accuracy.pdf', dpi=200)\nplt.show()\n# summarize history for loss\ndef plot_curves(hist):\n  loss = hist.history['loss']\n  val_loss = hist.history['val_loss']\n  epochs = range(1, len(loss) + 1)\n\n\n  plt.figure()\n  plt.plot(epochs, loss, 'g', label='Training loss')\n  plt.plot(epochs, val_loss, 'r', label='Validation loss')\n  plt.title('Training and validation loss')\n  plt.xlabel('Epoch')\n  plt.ylabel('Loss')\n  plt.legend(loc='upper right')\n  #plt.savefig('modelTVloss.pdf', dpi=200) \n  plt.show()\n\nplot_curves(hist)"

# %%
#####1-D Convolutional and LSTM together

data_dim = X_raw.shape[2] # = number of features = [{Acc_x, Acc_y, Acc_z, Gyr_*, Max_*, }] = 9
timesteps = X_raw.shape[1] # = 101 = (half_window_size:=50) * 2 + 1
num_classes = 1 # fall   (identifying fall_single class model) So we are using sigmoid activation and binary crossentropy
model2 = Sequential()
model2.add(Conv1D(filters=64, kernel_size=1, padding='same', activation='relu', input_shape=(timesteps, data_dim)))
model2.add(MaxPooling1D(pool_size=2))
model2.add(Conv1D(filters=128, kernel_size=1, padding='same', activation='relu', input_shape=(timesteps, data_dim)))
model2.add(MaxPooling1D(pool_size=2))
model2.add(LSTM(128))
model2.add(Dense(num_classes, activation='sigmoid'))
model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 32)                5376
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 5,409
# Trainable params: 5,409
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model2, show_shapes=True,to_file="images/model_2.pdf", dpi=120)

# %%
print(len(y_raw_test))
print(len(y_raw_test[y_raw_test == True])/len(y_raw_test))
print(len(y_raw_test[y_raw_test == False])/len(y_raw_test))
# Out:
# 314
# 0.5859872611464968
# 0.4140127388535032

# %%
hist = model2.fit(X_raw_train,y_raw_train,batch_size=64,epochs=100,validation_data=(X_raw_test, y_raw_test))
# Out:
# Epoch 1/100
# 20/20 [==============================] - 3s 79ms/step - loss: 0.3846 - accuracy: 0.8296 - val_loss: 0.2779 - val_accuracy: 0.8917
# Epoch 2/100
# 20/20 [==============================] - 1s 57ms/step - loss: 0.2322 - accuracy: 0.9005 - val_loss: 0.1775 - val_accuracy: 0.9172
# Epoch 3/100
# 20/20 [==============================] - 1s 55ms/step - loss: 0.1606 - accuracy: 0.9371 - val_loss: 0.1086 - val_accuracy: 0.9618
# Epoch 4/100
# 20/20 [==============================] - 1s 55ms/step - loss: 0.1121 - accuracy: 0.9594 - val_loss: 0.1252 - val_accuracy: 0.9395
# Epoch 5/100
# 20/20 [==============================] - 1s 55ms/step - loss: 0.0848 - accuracy: 0.9626 - val_loss: 0.0635 - val_accuracy: 0.9809
# Epoch 6/100
# 20/20 [==============================] - 1s 58ms/step - loss: 0.0656 - accuracy: 0.9777 - val_loss: 0.0414 - val_accuracy: 0.9904
# Epoch 7/100
# 20/20 [==============================] - 1s 57ms/step - loss: 0.0607 - accuracy: 0.9761 - val_loss: 0.0521 - val_accuracy: 0.9713
# Epoch 8/100
# 20/20 [==============================] - 1s 55ms/step - loss: 0.0383 - accuracy: 0.9912 - val_loss: 0.0322 - val_accuracy: 0.9936
# Epoch 9/100
# 20/20 [==============================] - 1s 53ms/step - loss: 0.0126 - accuracy: 0.9960 - val_loss: 0.0150 - val_accuracy: 0.9936
# Epoch 10/100
# 20/20 [==============================] - 1s 53ms/step - loss: 0.0065 - accuracy: 0.9992 - val_loss: 0.0099 - val_accuracy: 0.9968
# Epoch 11/100
# 20/20 [==============================] - 1s 50ms/step - loss: 0.0039 - accuracy: 0.9992 - val_loss: 0.0121 - val_accuracy: 0.9936
# Epoch 12/100
# 20/20 [==============================] - 1s 53ms/step - loss: 0.0240 - accuracy: 0.9928 - val_loss: 0.0708 - val_accuracy: 0.9777
# Epoch 13/100
# 20/20 [==============================] - 1s 52ms/step - loss: 0.0346 - accuracy: 0.9896 - val_loss: 0.0282 - val_accuracy: 0.9968
# Epoch 14/100
# 20/20 [==============================] - 1s 50ms/step - loss: 0.0109 - accuracy: 0.9976 - val_loss: 0.0138 - val_accuracy: 0.9968
# Epoch 15/100
# 20/20 [==============================] - 1s 52ms/step - loss: 0.0119 - accuracy: 0.9960 - val_loss: 0.0273 - val_accuracy: 0.9873
# Epoch 16/100
# 20/20 [==============================] - 1s 50ms/step - loss: 0.0484 - accuracy: 0.9833 - val_loss: 0.0340 - val_accuracy: 0.9841
# Epoch 17/100
# 20/20 [==============================] - 1s 53ms/step - loss: 0.0253 - accuracy: 0.9920 - val_loss: 0.0318 - val_accuracy: 0.9968
# Epoch 18/100
# 20/20 [==============================] - 1s 53ms/step - loss: 0.0171 - accuracy: 0.9952 - val_loss: 0.0247 - val_accuracy: 0.9936
# Epoch 19/100
# 20/20 [==============================] - 1s 49ms/step - loss: 0.0151 - accuracy: 0.9936 - val_loss: 0.0265 - val_accuracy: 0.9936
# Epoch 20/100
# 20/20 [==============================] - 1s 52ms/step - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.0209 - val_accuracy: 0.9968
# Epoch 21/100
# 20/20 [==============================] - 1s 49ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 0.9968
# Epoch 22/100
# 20/20 [==============================] - 1s 53ms/step - loss: 7.7764e-04 - accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 0.9936
# Epoch 23/100
# 20/20 [==============================] - 1s 48ms/step - loss: 5.8251e-04 - accuracy: 1.0000 - val_loss: 0.0176 - val_accuracy: 0.9936
# Epoch 24/100
# 20/20 [==============================] - 1s 53ms/step - loss: 4.1748e-04 - accuracy: 1.0000 - val_loss: 0.0158 - val_accuracy: 0.9968
# Epoch 25/100
# 20/20 [==============================] - 1s 53ms/step - loss: 3.5153e-04 - accuracy: 1.0000 - val_loss: 0.0151 - val_accuracy: 0.9968
# Epoch 26/100
# 20/20 [==============================] - 1s 51ms/step - loss: 3.0496e-04 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 0.9968
# Epoch 27/100
# 20/20 [==============================] - 1s 51ms/step - loss: 2.7204e-04 - accuracy: 1.0000 - val_loss: 0.0140 - val_accuracy: 0.9968
# Epoch 28/100
# 20/20 [==============================] - 1s 53ms/step - loss: 2.4228e-04 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 0.9968
# Epoch 29/100
# 20/20 [==============================] - 1s 50ms/step - loss: 2.2059e-04 - accuracy: 1.0000 - val_loss: 0.0130 - val_accuracy: 0.9968
# Epoch 30/100
# 20/20 [==============================] - 1s 54ms/step - loss: 2.0176e-04 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 0.9968
# Epoch 31/100
# 20/20 [==============================] - 1s 53ms/step - loss: 1.8613e-04 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 0.9968
# Epoch 32/100
# 20/20 [==============================] - 1s 51ms/step - loss: 1.7270e-04 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 0.9968
# Epoch 33/100
# 20/20 [==============================] - 1s 54ms/step - loss: 1.6053e-04 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 0.9968
# Epoch 34/100
# 20/20 [==============================] - 1s 50ms/step - loss: 1.4990e-04 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 0.9968
# Epoch 35/100
# 20/20 [==============================] - 1s 53ms/step - loss: 1.4022e-04 - accuracy: 1.0000 - val_loss: 0.0107 - val_accuracy: 0.9968
# Epoch 36/100
# 20/20 [==============================] - 1s 51ms/step - loss: 1.3239e-04 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 0.9968
# Epoch 37/100
# 20/20 [==============================] - 1s 54ms/step - loss: 1.2478e-04 - accuracy: 1.0000 - val_loss: 0.0100 - val_accuracy: 0.9968
# Epoch 38/100
# 20/20 [==============================] - 1s 53ms/step - loss: 1.1795e-04 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 0.9968
# Epoch 39/100
# 20/20 [==============================] - 1s 52ms/step - loss: 1.1192e-04 - accuracy: 1.0000 - val_loss: 0.0092 - val_accuracy: 0.9968
# Epoch 40/100
# 20/20 [==============================] - 1s 52ms/step - loss: 1.0652e-04 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 0.9968
# Epoch 41/100
# 20/20 [==============================] - 1s 53ms/step - loss: 1.0123e-04 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 0.9968
# Epoch 42/100
# 20/20 [==============================] - 1s 54ms/step - loss: 9.6638e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9968
# Epoch 43/100
# 20/20 [==============================] - 1s 54ms/step - loss: 9.2139e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9968
# Epoch 44/100
# 20/20 [==============================] - 1s 49ms/step - loss: 8.8300e-05 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 0.9968
# Epoch 45/100
# 20/20 [==============================] - 1s 52ms/step - loss: 8.4285e-05 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9968
# Epoch 46/100
# 20/20 [==============================] - 1s 48ms/step - loss: 8.0729e-05 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 0.9968
# Epoch 47/100
# 20/20 [==============================] - 1s 53ms/step - loss: 7.7474e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9968
# Epoch 48/100
# 20/20 [==============================] - 1s 51ms/step - loss: 7.4585e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9968
# Epoch 49/100
# 20/20 [==============================] - 1s 53ms/step - loss: 7.1534e-05 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 0.9968
# Epoch 50/100
# 20/20 [==============================] - 1s 53ms/step - loss: 6.8711e-05 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 0.9968
# Epoch 51/100
# 20/20 [==============================] - 1s 50ms/step - loss: 6.6068e-05 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 0.9968
# Epoch 52/100
# 20/20 [==============================] - 1s 49ms/step - loss: 6.3633e-05 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 0.9968
# Epoch 53/100
# 20/20 [==============================] - 1s 50ms/step - loss: 6.1280e-05 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 0.9968
# Epoch 54/100
# 20/20 [==============================] - 1s 50ms/step - loss: 5.9059e-05 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 0.9968
# Epoch 55/100
# 20/20 [==============================] - 1s 52ms/step - loss: 5.7034e-05 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 0.9968
# Epoch 56/100
# 20/20 [==============================] - 1s 50ms/step - loss: 5.5130e-05 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 0.9968
# Epoch 57/100
# 20/20 [==============================] - 1s 54ms/step - loss: 5.3202e-05 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 0.9968
# Epoch 58/100
# 20/20 [==============================] - 1s 52ms/step - loss: 5.1378e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 0.9968
# Epoch 59/100
# 20/20 [==============================] - 1s 54ms/step - loss: 4.9734e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 0.9968
# Epoch 60/100
# 20/20 [==============================] - 1s 54ms/step - loss: 4.8051e-05 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 0.9968
# Epoch 61/100
# 20/20 [==============================] - 1s 51ms/step - loss: 4.6610e-05 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 0.9968
# Epoch 62/100
# 20/20 [==============================] - 1s 53ms/step - loss: 4.5300e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 63/100
# 20/20 [==============================] - 1s 52ms/step - loss: 4.3716e-05 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 64/100
# 20/20 [==============================] - 1s 54ms/step - loss: 4.2463e-05 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 65/100
# 20/20 [==============================] - 1s 55ms/step - loss: 4.1158e-05 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 66/100
# 20/20 [==============================] - 1s 53ms/step - loss: 3.9980e-05 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 67/100
# 20/20 [==============================] - 1s 53ms/step - loss: 3.8918e-05 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 68/100
# 20/20 [==============================] - 1s 54ms/step - loss: 3.7747e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 69/100
# 20/20 [==============================] - 1s 51ms/step - loss: 3.6767e-05 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 70/100
# 20/20 [==============================] - 1s 54ms/step - loss: 3.5815e-05 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 71/100
# 20/20 [==============================] - 1s 54ms/step - loss: 3.4875e-05 - accuracy: 1.0000 - val_loss: 9.8041e-04 - val_accuracy: 1.0000
# Epoch 72/100
# 20/20 [==============================] - 1s 50ms/step - loss: 3.3984e-05 - accuracy: 1.0000 - val_loss: 8.5385e-04 - val_accuracy: 1.0000
# Epoch 73/100
# 20/20 [==============================] - 1s 49ms/step - loss: 3.3130e-05 - accuracy: 1.0000 - val_loss: 7.6007e-04 - val_accuracy: 1.0000
# Epoch 74/100
# 20/20 [==============================] - 1s 54ms/step - loss: 3.2312e-05 - accuracy: 1.0000 - val_loss: 7.4667e-04 - val_accuracy: 1.0000
# Epoch 75/100
# 20/20 [==============================] - 1s 59ms/step - loss: 3.1535e-05 - accuracy: 1.0000 - val_loss: 6.4597e-04 - val_accuracy: 1.0000
# Epoch 76/100
# 20/20 [==============================] - 1s 53ms/step - loss: 3.0774e-05 - accuracy: 1.0000 - val_loss: 5.8735e-04 - val_accuracy: 1.0000
# Epoch 77/100
# 20/20 [==============================] - 1s 53ms/step - loss: 3.0058e-05 - accuracy: 1.0000 - val_loss: 5.2066e-04 - val_accuracy: 1.0000
# Epoch 78/100
# 20/20 [==============================] - 1s 52ms/step - loss: 2.9358e-05 - accuracy: 1.0000 - val_loss: 4.6438e-04 - val_accuracy: 1.0000
# Epoch 79/100
# 20/20 [==============================] - 1s 52ms/step - loss: 2.8686e-05 - accuracy: 1.0000 - val_loss: 4.3387e-04 - val_accuracy: 1.0000
# Epoch 80/100
# 20/20 [==============================] - 1s 53ms/step - loss: 2.8064e-05 - accuracy: 1.0000 - val_loss: 4.0249e-04 - val_accuracy: 1.0000
# Epoch 81/100
# 20/20 [==============================] - 1s 51ms/step - loss: 2.7425e-05 - accuracy: 1.0000 - val_loss: 3.6363e-04 - val_accuracy: 1.0000
# Epoch 82/100
# 20/20 [==============================] - 1s 52ms/step - loss: 2.6843e-05 - accuracy: 1.0000 - val_loss: 3.3587e-04 - val_accuracy: 1.0000
# Epoch 83/100
# 20/20 [==============================] - 1s 52ms/step - loss: 2.6281e-05 - accuracy: 1.0000 - val_loss: 3.1443e-04 - val_accuracy: 1.0000
# Epoch 84/100
# 20/20 [==============================] - 1s 51ms/step - loss: 2.5700e-05 - accuracy: 1.0000 - val_loss: 2.8626e-04 - val_accuracy: 1.0000
# Epoch 85/100
# 20/20 [==============================] - 1s 53ms/step - loss: 2.5203e-05 - accuracy: 1.0000 - val_loss: 2.8356e-04 - val_accuracy: 1.0000
# Epoch 86/100
# 20/20 [==============================] - 1s 51ms/step - loss: 2.4659e-05 - accuracy: 1.0000 - val_loss: 2.5083e-04 - val_accuracy: 1.0000
# Epoch 87/100
# 20/20 [==============================] - 1s 52ms/step - loss: 2.4177e-05 - accuracy: 1.0000 - val_loss: 2.3269e-04 - val_accuracy: 1.0000
# Epoch 88/100
# 20/20 [==============================] - 1s 49ms/step - loss: 2.3668e-05 - accuracy: 1.0000 - val_loss: 2.1778e-04 - val_accuracy: 1.0000
# Epoch 89/100
# 20/20 [==============================] - 1s 51ms/step - loss: 2.3181e-05 - accuracy: 1.0000 - val_loss: 2.0547e-04 - val_accuracy: 1.0000
# Epoch 90/100
# 20/20 [==============================] - 1s 51ms/step - loss: 2.2712e-05 - accuracy: 1.0000 - val_loss: 1.8756e-04 - val_accuracy: 1.0000
# Epoch 91/100
# 20/20 [==============================] - 1s 52ms/step - loss: 2.2266e-05 - accuracy: 1.0000 - val_loss: 1.7991e-04 - val_accuracy: 1.0000
# Epoch 92/100
# 20/20 [==============================] - 1s 49ms/step - loss: 2.1831e-05 - accuracy: 1.0000 - val_loss: 1.6312e-04 - val_accuracy: 1.0000
# Epoch 93/100
# 20/20 [==============================] - 1s 49ms/step - loss: 2.1421e-05 - accuracy: 1.0000 - val_loss: 1.5688e-04 - val_accuracy: 1.0000
# Epoch 94/100
# 20/20 [==============================] - 1s 54ms/step - loss: 2.1000e-05 - accuracy: 1.0000 - val_loss: 1.4429e-04 - val_accuracy: 1.0000
# Epoch 95/100
# 20/20 [==============================] - 1s 51ms/step - loss: 2.0599e-05 - accuracy: 1.0000 - val_loss: 1.3742e-04 - val_accuracy: 1.0000
# Epoch 96/100
# 20/20 [==============================] - 1s 49ms/step - loss: 2.0216e-05 - accuracy: 1.0000 - val_loss: 1.3271e-04 - val_accuracy: 1.0000
# Epoch 97/100
# 20/20 [==============================] - 1s 48ms/step - loss: 1.9818e-05 - accuracy: 1.0000 - val_loss: 1.2696e-04 - val_accuracy: 1.0000
# Epoch 98/100
# 20/20 [==============================] - 1s 49ms/step - loss: 1.9457e-05 - accuracy: 1.0000 - val_loss: 1.1887e-04 - val_accuracy: 1.0000
# Epoch 99/100
# 20/20 [==============================] - 1s 51ms/step - loss: 1.9095e-05 - accuracy: 1.0000 - val_loss: 1.1105e-04 - val_accuracy: 1.0000
# Epoch 100/100
# 20/20 [==============================] - 1s 51ms/step - loss: 1.8763e-05 - accuracy: 1.0000 - val_loss: 1.0768e-04 - val_accuracy: 1.0000

# %%
# summarize history for accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy',fontsize=15, fontweight = 'bold')
plt.xlabel('epoch',fontsize=15, fontweight = 'bold')
plt.legend(['training accuracy', 'testing accuracy'], loc='center right')
plt.savefig('images/accuracybasemodel.pdf', dpi=200)
plt.show()
# summarize history for loss
def plot_curves(hist):
  loss = hist.history['loss']
  val_loss = hist.history['val_loss']
  epochs = range(1, len(loss) + 1)


  plt.figure()
  plt.plot(epochs, loss, 'g', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title('Training and validation loss')
  plt.xlabel('Epoch',fontsize=15, fontweight = 'bold')
  plt.ylabel('Loss',fontsize=15, fontweight = 'bold')
  plt.legend(loc='upper right')
  plt.savefig('images/modelTVloss_model1.pdf', dpi=200) 
  plt.show()

plot_curves(hist)

# %%
scores = model.evaluate(X_raw_test, y_raw_test, verbose=1)
print("Accuracy_model: {:.2f}%".format(scores[1]*100))
scores, model.metrics_names

from sklearn.metrics import accuracy_score
#predictions = model.predict_classes(X_raw_test)  # this is outdated to version 2.5 and above for tensorflow
predictions = (model.predict(X_raw_test) > 0.5).astype("int32")
accuracy_score(y_raw_test, predictions)
# Out:
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0121 - accuracy: 0.9968
# Accuracy_model: 99.68%
# 0.9968152866242038

# %%
scores = model1.evaluate(X_raw_test, y_raw_test, verbose=1)
print("Accuracy_model1: {:.2f}%".format(scores[1]*100))
scores, model1.metrics_names


from sklearn.metrics import accuracy_score
#predictions = model.predict_classes(X_raw_test)  # this is outdated to version 2.5 and above for tensorflow
predictions = (model1.predict(X_raw_test) > 0.5).astype("int32")
accuracy_score(y_raw_test, predictions)
# Out:
# 10/10 [==============================] - 0s 34ms/step - loss: 8.8095e-06 - accuracy: 1.0000
# Accuracy_model1: 100.00%
# 1.0

# %%
scores = model2.evaluate(X_raw_test, y_raw_test, verbose=1)
print("Accuracy_model2: {:.2f}%".format(scores[1]*100))
scores, model2.metrics_names


from sklearn.metrics import accuracy_score
#predictions = model.predict_classes(X_raw_test)  # this is outdated to version 2.5 and above for tensorflow
predictions = (model2.predict(X_raw_test) > 0.5).astype("int32")
accuracy_score(y_raw_test, predictions)
# Out:
# 10/10 [==============================] - 0s 16ms/step - loss: 1.0768e-04 - accuracy: 1.0000
# Accuracy_model2: 100.00%
# 1.0

# %%
""""#n_timesteps, n_features, n_outputs = X_raw.shape[2], X_raw.shape[1], 1

# the concept is same in this case:

data_dim = X_raw.shape[2] # = number of features = [{Acc_x, Acc_y, Acc_z, Gyr_*, Max_*, }] = 9
timesteps = X_raw.shape[1] # = 101 = (half_window_size:=50) * 2 + 1
num_classes = 1 # fall?


#second model 

model1 = Sequential()
model1.add(LSTM(128, input_shape=(timesteps, data_dim)))
model1.add(Dropout(0.5))
model1.add(Dense(100, activation='sigmoid'))
model1.add(Dropout(0.5))
model1.add(Dense(100, activation='sigmoid'))
model1.add(Dropout(0.5))
model1.add(Dense(num_classes, activation='softmax'))
model1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
print(model1.summary())"""


''''import tensorflow as tf
tf.keras.utils.plot_model(model1, show_shapes=True)


from sklearn.model_selection import train_test_split

X_raw_train, X_raw_test, y_raw_train, y_raw_test = train_test_split(X_raw, y_raw, test_size=0.2, random_state=0)


import matplotlib.pyplot as plt

def plot_curves(hist):
  loss = hist.history['loss']
  val_loss = hist.history['val_loss']
  epochs = range(1, len(loss) + 1)
  
  
  # fit network
batch_size =256
num_epochs = 50
validation_split = 0.20
#hist = model1.fit(X_raw_train, y_raw_train, batch_size=batch_size, validation_split=validation_split, epochs=num_epochs)
hist = model1.fit(X_raw_train,y_raw_train,batch_size=batch_size,epochs=num_epochs,validation_data=(X_raw_test, y_raw_test))

  plt.figure()
  plt.plot(epochs, loss, 'g', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title('Training and validation loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(loc='upper right')

  plt.show()

plot_curves(hist)'''
# Out:
# "'import tensorflow as tf\ntf.keras.utils.plot_model(model1, show_shapes=True)\n\n\nfrom sklearn.model_selection import train_test_split\n\nX_raw_train, X_raw_test, y_raw_train, y_raw_test = train_test_split(X_raw, y_raw, test_size=0.2, random_state=0)\n\n\nimport matplotlib.pyplot as plt\n\ndef plot_curves(hist):\n  loss = hist.history['loss']\n  val_loss = hist.history['val_loss']\n  epochs = range(1, len(loss) + 1)\n  \n  \n  # fit network\nbatch_size =256\nnum_epochs = 50\nvalidation_split = 0.20\n#hist = model1.fit(X_raw_train, y_raw_train, batch_size=batch_size, validation_split=validation_split, epochs=num_epochs)\nhist = model1.fit(X_raw_train,y_raw_train,batch_size=batch_size,epochs=num_epochs,validation_data=(X_raw_test, y_raw_test))\n\n  plt.figure()\n  plt.plot(epochs, loss, 'g', label='Training loss')\n  plt.plot(epochs, val_loss, 'r', label='Validation loss')\n  plt.title('Training and validation loss')\n  plt.xlabel('Epoch')\n  plt.ylabel('Loss')\n  plt.legend(loc='upper right')\n\n  plt.show()\n\nplot_curves(hist)"

# %%
#Refinement/standard machine learning

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

clf = KNeighborsClassifier(n_neighbors=3)
parameters = {'n_neighbors': [5, 6, 7],
              'weights': ['uniform', 'distance'],
              'p': [1, 2]}
grid_obj = GridSearchCV(clf,
                        param_grid=parameters,
                        scoring=make_scorer(accuracy_score),
                        cv=3)
grid_fit = grid_obj.fit(X_feature_train, y_feature_train)
best_clf = grid_fit.best_estimator_
predictions = (clf.fit(X_feature_train, y_feature_train)).predict(X_feature_test)
best_predictions = best_clf.predict(X_feature_test)

print("Unoptimized model\n------")
print("Accuracy score on testing data: {:.2f}%".format(accuracy_score(y_feature_test, predictions) * 100))
print("\nOptimized Model\n------")
print("Final accuracy score on the testing data: {:.2f}%".format(accuracy_score(y_feature_test, best_predictions) * 100))
best_clf
# Out:
# Unoptimized model
# ------
# Accuracy score on testing data: 100.00%
#
# Optimized Model
# ------
# Final accuracy score on the testing data: 99.68%
# KNeighborsClassifier()

# %%
from sklearn.base import clone
from sklearn.ensemble import RandomForestClassifier

model = DecisionTreeClassifier(random_state=120)
model.fit(X_feature_train, y_feature_train)

importances = model.feature_importances_

# Reduce the feature space
num_features = 68
X_feature_train_reduced = X_feature_train[X_feature_train.columns.values[(np.argsort(importances)[::-1])[:num_features]]]
X_feature_test_reduced = X_feature_test[X_feature_test.columns.values[(np.argsort(importances)[::-1])[:num_features]]]

clf = (clone(best_clf)).fit(X_feature_train_reduced, y_feature_train)

reduced_predictions = clf.predict(X_feature_test_reduced)

# Report scores from the final model using both versions of data
print("Final Model trained on full data\n------")
print("Accuracy on testing data: {:.2f}%".format(accuracy_score(y_feature_test, best_predictions) * 100))
print("\nFinal Model trained on reduced data\n------")
print("Accuracy on testing data: {:.2f}%".format(accuracy_score(y_feature_test, reduced_predictions) * 100))
# Out:
# Final Model trained on full data
# ------
# Accuracy on testing data: 99.68%
#
# Final Model trained on reduced data
# ------
# Accuracy on testing data: 99.04%

# %%
pca = PCA(n_components=68).fit(X_feature_train)
X_feature_train_pca = pca.transform(X_feature_train)
X_feature_test_pca = pca.transform(X_feature_test)

clf = (clone(best_clf)).fit(X_feature_train_pca, y_feature_train)

reduced_predictions = clf.predict(X_feature_test_pca)

# Report scores from the final model using both versions of data
print("Final Model trained on full data\n------")
print("Accuracy on testing data: {:.2f}%".format(accuracy_score(y_feature_test, best_predictions) * 100))
print("\nFinal Model trained on reduced data\n------")
print("Accuracy on testing data: {:.2f}%".format(accuracy_score(y_feature_test, reduced_predictions) * 100))
# Out:
# Final Model trained on full data
# ------
# Accuracy on testing data: 99.68%
#
# Final Model trained on reduced data
# ------
# Accuracy on testing data: 99.68%
